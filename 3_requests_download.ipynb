# %% [markdown]
# # Scraping search results with the `requests` library

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import Python modules

# %%
import os
import re
import time
from glob import glob
from random import choice, uniform
from zipfile import ZipFile

import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Import any custom modules

# %%
# Manually assembled list of browser headers to submit in a GET request
# %aimport src.webscraping_utils
from src.webscraping_utils import get_custom_headers_list

# %% [markdown]
# <a href="table-of-contents"></a>
#
# ## [Table of Contents](#table-of-contents)
# 0. [About](#about)
# 1. [User Inputs](#user-inputs)
# 2. [Scrape](#scrape)
# 3. [Examine collected outputs](#examine-collected-outputs)

# %% [markdown]
# <a id="about"></a>
#
# ## 0. [About](#about)

# %% [markdown]
# In this notebook, we will iterate over pages of search results for game listings on the Steam store using the `requests` library. We will get the HTML for each page of search results and then scrape the price, listing URL and supported platforms from each listing on each page. The scraping process will be described later in this notebook.

# %% [markdown]
# <a id="user-inputs"></a>
#
# ## 1. [User Inputs](#user-inputs)

# %% [markdown]
# Define variables that can be changed when running this notebook

# %%
PROJ_ROOT_DIR = os.getcwd()

# %%
# Cookies to be sent to Steam store to get access to listings that have an age requirement
cookies = {'birthtime': '283993201', 'mature_content': '1', "lastagecheckage":"14-0-1973"}

# Search results page numbers to be scraped
page_to_start_scraping = 50
number_pages_to_scrape = 50

# Delay before navigating to a new page of search results
min_pause_between_pages = 2.8
max_pause_between_pages = 4.2

# %% [markdown]
# Define variables that depend on the variables defined above
# - get paths to directories where single-row CSV files (produced after scraping) will be stored
# - adjust the number of pages of search results to be scraped
#   - this will depend on the maximum number of pages available and on the search results page numbers that are to be scraped (defined above in `page_to_start_scraping` and `number_pages_to_scrape`)
#     - Step 1. extract the maximum number of pages available, from the soup for the first page of search results
#     - Step 2. reduce `number_pages_to_scrape` if the sum of `page_to_start_scraping` and `number_pages_to_scrape` is larger than the maximum number of pages of search results available
# - create a list of manually assembled dictionaries of browser header, using the custom module imported earlier

# %%
data_dir = os.path.join(PROJ_ROOT_DIR, "data")
raw_data_dir = os.path.join(data_dir, "raw")
requests_data_dir = os.path.join(raw_data_dir, "requests")

# Adjust number of pages to scrape, based on last available page number
# # Step 1. Get first page of search results and determine last available page number
r = requests.get("https://store.steampowered.com/search/?category1=998&page=1")
soup = BeautifulSoup(r.content, "html.parser")
page_right_container = soup.find("div", {"class": "search_pagination_right"})
last_page = int(page_right_container.find_all("a")[-2].text)

# # Step 2. Adjust number of pages to scrape, based on last available page number
# - if the sum of the manually specified number of pages to scrape and the starting
#   page number exceeds last available page number, then re-calculate number of pages
#   to scrape by subtracting the page to start scraping from the last available page number
if page_to_start_scraping + number_pages_to_scrape > last_page:
    number_pages_to_scrape = last_page - page_to_start_scraping

# Define list of request headers to (randomly) choose from
headers_list = get_custom_headers_list()

# %% [markdown]
# Export list of `DataFrame`s to parquet files

# %%
def save_to_parquet_file(dfs: list, parquet_filepaths: list):
    """Save DataFrame to parquet file."""
    for parquet_filepath, df in zip(parquet_filepaths, dfs):
        try:
            print(f"Saving data to {parquet_filepath + '.gzip'}", end="...")
            df.to_parquet(
                parquet_filepath + ".gzip",
                engine="auto",
                index=False,
                compression="gzip",
            )
            print("done.")
        except Exception as e:
            print(str(e))
            raise

# %% [markdown]
# Define function to perform scraping of single search results page, using the following steps
# 1. Try to get one or more rows of search results
#    - if this is not possible, then no search results were returned (don't scrape this)
#      - assign attributes to this page number with `None` in all the expected columns
#    - if this is possible, then scrape search results page (see next step for details)
# 2. If one or more rows of search results is displayed, then iterate over each row of search results and use `BeautifulSoup` to scrape the displayed information on the web page
# 3. Export scraped attributes to CSV

# %%
def scrape_single_page_search_results(
    soup, raw_data_dir, current_page_num, request_status_code, verbose=False
):
    """Scrape a single page of search results."""
    # 1. Get all search results displayed on page
    search_results_div = soup.find(
        'div',
        {"id" :"search_resultsRows"}
    ).find_all("a", class_="search_result_row")
    d_search_results = []
    try:
        # 1. Verify some search results on page
        assert len(search_results_div) > 0
        try:
            # 2. Iterate over all rows of search results found on page
            for k, search_result in enumerate(search_results_div):
                listing_info = search_result.find("div", class_="responsive_search_name_combined")

                # Get title
                title_os = listing_info.find("div", class_="col search_name ellipsis")
                title = title_os.find("span", class_="title").text.strip()
                title = re.sub(r"\W+", "", title.replace(' ', '_'))

                # Get app_id and listing URL
                app_id = search_result["data-ds-appid"]
                url = f"https://store.steampowered.com/app/{app_id}/{title}/"

                # Get supported platforms
                try:
                    platform_spans = title_os.find("p").find_all("span")
                    platform_names = ",".join(
                        [
                            p["class"][-1]
                            for p in platform_spans
                        ]
                    )
                except Exception:
                    platform_names = [None, None, None]
                # print(3)

                # Get release date
                try:
                    rel_date = listing_info.find("div", class_="col search_released responsive_secondrow")
                    release_date = rel_date.text.strip()
                except Exception:
                    release_date = None

                # Get discount percent
                xpath_discount_price = (
                    './/div[contains(@class,"search_price_discount_combined")]/div'
                )
                discount_price = listing_info.find(
                    "div", {"class": "search_price_discount_combined"}
                ).find_all("div")
                discount_pct = (
                    discount_price[0].text.strip() if discount_price[0].text.strip() else None
                )
                
                # Get original and discount price (if any)
                try:
                    price = listing_info.find(
                        "div", class_="search_price_discount_combined"
                    ).find("div", class_="search_price")
                    price = price.text.strip()
                    _, original_price, discount_price = price.split("$")
                    original_price, discount_price = [original_price, discount_price]
                except Exception:
                    # print(5)
                    original_price = (
                        discount_price[1].text.strip().replace("$", "")
                        if discount_price[1].text.strip()
                        else None
                    )
                    discount_price = None

                # print summary message to screen
                if verbose:
                    print(
                        current_page_num,
                        request_status_code,
                        k + 1,
                        title,
                        app_id,
                        platform_names,
                        release_date,
                        discount_pct,
                        original_price,
                        discount_price,
                    )

                # Append dict of scraped information to list
                d_search_results.append(
                    {
                        "page": current_page_num,
                        "request_status_code": request_status_code,
                        "listing_counter": k + 1,
                        "title": title,
                        "url": url,
                        "platform_names": platform_names,
                        "release_date": release_date,
                        "discount_pct": discount_pct,
                        "original_price": original_price,
                        "discount_price": discount_price,
                    }
                )
            print(
                "Retrieved listings from search results page "
                f"{current_page_num}."
            )
        # Handle error during scraping of single search results page
        except Exception:
            d_search_results.append(
                {
                    "page": current_page_num,
                    "request_status_code": request_status_code,
                    "listing_counter": k + 1,
                    "title": None,
                    "url": None,
                    "platform_names": None,
                    "release_date": None,
                    "discount_pct": None,
                    "original_price": None,
                    "discount_price": None,
                }
            )
            print(
                "Error retrieving listings from search results page "
                f"{current_page_num}."
            )
    # Handle error of no search results
    except Exception:
        d_search_results = [
            {
                "page": current_page_num,
                "request_status_code": request_status_code,
                "listing_counter": k + 1,
                "title": None,
                "url": None,
                "platform_names": None,
                "release_date": None,
                "discount_pct": None,
                "original_price": None,
                "discount_price": None,
            }
            for _ in range(25)
        ]
        print("No listings on search results page " f"{current_page_num}.\n")

    # 3. Create DataFrame from list of dicts and export to CSV
    df_single_page_search_results_single_page = pd.DataFrame.from_records(
        d_search_results
    )
    timestr = time.strftime("%Y%m%d_%H%M%S")
    parquet_filepath = os.path.join(
        raw_data_dir,
        f"search_results_page_{current_page_num}_{timestr}.parquet",
    )
    if not os.path.exists(parquet_filepath):
        save_to_parquet_file(
            [df_single_page_search_results_single_page], [parquet_filepath]
        )
        print(f"Exported search results for page {current_page_num}.\n")
    else:
        print(
            "File was found with search results information for page "
            f"{current_page_num}. Did nothing.\n"
        )

# %% [markdown]
# We'll now scrape all search results that are displayed. We'll define a `while` loop that compares the number of search results found to the number to be scraped (calculated from `page_to_start_scraping` and `number_pages_to_scrape`). This comparison will be used to determine whether to proceed with the next iteration of the `while` loop (if the comparison returns `True`) or not (if it returns `False`). If okay to move ahead, then the loop will move to the next page of search results.
#
# This process includes the following two steps
# 1. If number of search results found is less than the total number of search results to be scraped (see `page_to_start_scraping` and `number_pages_to_scrape`), then continue (and increment the page number by 1); else break out of the `while` loop.
# 2. If able to continue from step 1. then
#    - (a) get a random header from the list of headers above
#    - (b) send a GET request to get HTML from page
#    - (c) Pause before scraping
#    - (d) Scrape HTML to get listing attributes

# %%
def scrape_search_results_pages(
    raw_data_dir,
    cookies={
        'birthtime': '283993201',
        'mature_content': '1',
        "lastagecheckage":"1-0-1900",
    },
    base_url=(
        "https://store.steampowered.com/search/?"
        "category1=998&supportedlang=english&page="
    ),
    n=100,
    page=500,
    min_pause_between_pages=1.5,
    max_pause_between_pages=2.5,
    verbose=False,
):
    """Scrape pages of search results."""
    # 1. Check number of search results available compared to number re
    while page * 25 < n:
        page += 1
        # 2. (a) Get random request header
        headers = choice(headers_list)
        # 2. (b) Send GET request
        with requests.Session() as r:
            response = r.get(
                url=base_url+str(page),
                cookies=cookies,
                headers=headers,
            )
        # 2. (c) Pause before scraping
        print(f"Received response to request from page {page}...", end="")
        pause_duration = uniform(min_pause_between_pages, max_pause_between_pages)
        print(f"Pausing for {pause_duration:.2f} sec...", end="")
        time.sleep(pause_duration)
        print("done.")
        # 2. (d) Scrape search results
        soup = BeautifulSoup(response.content, "html.parser")
        scrape_single_page_search_results(
            soup,
            raw_data_dir,
            page,
            response.status_code,
            verbose,
        )
        print(
            f"Completed page {page} [collected {(page-1) * 25}-{page * 25} search results "
            f"(max. search result index wanted = {n})].\n"
        )

# %% [markdown]
# <a id="scrape"></a>
#
# ## 2. [Scrape](#scrape)

# %% [markdown]
# Calculate the number of search results that will be retrieved
# - there are 25 listings displayed on a single page of search results

# %%
ending_search_result = ((page_to_start_scraping - 1) + number_pages_to_scrape) * 25
print(ending_search_result)
# Out:
# 2475

# %% [markdown]
# Scrape the number of listings required (see `number_pages_to_scrape` defined earlier), starting from the required starting page number (see `page_to_start_scraping`)

# %%
# %%time
scrape_search_results_pages(
    requests_data_dir,
    n=ending_search_result,
    page=page_to_start_scraping - 1,
    min_pause_between_pages=min_pause_between_pages,
    max_pause_between_pages=max_pause_between_pages,
    verbose=True,
)
# Out:
# Received response to request from page 50...Pausing for 4.01 sec...done.
# 50 200 1 Blazing_Sails 1158940 win Nov 5, 2020 -30% 14.99 10.49
# 50 200 2 LEGO_Harry_Potter_Years_14 21130 win Jun 25, 2010 None 19.99 None
# 50 200 3 Source_of_Madness 1315610 win Sep 22, 2021 None 16.99 None
# 50 200 4 Roll 1585910 win,mac May 13, 2021 None 4.99 None
# 50 200 5 Cloud_Gardens 1372320 win,mac Sep 1, 2021 None 17.99 None
# 50 200 6 Soul_Nomad__the_World_Eaters 1535610 win Aug 31, 2021 None 19.99 None
# 50 200 7 Yakuza_5_Remastered 1105510 win Jan 28, 2021 None 19.99 None
# 50 200 8 Maid_of_Sker 826940 win Jul 28, 2020 -55% 24.99 11.24
# 50 200 9 Cultist_Simulator 718670 win,mac,linux May 31, 2018 None 19.99 None
# 50 200 10 Sakuna_Of_Rice_and_Ruin 1356670 win Nov 10, 2020 None 39.99 None
# 50 200 11 Shovel_Knight_Treasure_Trove 250760 win,mac,linux Jun 26, 2014 None 39.99 None
# 50 200 12 Max_Payne_3 204100 win May 31, 2012 None 19.99 None
# 50 200 13 The_Sinking_City 750130 win Feb 26, 2021 None 39.99 None
# 50 200 14 Bloodwash 1598160 win Sep 16, 2021 None 7.99 None
# 50 200 15 Dungeon_Defenders 65800 win,mac,linux Oct 18, 2011 None 14.99 None
# 50 200 16 Deus_Ex_Mankind_Divided 337000 win,mac,linux Aug 23, 2016 None 29.99 None
# 50 200 17 League_of_AngelsHeavens_Fury 1379130 win Sep 3, 2020 None Free None
# 50 200 18 Voidigo 1304680 win Feb 25, 2021 None 14.99 None
# 50 200 19 Jupiter_Hell 811320 win,mac,linux Aug 5, 2021 None 24.99 None
# 50 200 20 State_of_Decay_YOSE 329430 win Apr 27, 2015 None 19.99 None
# 50 200 21 Uncrashed__FPV_Drone_Simulator 1682970 win Sep 1, 2021 None 14.99 None
# 50 200 22 LEGO_Marvel_Super_Heroes 249130 win Oct 22, 2013 None 19.99 None
# 50 200 23 ELEX 411300 win Oct 17, 2017 None 49.99 None
# 50 200 24 STAR_WARS__The_Force_Unleashed_Ultimate_Sith_Edition 32430 win,mac Dec 15, 2009 None 19.99 None
# 50 200 25 Onmyoji 551170 win Apr 18, 2018 None Free To Play None
# Retrieved listings from search results page 50.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_50_20211019_145402.parquet.gzip...done.
# Exported search results for page 50.
#
# Completed page 50 [collected 1225-1250 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 51...Pausing for 3.01 sec...done.
# 51 200 1 Bright_Memory 955050 win Mar 25, 2020 None 9.99 None
# 51 200 2 Pumpkin_Jack 1186640 win Oct 23, 2020 None 29.99 None
# 51 200 3 VALKYRIE_CONNECT 1222800 win Apr 2, 2020 None Free To Play None
# 51 200 4 Big_Farm_Story 1329510 win Aug 2, 2021 None 19.99 None
# 51 200 5 The_Evil_Within 268050 win Oct 13, 2014 None 19.99 None
# 51 200 6 Rustler 844260 win Aug 31, 2021 None 24.99 None
# 51 200 7 Puzzle_Pirates 99910 win,mac Aug 31, 2011 None Free to Play None
# 51 200 8 Doctor_Who_The_Edge_of_Reality 1444920 win Oct 13, 2021 None 24.99 None
# 51 200 9 Voidigo 1304680 win Feb 25, 2021 None 14.99 None
# 51 200 10 Suzerain 1207650 win,mac Dec 4, 2020 None 14.99 None
# 51 200 11 Amnesia_The_Dark_Descent 57300 win,mac,linux Sep 8, 2010 None 19.99 None
# 51 200 12 Unity_of_Command_II 809230 win,mac Nov 12, 2019 None 29.99 None
# 51 200 13 Motorsport_Manager 415200 win,mac,linux Nov 9, 2016 None 34.99 None
# 51 200 14 STALKER_Call_of_Pripyat 41700 win Feb 11, 2010 None 19.99 None
# 51 200 15 Fun_with_Ragdolls_The_Game 1142500 win,mac Sep 17, 2019 None 14.99 None
# 51 200 16 Saints_Row_The_Third 55230 win,linux Nov 14, 2011 None 9.99 None
# 51 200 17 Clicker_Heroes 363970 win,mac May 13, 2015 None Free to Play None
# 51 200 18 RollerCoaster_Tycoon_Classic 683900 win,mac Sep 28, 2017 None 19.99 None
# 51 200 19 古剑奇谭三Gujian3 994280 win Dec 14, 2018 None 29.99 None
# 51 200 20 LEGO_MARVELs_Avengers 405310 win Jan 26, 2016 None 19.99 None
# 51 200 21 cyubeVR 619500 win,vr_required Jan 26, 2018 None 19.99 None
# 51 200 22 Rain_World 312520 win Mar 28, 2017 None 19.99 None
# 51 200 23 The_Greatest_Penguin_Heist_of_All_Time 1451480 win,mac,linux Jul 2, 2021 None 14.99 None
# 51 200 24 Garden_Story 1062140 win,mac Aug 11, 2021 None 19.99 None
# 51 200 25 Yakuza_3_Remastered 1088710 win Jan 28, 2021 None 19.99 None
# Retrieved listings from search results page 51.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_51_20211019_145406.parquet.gzip...done.
# Exported search results for page 51.
#
# Completed page 51 [collected 1250-1275 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 52...Pausing for 3.13 sec...done.
# 52 200 1 Armored_Warfare 443110 win Nov 17, 2017 None Free To Play None
# 52 200 2 Curse_of_the_Dead_Gods 1123770 win Feb 23, 2021 None 19.99 None
# 52 200 3 Behind_the_Frame_The_Finest_Scenery 1634150 win,mac Aug 25, 2021 None 9.99 None
# 52 200 4 Ni_no_Kuni_Wrath_of_the_White_Witch_Remastered 798460 win Sep 19, 2019 None 49.99 None
# 52 200 5 Chronicon 375480 win,linux Aug 21, 2020 None 13.99 None
# 52 200 6 Zombie_Army_Trilogy 301640 win Mar 6, 2015 None 44.99 None
# 52 200 7 Hasbros_BATTLESHIP 893050 win Aug 14, 2018 None 9.99 None
# 52 200 8 DEAD_OR_ALIVE_6 838380 win Feb 28, 2019 None 59.99 None
# 52 200 9 Pumpkin_Jack 1186640 win Oct 23, 2020 None 29.99 None
# 52 200 10 Danganronpa_Another_Episode_Ultra_Despair_Girls 555950 win Jun 27, 2017 None 29.99 None
# 52 200 11 RUNNING_WITH_RIFLES 270150 win,mac,linux Apr 2, 2015 None 14.99 None
# 52 200 12 Vigil_The_Longest_Night 720560 win Oct 14, 2020 None 21.99 None
# 52 200 13 Mist_Legacy 1259440 win Oct 5, 2021 None Free to Play None
# 52 200 14 The_Walking_Dead 207610 win,mac Apr 24, 2012 None 14.99 None
# 52 200 15 Sleeping_Dogs_Definitive_Edition 307690 win,mac Oct 8, 2014 None 19.99 None
# 52 200 16 Airport_CEO 673610 win,mac Mar 4, 2021 None 24.99 None
# 52 200 17 Lost_Ruins 1306630 win,mac,linux May 13, 2021 None 19.99 None
# 52 200 18 Element_TD_2__Tower_Defense 1018830 win Apr 2, 2021 None 14.99 None
# 52 200 19 First_Class_Trouble 953880 win Apr 8, 2021 None 14.99 None
# 52 200 20 Mindustry 1127400 win,mac,linux Sep 26, 2019 None 5.99 None
# 52 200 21 The_Alien_Cube 1099220 win Oct 14, 2021 -10% 19.99 17.99
# 52 200 22 INDUSTRIA 1172650 win Sep 30, 2021 None 19.99 None
# 52 200 23 Farm_Manager_2021 1123830 win May 6, 2021 None 19.99 None
# 52 200 24 Goat_Simulator 265930 win,mac,linux Apr 1, 2014 None 9.99 None
# 52 200 25 Kindergarten_2 1067850 win,mac,linux Jul 29, 2019 None 14.99 None
# Retrieved listings from search results page 52.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_52_20211019_145410.parquet.gzip...done.
# Exported search results for page 52.
#
# Completed page 52 [collected 1275-1300 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 53...Pausing for 4.11 sec...done.
# 53 200 1 Shieldwall 1216320 win Mar 23, 2020 None 13.99 None
# 53 200 2 Hot_Lava 382560 win Sep 19, 2019 None 19.99 None
# 53 200 3 Bad_North_Jotunn_Edition 688420 win,mac Nov 16, 2018 None 14.99 None
# 53 200 4 Rise_of_Nations_Extended_Edition 287450 win Jun 12, 2014 None 19.99 None
# 53 200 5 The_Legend_of_Heroes_Trails_of_Cold_Steel 538680 win Aug 2, 2017 None 39.99 None
# 53 200 6 Changed 814540 win Apr 4, 2018 None 5.99 None
# 53 200 7 Warhammer_40000_Dawn_of_War_III 285190 win,mac,linux Apr 27, 2017 None 39.99 None
# 53 200 8 Deaths_Gambit_Afterlife 356650 win Aug 13, 2018 None 19.99 None
# 53 200 9 Tales_of_Vesperia_Definitive_Edition 738540 win Jan 10, 2019 None 49.99 None
# 53 200 10 The_Universim 352720 win,mac,linux Aug 2018 None 29.99 None
# 53 200 11 Lost_Castle__失落城堡 434650 win,mac Aug 31, 2016 None 9.99 None
# 53 200 12 SpyParty 329070 win Apr 12, 2018 None 24.99 None
# 53 200 13 Monster_Sanctuary 814370 win,mac,linux Dec 8, 2020 None 19.99 None
# 53 200 14 The_Legend_of_Heroes_Trails_of_Cold_Steel_II 748490 win Feb 14, 2018 None 39.99 None
# 53 200 15 Order_of_Battle_World_War_II 312450 win,mac Apr 30, 2015 None Free to Play None
# 53 200 16 Saints_Row_The_Third_Remastered 978300 win May 21, 2021 None 39.99 None
# 53 200 17 Leaf_Blower_Revolution__Idle_Game 1468260 win Dec 4, 2020 None Free To Play None
# 53 200 18 STEINSGATE 412830 win Sep 8, 2016 None 29.99 None
# 53 200 19 League_of_Maidens 557180 win Feb 25, 2021 None Free To Play None
# 53 200 20 Command__Conquer_3_Tiberium_Wars 24790 win Nov 13, 2009 None 14.99 None
# 53 200 21 Resident_Evil_6 221040 win Mar 21, 2013 None 29.99 None
# 53 200 22 Love_Esquire__RPGDating_SimVisual_Novel 849740 win,mac,linux Oct 8, 2019 -25% 24.99 18.74
# 53 200 23 Car_Mechanic_Simulator_VR 1088770 win,vr_required Jun 8, 2021 -20% 19.99 15.99
# 53 200 24 Shakes_and_Fidget 438040 win,mac Feb 24, 2016 None Free to Play None
# 53 200 25 SUPERHOT 322500 win,mac,linux Feb 25, 2016 None 24.99 None
# Retrieved listings from search results page 53.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_53_20211019_145415.parquet.gzip...done.
# Exported search results for page 53.
#
# Completed page 53 [collected 1300-1325 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 54...Pausing for 3.13 sec...done.
# 54 200 1 SAS_Zombie_Assault_4 678800 win,mac Oct 16, 2017 None Free To Play None
# 54 200 2 Mabinogi 212200 win Dec 6, 2012 None Free to Play None
# 54 200 3 Dungeons_3 493900 win,mac,linux Oct 13, 2017 None 29.99 None
# 54 200 4 Session_Skateboarding_Sim_Game 861650 win Sep 17, 2019 None 19.99 None
# 54 200 5 Mirrors_Edge 17410 win Jan 14, 2009 None 19.99 None
# 54 200 6 Hellblade_Senuas_Sacrifice 414340 win Aug 7, 2017 None 29.99 None
# 54 200 7 Animation_Throwdown_The_Quest_for_Cards 591960 win,mac May 5, 2017 None Free to Play None
# 54 200 8 Beyond_The_Wire 1058650 win Oct 21, 2020 None 34.99 None
# 54 200 9 WORLD_OF_FINAL_FANTASY 552700 win Nov 21, 2017 None 24.99 None
# 54 200 10 Last_Oasis 903950 win Mar 26, 2020 None 29.99 None
# 54 200 11 Champions_Online 9880 win Jun 14, 2011 None Free to Play None
# 54 200 12 The_Bus 491540 win Mar 25, 2021 None 24.99 None
# 54 200 13 Manifold_Garden 473950 win Oct 20, 2020 None 19.99 None
# 54 200 14 SpellForce_3_Fallen_God 1154040 win Nov 3, 2020 None 24.99 None
# 54 200 15 Othercide 798490 win Jul 27, 2020 None 29.99 None
# 54 200 16 Amazing_Frog 332570 win,mac,linux Nov 21, 2014 None 15.99 None
# 54 200 17 RIFT 39120 win Mar 1, 2011 None Free to Play None
# 54 200 18 The_Blackout_Club 599080 win Jul 29, 2019 None 29.99 None
# 54 200 19 Spiral_Knights 99900 win,mac Jun 14, 2011 None Free to Play None
# 54 200 20 Blood_of_Steel 567630 win Oct 20, 2020 None Free To Play None
# 54 200 21 GUILTY_GEAR_Xrd_REVELATOR 520440 win Dec 14, 2016 None 29.99 None
# 54 200 22 Tomb_Raider 203160 win,mac,linux Mar 4, 2013 None 14.99 None
# 54 200 23 Opus_Magnum 558990 win,mac,linux Dec 7, 2017 None 19.99 None
# 54 200 24 Ironsight 783770 win Jun 19, 2019 None Free To Play None
# 54 200 25 Axis__Allies_1942_Online 898920 win,mac,linux Jul 31, 2019 None 19.99 None
# Retrieved listings from search results page 54.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_54_20211019_145419.parquet.gzip...done.
# Exported search results for page 54.
#
# Completed page 54 [collected 1325-1350 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 55...Pausing for 2.83 sec...done.
# 55 200 1 Airships_Conquer_the_Skies 342560 win,mac,linux Aug 16, 2018 None 24.99 None
# 55 200 2 Valkyria_Chronicles_4_Complete_Edition 790820 win Sep 25, 2018 None 49.99 None
# 55 200 3 HD_Poker_Texas_Holdem 797430 win,mac Sep 14, 2018 None Free To Play None
# 55 200 4 SpellForce_3 311290 win Dec 7, 2017 None 49.99 None
# 55 200 5 VA11_HallA_Cyberpunk_Bartender_Action 447530 win,mac,linux Jun 21, 2016 None 14.99 None
# 55 200 6 XCOM_Chimera_Squad 882100 win Apr 23, 2020 None 19.99 None
# 55 200 7 Until_You_Fall 858260 win,vr_required Oct 27, 2020 None 24.99 None
# 55 200 8 Total_Tank_Simulator 674500 win May 20, 2020 None 19.99 None
# 55 200 9 Injustice_Gods_Among_Us_Ultimate_Edition 242700 win Nov 12, 2013 None 19.99 None
# 55 200 10 Hello_Neighbor 521890 win Dec 8, 2017 None 29.99 None
# 55 200 11 Blood_Bowl_2 236690 win,mac Sep 5, 2017 None 19.99 None
# 55 200 12 GRIS 683320 win,mac Dec 13, 2018 None 16.99 None
# 55 200 13 Rick_and_Morty_Virtual_Rickality 469610 win,vr_required Apr 20, 2017 None 29.99 None
# 55 200 14 Our_Life_Beginnings__Always 1129190 win,linux Nov 16, 2020 None Free To Play None
# 55 200 15 Clustertruck 397950 win,mac,linux Sep 27, 2016 None 14.99 None
# 55 200 16 Bot_Wars 1672140 win Sep 10, 2021 None 14.99 None
# 55 200 17 Emily_is_Away_3 978460 win,mac Apr 16, 2021 None 9.99 None
# 55 200 18 Turnip_Boy_Commits_Tax_Evasion 1205450 win,mac,linux Apr 22, 2021 None 14.99 None
# 55 200 19 Hedon_Bloodrite 1072150 win,linux May 16, 2019 None 16.99 None
# 55 200 20 I_Expect_You_To_Die 587430 win,vr_required Apr 25, 2017 None 24.99 None
# 55 200 21 Five_Nights_at_Freddys_2 332800 win Nov 10, 2014 None 7.99 None
# 55 200 22 The_Battle_of_Polytopia 874390 win,mac,linux Aug 4, 2020 None 14.99 None
# 55 200 23 Farmers_Life 1137750 win Aug 5, 2021 None 14.99 None
# 55 200 24 Darksiders_III 606280 win Nov 27, 2018 None 59.99 None
# 55 200 25 STRIDE__Multiplayer_Pass 1292040 win,vr_required Sep 4, 2020 None 19.99 None
# Retrieved listings from search results page 55.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_55_20211019_145422.parquet.gzip...done.
# Exported search results for page 55.
#
# Completed page 55 [collected 1350-1375 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 56...Pausing for 3.53 sec...done.
# 56 200 1 PokerStars_VR 886250 win,vr_required Nov 8, 2018 None Free To Play None
# 56 200 2 NEKOPARA_Vol_1 333600 win Dec 29, 2014 None 9.99 None
# 56 200 3 Ys_VIII_Lacrimosa_of_DANA 579180 win Apr 16, 2018 None 59.99 None
# 56 200 4 LEGO_Star_Wars_III__The_Clone_Wars 32510 win Mar 22, 2011 None 19.99 None
# 56 200 5 Marble_World 1491340 win May 7, 2021 None 11.99 None
# 56 200 6 Cloudpunk 746850 win Apr 23, 2020 None 19.99 None
# 56 200 7 Overcrowd_A_Commute_Em_Up 726110 win Oct 6, 2020 -50% 19.99 9.99
# 56 200 8 DARIUSBURST_Chronicle_Saviours 377870 win Dec 3, 2015 -70% 49.99 14.99
# 56 200 9 Will_To_Live_Online 707010 win Apr 5, 2018 None Free to Play None
# 56 200 10 NARUTO_Ultimate_Ninja_STORM 495140 win Aug 25, 2017 None 19.99 None
# 56 200 11 Mighty_Party 575720 win Mar 30, 2017 None Free None
# 56 200 12 Doom_3_BFG_Edition 208200 win Oct 15, 2012 None 19.99 None
# 56 200 13 Torchlight 41500 win,mac Oct 27, 2009 None 14.99 None
# 56 200 14 Overgrowth 25000 win,mac,linux Oct 16, 2017 None 29.99 None
# 56 200 15 Carcassonne__Tiles__Tactics 598810 win Nov 29, 2017 None 9.99 None
# 56 200 16 Dungeon_Defenders_Awakened 1101190 win May 28, 2020 None 29.99 None
# 56 200 17 Tom_Clancys_Splinter_Cell_Blacklist 235600 win Aug 20, 2013 None 29.99 None
# 56 200 18 FINAL_FANTASY_VIII__REMASTERED 1026680 win Sep 3, 2019 None 19.99 None
# 56 200 19 Haven 983970 win Dec 3, 2020 None 24.99 None
# 56 200 20 INSIDE 304430 win,mac Jul 7, 2016 None 19.99 None
# 56 200 21 Youtubers_Life 428690 win,mac,linux Feb 2, 2017 None 24.99 None
# 56 200 22 Later_Alligator 966320 win,mac,linux Sep 18, 2019 None 17.99 None
# 56 200 23 Cine_Tracer 904960 win,mac Sep 28, 2018 None 89.99 None
# 56 200 24 Ashes_of_the_Singularity_Escalation 507490 win Nov 10, 2016 None 29.99 None
# 56 200 25 Dungeon_Town 959880 win Sep 24, 2021 None 19.99 None
# Retrieved listings from search results page 56.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_56_20211019_145426.parquet.gzip...done.
# Exported search results for page 56.
#
# Completed page 56 [collected 1375-1400 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 57...Pausing for 3.35 sec...done.
# 57 200 1 Osiris_New_Dawn 402710 win Sep 28, 2016 None 24.99 None
# 57 200 2 Combat_Mission_Shock_Force_2 1369370 win Aug 31, 2020 None 59.99 None
# 57 200 3 No_More_Heroes 1420290 win Jun 9, 2021 None 19.99 None
# 57 200 4 We_Need_To_Go_Deeper 307110 win,linux Aug 1, 2019 None 15.99 None
# 57 200 5 ONE_PIECE_World_Seeker 755500 win Mar 14, 2019 None 59.99 None
# 57 200 6 Puyo_Puyo_Tetris_2 1259790 win Mar 23, 2021 None 29.99 None
# 57 200 7 To_the_Moon 206440 win,mac,linux Sep 7, 2012 None 9.99 None
# 57 200 8 Sniper_Ghost_Warrior_Contracts 973580 win Nov 22, 2019 None 29.99 None
# 57 200 9 Overcooked 448510 win Aug 3, 2016 None 16.99 None
# 57 200 10 Concordia_Digital_Edition 1450330 win,mac Sep 28, 2021 None 18.99 None
# 57 200 11 Fell_Seal_Arbiters_Mark 699170 win,mac,linux Apr 30, 2019 None 29.99 None
# 57 200 12 FateEXTELLA_LINK 622220 win Mar 19, 2019 None 49.99 None
# 57 200 13 Exanima 362490 win Apr 29, 2015 None 14.99 None
# 57 200 14 Monster_Energy_Supercross__The_Official_Videogame_4 1304340 win Mar 11, 2021 None 49.99 None
# 57 200 15 Banners_of_Ruin 1075740 win Jul 29, 2021 None 19.99 None
# 57 200 16 Atelier_Sophie_The_Alchemist_of_the_Mysterious_Book_DX 1502970 win Apr 21, 2021 None 39.99 None
# 57 200 17 SimAirport 598330 win,mac,linux Feb 28, 2020 None 24.99 None
# 57 200 18 Dungeon_of_the_ENDLESS 249050 win,mac Oct 27, 2014 None 11.99 None
# 57 200 19 Astria_Ascending 1121780 win Sep 30, 2021 None 34.99 None
# 57 200 20 Murder_House 1064460 win Oct 22, 2020 None 11.99 None
# 57 200 21 NARUTO_SHIPPUDEN_Ultimate_Ninja_STORM_3_Full_Burst_HD 234670 win Oct 24, 2013 None 19.99 None
# 57 200 22 Kynseed 758870 win Nov 8, 2018 None 12.99 None
# 57 200 23 NARUTO_SHIPPUDEN_Ultimate_Ninja_STORM_2 543870 win Aug 25, 2017 None 19.99 None
# 57 200 24 Dishonored_Death_of_the_Outsider 614570 win Sep 14, 2017 None 29.99 None
# 57 200 25 Iratus_Lord_of_the_Dead 807120 win,mac,linux Apr 23, 2020 None 29.99 None
# Retrieved listings from search results page 57.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_57_20211019_145430.parquet.gzip...done.
# Exported search results for page 57.
#
# Completed page 57 [collected 1400-1425 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 58...Pausing for 3.36 sec...done.
# 58 200 1 Going_Under 1154810 win Sep 24, 2020 None 19.99 None
# 58 200 2 El_Shaddai_ASCENSION_OF_THE_METATRON 1581040 win Sep 1, 2021 None 29.99 None
# 58 200 3 Pony_Island 405640 win,mac,linux Jan 4, 2016 None 4.99 None
# 58 200 4 Salt_and_Sanctuary 283640 win,mac,linux May 17, 2016 None 17.99 None
# 58 200 5 Wrestling_Empire 1620340 win Jul 2, 2021 None 19.99 None
# 58 200 6 POLYGON_Online_Shooter 1241100 win Mar 6, 2020 None Free to Play None
# 58 200 7 DYNASTY_WARRIORS_8_Xtreme_Legends_Complete_Edition 278080 win May 13, 2014 None 49.99 None
# 58 200 8 Transformice 335240 win,mac,linux Jan 30, 2015 None Free to Play None
# 58 200 9 STEINSGATE_0 825630 win May 8, 2018 None 34.99 None
# 58 200 10 The_Legend_of_Heroes_Trails_in_the_Sky 251150 win Jul 29, 2014 None 19.99 None
# 58 200 11 Dead_Effect_2_VR 646200 win,vr_required Oct 3, 2017 -70% 24.99 7.49
# 58 200 12 The_Life_and_Suffering_of_Sir_Brante 1272160 win Mar 4, 2021 None 19.99 None
# 58 200 13 Rise_to_Ruins 328080 win,mac,linux Oct 14, 2019 -50% 14.99 7.49
# 58 200 14 MASS_Builder 956680 win Sep 13, 2019 None 24.99 None
# 58 200 15 Idling_to_Rule_the_Gods 466170 win,mac,linux May 27, 2016 None Free To Play None
# 58 200 16 Subsistence 418030 win Oct 25, 2016 None 13.99 None
# 58 200 17 Moon_Hunters 320040 win,mac,linux Mar 10, 2016 -90% 14.99 1.49
# 58 200 18 Tyranny 362960 win,mac,linux Nov 10, 2016 None 29.99 None
# 58 200 19 Sniper_Elite_3 238090 win Jun 27, 2014 None 29.99 None
# 58 200 20 A_Short_Hike 1055540 win,mac,linux Jul 30, 2019 None 7.99 None
# 58 200 21 Before_We_Leave 1073910 win,mac May 13, 2021 None 19.99 None
# 58 200 22 Agatha_Christie__Hercule_Poirot_The_First_Cases 1573720 win,mac Sep 27, 2021 None 24.99 None
# 58 200 23 Metro_Sim_Hustle 882250 win Jul 24, 2021 None 19.99 None
# 58 200 24 Observer_System_Redux 1386900 win Nov 10, 2020 None 29.99 None
# 58 200 25 Pogostuck_Rage_With_Your_Friends 688130 win Feb 28, 2019 None 6.99 None
# Retrieved listings from search results page 58.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_58_20211019_145434.parquet.gzip...done.
# Exported search results for page 58.
#
# Completed page 58 [collected 1425-1450 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 59...Pausing for 3.99 sec...done.
# 59 200 1 Train_Life_A_Railway_Simulator 1330660 win Aug 31, 2021 None 14.99 None
# 59 200 2 SENRAN_KAGURA_ESTIVAL_VERSUS 502800 win Mar 17, 2017 None 29.99 None
# 59 200 3 Cooking_Companions 1263230 win Oct 7, 2021 None 14.99 None
# 59 200 4 Power__Revolution_2021_Edition 1683320 win,mac Aug 4, 2021 None 49.99 None
# 59 200 5 DRAMAtical_Murder 1481080 win Apr 6, 2021 None 19.99 None
# 59 200 6 Castlevania_Lords_of_Shadow_2 239250 win Feb 25, 2014 None 39.99 None
# 59 200 7 killer7 868520 win Nov 15, 2018 None 19.99 None
# 59 200 8 Voice_of_Cards_The_Isle_Dragon_Roars 1113570 win Oct 28, 2021 None 29.99 None
# 59 200 9 Bit_Heroes 666860 win Dec 13, 2017 None Free to Play None
# 59 200 10 Dominion 1131620 win Oct 7, 2021 None Free To Play None
# 59 200 11 Ni_no_Kuni_II_Revenant_Kingdom 589360 win Mar 23, 2018 None 59.99 None
# 59 200 12 Per_Aspera 803050 win Dec 3, 2020 None 29.99 None
# 59 200 13 Death_and_Taxes 1166290 win,mac,linux Feb 20, 2020 None 12.99 None
# 59 200 14 CounterStrike_Nexon_Studio 273110 win Oct 7, 2014 None Free To Play None
# 59 200 15 Intravenous 1486630 win Jul 26, 2021 None 12.99 None
# 59 200 16 The_Escapists 298630 win,mac,linux Feb 13, 2015 None 17.99 None
# 59 200 17 Supreme_Commander_2 40100 win Mar 1, 2010 None 12.99 None
# 59 200 18 Eleven_Table_Tennis 488310 win,vr_required Sep 22, 2016 None 19.99 None
# 59 200 19 Wartune_Reborn 1469160 win Feb 26, 2021 None Free To Play None
# 59 200 20 Circle_Empires 834740 win,mac,linux Aug 8, 2018 -66% 7.99 2.71
# 59 200 21 Stronghold_Warlords 907650 win Mar 9, 2021 None 39.99 None
# 59 200 22 STALKER_2_Heart_of_Chernobyl 1643320 win 28 April 2022 None 59.99 None
# 59 200 23 Sam__Max_Save_the_World 1440440 win Dec 2, 2020 None 19.99 None
# 59 200 24 Buddy_Simulator_1984 1269950 win Feb 18, 2021 None 9.99 None
# 59 200 25 60_Seconds_Reatomized 1012880 win,mac Jul 25, 2019 None 9.99 None
# Retrieved listings from search results page 59.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_59_20211019_145439.parquet.gzip...done.
# Exported search results for page 59.
#
# Completed page 59 [collected 1450-1475 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 60...Pausing for 2.86 sec...done.
# 60 200 1 War_for_the_Overworld 230190 win,mac,linux Apr 2, 2015 None 29.99 None
# 60 200 2 Supreme_Commander_Forged_Alliance 9420 win Sep 28, 2011 None 12.99 None
# 60 200 3 Batman__The_Telltale_Series 498240 win Aug 2, 2016 None 14.99 None
# 60 200 4 Resident_Evil 304240 win Jan 19, 2015 None 19.99 None
# 60 200 5 FINAL_FANTASY_V 1173810 win 2021 None None None
# 60 200 6 Black_Skylands 1143810 win Jul 9, 2021 None 19.99 None
# 60 200 7 FINAL_FANTASY_VI 1173820 win 2021 None None None
# 60 200 8 DIRT_5 1038250 win Nov 5, 2020 None 59.99 None
# 60 200 9 Prodeus 964800 win,mac Nov 9, 2020 None 24.99 None
# 60 200 10 Craft_The_World 248390 win,mac Nov 24, 2014 None 18.99 None
# 60 200 11 Death_Road_to_Canada 252610 win,mac,linux Jul 21, 2016 None 14.99 None
# 60 200 12 Wurm_Online 1179680 win,mac,linux Jul 24, 2020 None Free To Play None
# 60 200 13 NBA_2K20 1089350 win Sep 5, 2019 None 59.99 None
# 60 200 14 Locked_Up 1258590 win Apr 23, 2020 None 12.99 None
# 60 200 15 OneShot 420530 win,mac,linux Dec 2016 None 9.99 None
# 60 200 16 Trackmania_United_Forever 7200 win Apr 16, 2008 None 29.99 None
# 60 200 17 WARRIORS_OROCHI_4_Ultimate__無双OROCHI３_Ultimate 831560 win Oct 15, 2018 None 59.99 None
# 60 200 18 Need_for_Speed 1262540 win Jun 4, 2020 None 29.99 None
# 60 200 19 The_Rewinder 1161170 win,mac Sep 9, 2021 None 14.99 None
# 60 200 20 The_Thrill_of_the_Fight__VR_Boxing 494150 win,vr_required Oct 24, 2019 None 9.99 None
# 60 200 21 Sudden_Strike_4 373930 win,mac,linux Aug 11, 2017 None 19.99 None
# 60 200 22 COMPOUND 615120 win,vr_required May 15, 2018 None 19.99 None
# 60 200 23 Epic_Fantasy_Battle_Simulator 1724440 win Aug 30, 2021 None 9.99 None
# 60 200 24 MuvLuv_Alternative_マブラヴ_オルタネイティヴ 802890 win Feb 28, 2018 None 39.99 None
# 60 200 25 嗜血印_Bloody_Spell 992300 win Jan 15, 2019 None 24.99 None
# Retrieved listings from search results page 60.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_60_20211019_145443.parquet.gzip...done.
# Exported search results for page 60.
#
# Completed page 60 [collected 1475-1500 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 61...Pausing for 4.19 sec...done.
# 61 200 1 TOEM 1307580 win,mac Sep 17, 2021 None 19.99 None
# 61 200 2 Castlevania_Anniversary_Collection 1018010 win May 16, 2019 None 19.99 None
# 61 200 3 Wayward 379210 win,mac,linux Apr 22, 2016 -25% 7.99 5.99
# 61 200 4 Broforce 274190 win,mac,linux Oct 15, 2015 None 14.99 None
# 61 200 5 Katamari_Damacy_REROLL 848350 win Dec 6, 2018 None 29.99 None
# 61 200 6 CosmicBreak_Universal 1140620 win Apr 6, 2021 None Free To Play None
# 61 200 7 911_Operator 503560 win,mac Feb 24, 2017 None 14.99 None
# 61 200 8 Ostriv 773790 win Mar 19, 2020 None 24.99 None
# 61 200 9 The_Talos_Principle 257510 win,mac,linux Dec 11, 2014 None 39.99 None
# 61 200 10 Post_Void 1285670 win Aug 6, 2020 None 2.99 None
# 61 200 11 A_Game_of_Thrones_The_Board_Game__Digital_Edition 1075190 win,mac Oct 6, 2020 None 19.99 None
# 61 200 12 Dicey_Dungeons 861540 win,mac,linux Aug 13, 2019 None 14.99 None
# 61 200 13 Wolfenstein_Youngblood 1056960 win Jul 25, 2019 None 19.99 None
# 61 200 14 Call_of_Cthulhu 399810 win Oct 29, 2018 None 19.99 None
# 61 200 15 Absolver 473690 win Aug 29, 2017 None 29.99 None
# 61 200 16 MuvLuv_マブラヴ 802880 win Feb 28, 2018 None 29.99 None
# 61 200 17 Sakura_Hime 1732740 win Oct 15, 2021 -20% 3.99 3.19
# 61 200 18 Terminator_Resistance 954740 win Nov 14, 2019 None 39.99 None
# 61 200 19 Malum 1648610 win Sep 2, 2021 None 4.99 None
# 61 200 20 DmC_Devil_May_Cry 220440 win Jan 24, 2013 None 29.99 None
# 61 200 21 ULTIMATE_MARVEL_VS_CAPCOM_3 357190 win Mar 6, 2017 None 24.99 None
# 61 200 22 Scavengers 1183940 win May 1, 2021 None Free to Play None
# 61 200 23 Eldest_Souls 1108590 win Jul 29, 2021 None 19.99 None
# 61 200 24 Star_Conflict 212070 win,mac,linux Feb 27, 2013 None Free to Play None
# 61 200 25 Dead_Rising_3_Apocalypse_Edition 265550 win Sep 5, 2014 None 29.99 None
# Retrieved listings from search results page 61.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_61_20211019_145447.parquet.gzip...done.
# Exported search results for page 61.
#
# Completed page 61 [collected 1500-1525 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 62...Pausing for 3.18 sec...done.
# 62 200 1 RollerCoaster_Tycoon_Deluxe 285310 win May 21, 2014 None 5.99 None
# 62 200 2 Welcome_to_the_Game_II 720250 win,mac Apr 3, 2018 None 9.99 None
# 62 200 3 Saints_Row_2 9480 win,linux Jan 7, 2009 None 9.99 None
# 62 200 4 Five_Nights_at_Freddys_Sister_Location 506610 win Oct 7, 2016 None 7.99 None
# 62 200 5 Age_of_Empires_III_2007 105450 win Jan 5, 2012 None 39.99 None
# 62 200 6 Scarlet_Hollow 1609230 win,mac,linux Jun 11, 2021 None 19.99 None
# 62 200 7 Hand_Simulator 657200 win,vr_supported Jul 18, 2017 None 1.99 None
# 62 200 8 The_Room_VR_A_Dark_Matter 1104380 win,vr_required Mar 26, 2020 None 29.99 None
# 62 200 9 Five_Nights_at_Freddys_4 388090 win Jul 23, 2015 None 7.99 None
# 62 200 10 realMyst_Masterpiece_Edition 244430 win,mac Feb 5, 2014 None 17.99 None
# 62 200 11 Batman_The_Enemy_Within__The_Telltale_Series 675260 win Aug 8, 2017 None 14.99 None
# 62 200 12 Life_is_Strange_Before_the_Storm 554620 win,mac,linux Aug 31, 2017 None 16.99 None
# 62 200 13 No_Place_Like_Home 1472660 win Dec 23, 2020 None 9.99 None
# 62 200 14 Anno_1404__History_Edition 1281630 win Jun 25, 2020 None 14.99 None
# 62 200 15 Aura_Kingdom 268420 win Jul 2014 None Free to Play None
# 62 200 16 30XX 1029210 win Feb 17, 2021 None 19.99 None
# 62 200 17 Ziggurat_2 1159560 win,mac,linux Oct 22, 2020 None 24.99 None
# 62 200 18 Mist_Survival 914620 win Aug 14, 2018 None 10.99 None
# 62 200 19 Pathologic_2 505230 win May 23, 2019 None 34.99 None
# 62 200 20 HalfLife_2_Episode_One 380 win,mac,linux Oct 10, 2007 None 7.99 None
# 62 200 21 Crypt_of_the_NecroDancer 247080 win,mac,linux Apr 23, 2015 None 14.99 None
# 62 200 22 Spellbreak 1399780 win Dec 15, 2020 None Free To Play None
# 62 200 23 Fast_and_Low 1097620 win,vr_supported Jun 20, 2019 None 20.99 None
# 62 200 24 Magicka_2 238370 win,mac,linux May 26, 2015 None 14.99 None
# 62 200 25 Battlestar_Galactica_Deadlock 544610 win Aug 31, 2017 None 39.99 None
# Retrieved listings from search results page 62.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_62_20211019_145451.parquet.gzip...done.
# Exported search results for page 62.
#
# Completed page 62 [collected 1525-1550 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 63...Pausing for 2.83 sec...done.
# 63 200 1 Nioh_Complete_Edition__仁王_Complete_Edition 485510 win Nov 7, 2017 None 49.99 None
# 63 200 2 The_Beast_Inside 792300 win Oct 17, 2019 None 24.99 None
# 63 200 3 Wrench 936720 win,vr_supported Dec 19, 2018 None 29.99 None
# 63 200 4 Deadliest_Catch_The_Game 838630 win Apr 14, 2020 -80% 19.99 3.99
# 63 200 5 Nexomon_Extinction 1196630 win,mac Aug 28, 2020 None 19.99 None
# 63 200 6 LEGO_The_Hobbit 285160 win Apr 8, 2014 None 19.99 None
# 63 200 7 Blade_Assault 1367300 win Jun 7, 2021 None 17.99 None
# 63 200 8 Lumione 1339860 win Oct 12, 2021 -10% 11.99 10.79
# 63 200 9 Ashen 649950 win Dec 9, 2019 None 39.99 None
# 63 200 10 Secret_World_Legends 215280 win Jul 31, 2017 None Free To Play None
# 63 200 11 The_Typing_of_The_Dead_Overkill 246580 win Oct 29, 2013 None 19.99 None
# 63 200 12 The_Four_Kings_Casino_and_Slots 260430 win,mac Jun 1, 2015 None Free to Play None
# 63 200 13 OMSI_2_Steam_Edition 252530 win Dec 11, 2013 None 29.99 None
# 63 200 14 SNKRX 915310 win May 17, 2021 None 2.99 None
# 63 200 15 Hood_Outlaws__Legends 927350 win May 10, 2021 None 19.99 None
# 63 200 16 Mind_Scanners 1389550 win,mac May 20, 2021 None 16.99 None
# 63 200 17 DARK_SOULS_II 236430 win Apr 25, 2014 None 39.99 None
# 63 200 18 MotoGP21 1447000 win Apr 22, 2021 None 49.99 None
# 63 200 19 Command_Modern_Operations 1076160 win Nov 14, 2019 None 79.99 None
# 63 200 20 The_Artful_Escape 1122680 win Sep 9, 2021 None 19.99 None
# 63 200 21 Stronghold_Crusader_2 232890 win Sep 22, 2014 None 39.99 None
# 63 200 22 Far_Cry_2_Fortunes_Edition 19900 win Oct 22, 2008 None 9.99 None
# 63 200 23 HalfLife_2_Episode_Two 420 win,mac,linux Oct 10, 2007 None 7.99 None
# 63 200 24 Disciples_Liberation 1287840 win Oct 21, 2021 -10% 39.99 35.99
# 63 200 25 SPOOKWARE 1574250 win Aug 26, 2021 None 12.99 None
# Retrieved listings from search results page 63.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_63_20211019_145455.parquet.gzip...done.
# Exported search results for page 63.
#
# Completed page 63 [collected 1550-1575 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 64...Pausing for 3.71 sec...done.
# 64 200 1 Dream_Engines_Nomad_Cities__A_survival_city_builder_with_flying_cities 1076750 win Jul 14, 2021 None 29.99 None
# 64 200 2 Sphere__Flying_Cities 1273220 win Oct 14, 2021 -15% 17.99 15.29
# 64 200 3 Disgaea_2_PC 495280 win,mac,linux Jan 30, 2017 None 19.99 None
# 64 200 4 Derail_Valley 588030 win,vr_supported Jan 25, 2019 None 19.99 None
# 64 200 5 Poly_Bridge 367450 win,mac,linux Jul 12, 2016 None 9.99 None
# 64 200 6 Interstellar_Rift 363360 win Sep 24, 2020 -50% 19.99 9.99
# 64 200 7 Learn_to_Fly_3 589870 win May 12, 2017 None Free To Play None
# 64 200 8 Orcs_Must_Die_2 201790 win Jul 30, 2012 None 14.99 None
# 64 200 9 Domina 535230 win Apr 3, 2017 None 9.99 None
# 64 200 10 Thronebreaker_The_Witcher_Tales 973760 win Nov 9, 2018 None 19.99 None
# 64 200 11 Serin_Fate 1070860 win Aug 25, 2021 None 19.99 None
# 64 200 12 Ghostbusters_The_Video_Game_Remastered 1449280 win Nov 17, 2020 None 24.99 None
# 64 200 13 SONG_OF_HORROR_COMPLETE_EDITION 1096570 win Oct 31, 2019 None 29.99 None
# 64 200 14 BioShock_2 8850 win Feb 9, 2010 None None None
# 64 200 15 Touhou_Luna_Nights 851100 win Feb 25, 2019 None 17.99 None
# 64 200 16 The_Horus_Heresy_Legions 1031140 win,mac Mar 28, 2019 None Free To Play None
# 64 200 17 The_Drone_Racing_League_Simulator 641780 win,mac Nov 1, 2017 None 9.99 None
# 64 200 18 Tank_Mechanic_Simulator 407130 win,mac Feb 20, 2020 None 19.99 None
# 64 200 19 AWAY_The_Survival_Series 750200 win Sep 28, 2021 None 29.99 None
# 64 200 20 Dream_Daddy_A_Dad_Dating_Simulator 654880 win,mac,linux Jul 20, 2017 None 14.99 None
# 64 200 21 Age_of_Wonders_III 226840 win,mac,linux Mar 31, 2014 None 29.99 None
# 64 200 22 Crusaders_of_the_Lost_Idols 402840 win,mac Oct 13, 2015 None Free to Play None
# 64 200 23 Master_of_Orion 298050 win,mac,linux Aug 25, 2016 None 24.99 None
# 64 200 24 Genesis_Alpha_One_Deluxe_Edition 712190 win Feb 25, 2020 None 29.99 None
# 64 200 25 Might__Magic_Heroes_VII 321960 win Sep 29, 2015 None 29.99 None
# Retrieved listings from search results page 64.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_64_20211019_145459.parquet.gzip...done.
# Exported search results for page 64.
#
# Completed page 64 [collected 1575-1600 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 65...Pausing for 3.98 sec...done.
# 65 200 1 Wolfpack 490920 win Mar 15, 2019 None 34.99 None
# 65 200 2 Vanquish 460810 win May 25, 2017 None 19.99 None
# 65 200 3 Not_For_Broadcast 1147550 win Jan 30, 2020 None 24.99 None
# 65 200 4 Verdun 242860 win,mac,linux Apr 28, 2015 None 19.99 None
# 65 200 5 Sunset_Overdrive 847370 win Nov 16, 2018 None 19.99 None
# 65 200 6 Sniper_Fury 591740 win Jun 13, 2017 None Free to Play None
# 65 200 7 Starmancer 1062000 win,mac,linux Aug 5, 2021 None 19.99 None
# 65 200 8 Port_Royale_4 1024650 win Sep 25, 2020 None 39.99 None
# 65 200 9 RAGE_2 548570 win May 13, 2019 None 39.99 None
# 65 200 10 Spookys_Jump_Scare_Mansion_HD_Renovation 577690 win,mac,vr_supported Mar 1, 2017 None 9.99 None
# 65 200 11 Warbox 1550710 win Mar 22, 2021 None 9.99 None
# 65 200 12 Stick_RPG_2_Directors_Cut 307640 win,mac Jun 16, 2014 None 19.99 None
# 65 200 13 Zombie_Driver_HD 220820 win Oct 17, 2012 -80% 9.99 1.99
# 65 200 14 SHENZHEN_IO 504210 win,mac,linux Nov 17, 2016 None 14.99 None
# 65 200 15 Kings_Quest_Collection 10100 win Jul 23, 2009 -33% 19.99 13.39
# 65 200 16 FATE 246840 win Dec 12, 2013 None 7.99 None
# 65 200 17 LIGHTNING_RETURNS_FINAL_FANTASY_XIII 345350 win Dec 10, 2015 None 19.99 None
# 65 200 18 Niche__a_genetics_survival_game 440650 win,mac,linux Sep 21, 2017 -50% 17.99 8.99
# 65 200 19 Ancestors_Legacy 620590 win May 22, 2018 None 34.99 None
# 65 200 20 STAR_WARS_Republic_Commando 6000 win Jul 8, 2009 None 9.99 None
# 65 200 21 Scribblenauts_Unlimited 218680 win Nov 19, 2012 None 19.99 None
# 65 200 22 Pawnbarian 1142080 win,mac,linux Sep 24, 2021 None 9.99 None
# 65 200 23 Here_Comes_Niko 925950 win Aug 3, 2021 None 24.99 None
# 65 200 24 Worms_Armageddon 217200 win Mar 19, 2013 None 14.99 None
# 65 200 25 GTTOD_Get_To_The_Orange_Door 541200 win Oct 27, 2017 None 14.99 None
# Retrieved listings from search results page 65.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_65_20211019_145504.parquet.gzip...done.
# Exported search results for page 65.
#
# Completed page 65 [collected 1600-1625 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 66...Pausing for 2.98 sec...done.
# 66 200 1 Offworld_Trading_Company 271240 win,mac Apr 28, 2016 None 29.99 None
# 66 200 2 Vacation_Simulator 726830 win,vr_required Apr 9, 2019 None 29.99 None
# 66 200 3 Thief_Simulator_VR 1019550 win,vr_required Nov 5, 2020 None 19.99 None
# 66 200 4 Zoo_Tycoon_Ultimate_Animal_Collection 613880 win Sep 14, 2018 None 19.99 None
# 66 200 5 Coffee_Talk 914800 win,mac Jan 29, 2020 None 12.99 None
# 66 200 6 From_The_Darkness 1517340 win Mar 30, 2021 None 6.99 None
# 66 200 7 The_Last_Stand_Legacy_Collection 1615100 win,mac Jul 15, 2021 None 9.99 None
# 66 200 8 Critadel 808010 win Oct 12, 2021 None 19.99 None
# 66 200 9 Kill_It_With_Fire 1179210 win Aug 13, 2020 None 14.99 None
# 66 200 10 RiMS_Racing 1346010 win Aug 19, 2021 None 49.99 None
# 66 200 11 LEGO_Harry_Potter_Years_57 204120 win Jan 5, 2012 None 19.99 None
# 66 200 12 LISA_The_Painful 335670 win,mac,linux Dec 15, 2014 None 9.99 None
# 66 200 13 Black_Squad 550650 win Jun 26, 2019 None Free to Play None
# 66 200 14 Attack_on_Toys 1269690 win Sep 24, 2021 None 6.99 None
# 66 200 15 Max_Payne 12140 win Jan 4, 2008 None 9.99 None
# 66 200 16 Atelier_Lydie__Suelle_The_Alchemists_and_the_Mysterious_Paintings_DX 1502990 win Apr 21, 2021 None 39.99 None
# 66 200 17 Fights_in_Tight_Spaces 1265820 win Feb 24, 2021 None 24.99 None
# 66 200 18 Shadowrun_Dragonfall__Directors_Cut 300550 win,mac,linux Sep 18, 2014 -75% 14.99 3.74
# 66 200 19 Rail_Route 1124180 win,mac,linux Jun 23, 2021 None 14.99 None
# 66 200 20 Sword_Art_Online_Hollow_Realization_Deluxe_Edition 607890 win Oct 27, 2017 None 49.99 None
# 66 200 21 Peggle_Deluxe 3480 win,mac Mar 6, 2007 None 4.99 None
# 66 200 22 Watch_Dogs 243470 win May 26, 2014 None 29.99 None
# 66 200 23 Sniper_Elite_VR 752480 win,vr_required Jul 8, 2021 None 29.99 None
# 66 200 24 DARK_SOULS_III_Deluxe_Edition 374320,442010 win Apr 11, 2016 None 84.98 None
# 66 200 25 Vermillion 1608400 win,vr_required Jul 26, 2021 None 19.99 None
# Retrieved listings from search results page 66.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_66_20211019_145507.parquet.gzip...done.
# Exported search results for page 66.
#
# Completed page 66 [collected 1625-1650 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 67...Pausing for 3.30 sec...done.
# 67 200 1 Stationeers 544550 win Dec 12, 2017 None 24.99 None
# 67 200 2 World_of_Warplanes 790710 win Sep 12, 2018 None Free To Play None
# 67 200 3 Stellar_Warfare 1113030 win Aug 4, 2021 None 19.99 None
# 67 200 4 DEEMO_Reborn 1282210 win,vr_supported Sep 3, 2020 None 24.99 None
# 67 200 5 Stronghold_Crusader_HD 40970 win Oct 21, 2013 None 9.99 None
# 67 200 6 UNDER_NIGHT_INBIRTH_ExeLateclr 801630 win Aug 20, 2018 None 24.99 None
# 67 200 7 Warhammer_40000_Dawn_of_War__Soulstorm 9450 win Mar 5, 2008 None 12.99 None
# 67 200 8 Shotgun_Farmers 604240 win,mac,linux Mar 8, 2019 None 9.99 None
# 67 200 9 Toodee_and_Topdee 1303950 win Aug 4, 2021 -25% 19.99 14.99
# 67 200 10 World_of_Guns_Gun_Disassembly 262410 win,mac,linux May 21, 2014 None Free to Play None
# 67 200 11 CastleMiner_Z 253430 win Feb 3, 2014 None 3.99 None
# 67 200 12 My_Friend_Pedro 557340 win Jun 20, 2019 None 19.99 None
# 67 200 13 SENRAN_KAGURA_Peach_Beach_Splash 696170 win,vr_supported Mar 7, 2018 None 29.99 None
# 67 200 14 Planescape_Torment_Enhanced_Edition 466300 win,mac,linux Apr 11, 2017 None 19.99 None
# 67 200 15 花妖物语Flower_girl 1568940 win Sep 15, 2021 None Free To Play None
# 67 200 16 Quiplash 351510 win,mac,linux Jun 30, 2015 None 9.99 None
# 67 200 17 Richman10 1162520 win,mac Oct 24, 2019 None 13.99 None
# 67 200 18 The_Wolf_Among_Us 250320 win Oct 11, 2013 None 14.99 None
# 67 200 19 Catherine_Classic 893180 win Jan 10, 2019 None 19.99 None
# 67 200 20 Hoa 1484900 win,mac Aug 24, 2021 None 14.99 None
# 67 200 21 FAIRY_TAIL 1233260 win Jul 29, 2020 None 59.99 None
# 67 200 22 Icewind_Dale_Enhanced_Edition 321800 win,mac,linux Oct 30, 2014 None 19.99 None
# 67 200 23 Serious_Sam_4 257420 win Sep 24, 2020 None 39.99 None
# 67 200 24 Fuga_Melodies_of_Steel 1357860 win Jul 28, 2021 None 39.99 None
# 67 200 25 SMASH_LEGENDS 1352080 win Apr 12, 2021 None Free To Play None
# Retrieved listings from search results page 67.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_67_20211019_145511.parquet.gzip...done.
# Exported search results for page 67.
#
# Completed page 67 [collected 1650-1675 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 68...Pausing for 2.94 sec...done.
# 68 200 1 DEAD_RISING 427190 win Sep 12, 2016 None 19.99 None
# 68 200 2 Snowtopia_Ski_Resort_Builder 1124260 win,linux Jan 26, 2021 None 24.99 None
# 68 200 3 Kindergarten 589590 win,mac,linux Jun 15, 2017 None 4.99 None
# 68 200 4 Terrain_of_Magical_Expertise 1543430 win Sep 9, 2021 None 24.99 None
# 68 200 5 Call_of_War_World_War_2 672680 win,mac Oct 21, 2017 None Free to Play None
# 68 200 6 Risk_of_Rain 248820 win,mac,linux Nov 8, 2013 None 9.99 None
# 68 200 7 Hacknet 365450 win,mac,linux Aug 12, 2015 None 9.99 None
# 68 200 8 Insaniquarium_Deluxe 3320 win Aug 30, 2006 None 4.99 None
# 68 200 9 FINAL_FANTASY_XIII2 292140 win Dec 11, 2014 None 19.99 None
# 68 200 10 Kingdom_Rush_Origins__Tower_Defense 816340 win,mac,linux Oct 17, 2018 None 14.99 None
# 68 200 11 Karnage_Chronicles 611160 win,vr_required Jul 31, 2020 None 24.99 None
# 68 200 12 Due_Process 753650 win Nov 3, 2020 None 24.99 None
# 68 200 13 Project_Highrise 423580 win,mac Sep 8, 2016 None 19.99 None
# 68 200 14 Castlevania_Lords_of_Shadow__Ultimate_Edition 234080 win Aug 27, 2013 None 29.99 None
# 68 200 15 WHAT_THE_GOLF 785790 win,mac,linux Oct 22, 2020 None 19.99 None
# 68 200 16 Finding_Paradise 337340 win,mac,linux Dec 14, 2017 None 9.99 None
# 68 200 17 GUNS_UP 446150 win Feb 5, 2018 None Free To Play None
# 68 200 18 Bloons_Monkey_City 1252780 win,mac Apr 10, 2020 None Free To Play None
# 68 200 19 Marfusha 1456820 win Aug 26, 2021 None 7.99 None
# 68 200 20 My_Garage 1578390 win Aug 10, 2021 None 24.99 None
# 68 200 21 EARTH_DEFENSE_FORCE_WORLD_BROTHERS 1497950 win May 27, 2021 None 59.99 None
# 68 200 22 Tick_Tock_A_Tale_for_Two 790740 win,mac Mar 7, 2019 None 5.99 None
# 68 200 23 Voxel_Tycoon 732050 win,mac,linux Apr 15, 2021 None 24.99 None
# 68 200 24 Labyrinth_of_Refrain_Coven_of_Dusk 566540 win Sep 18, 2018 None 49.99 None
# 68 200 25 Sonic__AllStars_Racing_Transformed_Collection 212480 win Jan 31, 2013 None 19.99 None
# Retrieved listings from search results page 68.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_68_20211019_145515.parquet.gzip...done.
# Exported search results for page 68.
#
# Completed page 68 [collected 1675-1700 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 69...Pausing for 4.14 sec...done.
# 69 200 1 Fallout_2_A_Post_Nuclear_Role_Playing_Game 38410 win Aug 19, 2009 -70% 9.99 2.99
# 69 200 2 Chess_Ultra 518060 win,vr_supported Jun 21, 2017 -60% 12.99 5.19
# 69 200 3 Dark_Deception_Monsters__Mortals 1266690 win Nov 2, 2020 None 9.99 None
# 69 200 4 The_Suicide_of_Rachel_Foster 1057750 win Feb 19, 2020 None 17.99 None
# 69 200 5 Fireworks_Mania__An_Explosive_Simulator 1079260 win Dec 17, 2020 None 11.99 None
# 69 200 6 The_Room_Three 456750 win Nov 13, 2018 None 5.99 None
# 69 200 7 The_Legend_of_Heroes_Trails_in_the_Sky_SC 251290 win Oct 29, 2015 None 29.99 None
# 69 200 8 Farming_Simulator_17 447020 win,mac Oct 24, 2016 None 14.99 None
# 69 200 9 BlazBlue_Centralfiction 586140 win Apr 25, 2017 None 39.99 None
# 69 200 10 Hexcells_Infinite 304410 win,mac,linux Sep 1, 2014 None 4.99 None
# 69 200 11 Citadel_Forged_with_Fire 487120 win Nov 1, 2019 -70% 39.99 11.99
# 69 200 12 art_of_rally 550320 win,mac,linux Sep 23, 2020 None 24.99 None
# 69 200 13 Vagante 323220 win,mac,linux Feb 21, 2018 None 14.99 None
# 69 200 14 Surviving_the_Aftermath 684450 win Oct 22, 2020 None 24.99 None
# 69 200 15 Eternal_Card_Game 531640 win,mac Nov 15, 2018 None Free To Play None
# 69 200 16 Zero_Escape_Zero_Time_Dilemma 311240 win Jun 29, 2016 None 19.99 None
# 69 200 17 BLUE_REFLECTION__BLUE_REFLECTION幻に舞う少女の剣 658260 win Sep 26, 2017 None 59.99 None
# 69 200 18 Resident_Evil_0 339340 win Jan 19, 2016 None 19.99 None
# 69 200 19 Kingdom_Rush___Tower_Defense 246420 win,mac,linux Jan 6, 2014 None 9.99 None
# 69 200 20 UnderRail 250520 win Dec 18, 2015 None 14.99 None
# 69 200 21 Lost_in_Vivo 963710 win Nov 5, 2018 None 11.99 None
# 69 200 22 SHIPS_AT_WAR 1557420 win Aug 5, 2021 None 14.99 None
# 69 200 23 EXAPUNKS 716490 win,mac,linux Oct 22, 2018 None 19.99 None
# 69 200 24 Realm_Royale 813820 win Jun 5, 2018 None Free To Play None
# 69 200 25 Hyper_Light_Drifter 257850 win,mac,linux Mar 31, 2016 None 19.99 None
# Retrieved listings from search results page 69.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_69_20211019_145520.parquet.gzip...done.
# Exported search results for page 69.
#
# Completed page 69 [collected 1700-1725 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 70...Pausing for 3.64 sec...done.
# 70 200 1 STAR_WARS_Battlefront_Classic_2004 1058020 win May 1, 2019 None 9.99 None
# 70 200 2 Haydee_2 1444650 win Nov 23, 2020 None 24.99 None
# 70 200 3 Hadean_Tactics 1260590 win,mac,linux Feb 25, 2021 None 17.99 None
# 70 200 4 Creed_Rise_to_Glory 804490 win,vr_required Sep 25, 2018 None 29.99 None
# 70 200 5 Find_Yourself 1504740 win Feb 21, 2021 None 6.99 None
# 70 200 6 ICBM 1178220 win Nov 17, 2020 None 19.99 None
# 70 200 7 Trover_Saves_the_Universe 1051200 win,vr_supported Jun 4, 2019 None 29.99 None
# 70 200 8 APB_Reloaded 113400 win Dec 6, 2011 None Free to Play None
# 70 200 9 PixARK 593600 win May 31, 2019 None 39.99 None
# 70 200 10 EZ2ON_REBOOT__R 1477590 win Mar 17, 2021 None 44.99 None
# 70 200 11 Golden_Krone_Hotel 497800 win,mac,linux Oct 26, 2017 -75% 9.99 2.49
# 70 200 12 The_Room 288160 win Jul 28, 2014 None 4.99 None
# 70 200 13 Riders_of_Icarus 442080 win Jul 6, 2016 None Free to Play None
# 70 200 14 Paradise_Lost 982720 win Mar 24, 2021 -40% 14.99 8.99
# 70 200 15 Project_Nightmares_Case_36_Henrietta_Kedward 812070 win Sep 29, 2021 None 24.99 None
# 70 200 16 Obduction 306760 win,mac,vr_supported Aug 24, 2016 None 29.99 None
# 70 200 17 We_Happy_Few 320240 win Aug 10, 2018 None 59.99 None
# 70 200 18 STAR_WARS_Jedi_Knight__Jedi_Academy 6020 win,mac Sep 16, 2009 None 9.99 None
# 70 200 19 GUILTY_GEAR_XX_ACCENT_CORE_PLUS_R 348550 win May 26, 2015 None 14.99 None
# 70 200 20 Nuclear_Throne 242680 win,mac,linux Dec 5, 2015 None 11.99 None
# 70 200 21 HALF_DEAD_3 1520380 win Aug 20, 2021 None 4.99 None
# 70 200 22 Hypnospace_Outlaw 844590 win,mac,linux Mar 12, 2019 None 19.99 None
# 70 200 23 DISSIDIA_FINAL_FANTASY_NT_Free_Edition 921590 win Mar 12, 2019 None Free To Play None
# 70 200 24 Fake_Hostel 1735420 win Sep 16, 2021 None 4.99 None
# 70 200 25 Duck_Season 503580 win,vr_required Sep 14, 2017 None 19.99 None
# Retrieved listings from search results page 70.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_70_20211019_145524.parquet.gzip...done.
# Exported search results for page 70.
#
# Completed page 70 [collected 1725-1750 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 71...Pausing for 4.05 sec...done.
# 71 200 1 EverQuest 205710 win Dec 13, 2012 None Free to Play None
# 71 200 2 ONE_PUNCH_MAN_A_HERO_NOBODY_KNOWS 991560 win Feb 27, 2020 None 59.99 None
# 71 200 3 Tales_of_Symphonia 372360 win Feb 1, 2016 None 19.99 None
# 71 200 4 Drawful_2 442070 win,mac,linux Jun 20, 2016 None 9.99 None
# 71 200 5 Fallout_Classic_Collection 38400,38420,38410 win  -70% 19.99 5.99
# 71 200 6 The_Legend_of_Heroes_Trails_in_the_Sky_the_3rd 436670 win May 3, 2017 None 29.99 None
# 71 200 7 Quantum_Break 474960 win Sep 29, 2016 None 39.99 None
# 71 200 8 Mutant_Football_League 529520 win Oct 31, 2017 None 14.99 None
# 71 200 9 SAMURAI_SHODOWN 1342260 win Jun 14, 2021 None None None
# 71 200 10 Stonehearth 253250 win,mac Jul 25, 2018 None 19.99 None
# 71 200 11 Screeps_World 464350 win,mac,linux Nov 16, 2016 None 14.99 None
# 71 200 12 Attack_on_Titan__AOT_Wings_of_Freedom 449800 win Aug 26, 2016 None 59.99 None
# 71 200 13 Disgaea_PC 405900 win Feb 24, 2016 None 19.99 None
# 71 200 14 Slender_The_Arrival 252330 win,mac Oct 28, 2013 -85% 9.99 1.49
# 71 200 15 Granny_Simulator 1053680 win Apr 17, 2019 None 4.99 None
# 71 200 16 Atelier_Firis_The_Alchemist_and_the_Mysterious_Journey_DX 1502980 win Apr 21, 2021 None 39.99 None
# 71 200 17 DEEEER_Simulator_Your_Average_Everyday_Deer_Game 1018800 win Jan 20, 2020 None 12.99 None
# 71 200 18 Jalopy 446020 win Mar 28, 2018 -40% 14.99 8.99
# 71 200 19 Shelter_Manager 1256830 win Oct 8, 2021 None 14.99 None
# ...
# Retrieved listings from search results page 92.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_92_20211019_145659.parquet.gzip...done.
# Exported search results for page 92.
#
# Completed page 92 [collected 2275-2300 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 93...Pausing for 3.37 sec...done.
# 93 200 1 Vertigo_Remastered 1318090 win,vr_required Jul 21, 2020 None 24.99 None
# 93 200 2 Kind_Words_lo_fi_chill_beats_to_write_to 1070710 win,mac,linux Sep 12, 2019 None 4.99 None
# 93 200 3 Apex_Aim_Trainer 1188540 win Jan 29, 2020 None 4.99 None
# 93 200 4 Duke_Nukem_3D_20th_Anniversary_World_Tour 434050 win Oct 11, 2016 None 19.99 None
# 93 200 5 Quake_III_Arena 2200 win Aug 3, 2007 None 14.99 None
# 93 200 6 Transistor 237930 win,mac,linux May 20, 2014 None 19.99 None
# 93 200 7 NosTale__Anime_MMORPG 550470 win Sep 18, 2017 None Free to Play None
# 93 200 8 Force_of_Nature_2_Ghost_Keeper 1316230 win May 27, 2021 None 15.99 None
# 93 200 9 Grey_Hack 605230 win,mac,linux Dec 14, 2017 None 14.99 None
# 93 200 10 Unreal_Tournament_2004_Editors_Choice_Edition 13230 win Mar 17, 2004 None 14.99 None
# 93 200 11 Cattails__Become_a_Cat 634160 win,mac Dec 1, 2017 None 14.99 None
# 93 200 12 Call_of_Duty 2620 win Oct 13, 2006 None 19.99 None
# 93 200 13 The_Ditzy_Demons_Are_in_Love_With_Me 802870 win Oct 26, 2018 None 24.99 None
# 93 200 14 Cricket_19 1028630 win Jul 30, 2019 None 29.99 None
# 93 200 15 Harvest_Moon_One_World 1246870 win Sep 7, 2021 None 49.99 None
# 93 200 16 The_Alliance_Alive_HD_Remastered 1027250 win Jan 16, 2020 None 39.99 None
# 93 200 17 Battle_Realms_Zen_Edition 1025600 win Dec 3, 2019 None 9.99 None
# 93 200 18 Ion_Fury 562860 win,linux Aug 15, 2019 None 24.99 None
# 93 200 19 Total_War_EMPIRE__Definitive_Edition 10500,10600,10604,10606,10607,10608 win,mac,linux  None 24.99 None
# 93 200 20 The_Shrouded_Isle 501320 win,mac Aug 4, 2017 -80% 9.99 1.99
# 93 200 21 Secrets_of_Grindea 269770 win Jul 13, 2015 None 14.99 None
# 93 200 22 Ideology_in_Friction 1011940 win Jun 13, 2019 None 24.99 None
# 93 200 23 Rock_of_Ages_2_Bigger__Boulder 434460 win Aug 28, 2017 None 14.99 None
# 93 200 24 The_Banner_Saga 237990 win,mac Jan 14, 2014 None 24.99 None
# 93 200 25 Dont_Be_Afraid 760410 win Dec 17, 2020 None 13.99 None
# Retrieved listings from search results page 93.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_93_20211019_145703.parquet.gzip...done.
# Exported search results for page 93.
#
# Completed page 93 [collected 2300-2325 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 94...Pausing for 3.12 sec...done.
# 94 200 1 Die_Young 433170 win Sep 12, 2019 -70% 19.99 5.99
# 94 200 2 The_Slormancer 1104280 win Apr 6, 2021 None 14.99 None
# 94 200 3 Blair_Witch_VR 1576350 win,vr_required Aug 12, 2021 None 29.99 None
# 94 200 4 Reshaping_Mars 1395760 win Aug 25, 2021 None 9.99 None
# 94 200 5 Nancy_Drew_Sea_of_Darkness 572700 win Feb 2, 2017 None 19.99 None
# 94 200 6 Ancient_Warfare_3 758990 win,linux Dec 21, 2017 None 9.99 None
# 94 200 7 The_Caligula_Effect_Overdose 889600 win Mar 12, 2019 None 49.99 None
# 94 200 8 Trine_2_Complete_Story 35720 win,mac,linux Jun 6, 2013 None 19.99 None
# 94 200 9 Brothers_in_Arms_Earned_in_Blood 19800 win Jul 17, 2009 None 9.99 None
# 94 200 10 Card_Hunter 293260 win,mac Jul 13, 2015 None Free None
# 94 200 11 CUSTOM_ORDER_MAID_3D2_Its_a_Night_Magic 1097580 win,vr_supported Jul 30, 2019 None 40.00 None
# 94 200 12 Team_Fortress_Classic 20 win,mac,linux Apr 1, 1999 None 4.99 None
# 94 200 13 Nimbatus__The_Space_Drone_Constructor 383840 win,mac,linux May 14, 2020 None 19.99 None
# 94 200 14 Ys_SEVEN 587100 win Aug 30, 2017 None 24.99 None
# 94 200 15 ReZERO_Starting_Life_in_Another_World_The_Prophecy_of_the_Throne 1277510 win Jan 27, 2021 None 59.99 None
# 94 200 16 Little_Inferno 221260 win,mac,linux Nov 19, 2012 None 14.99 None
# 94 200 17 The_Darkside_Detective 368390 win,mac,linux Jul 27, 2017 None 12.99 None
# 94 200 18 Townsmen__A_Kingdom_Rebuilt 938380 win Feb 26, 2019 -60% 19.99 7.99
# 94 200 19 Good_Company 911430 win Mar 31, 2020 None 24.99 None
# 94 200 20 The_Convenience_Store__夜勤事件 1228520 win Feb 17, 2020 None 2.99 None
# 94 200 21 Disney_Infinity_30_Gold_Edition 541670 win Dec 9, 2016 None 29.99 None
# 94 200 22 Tom_Clancys_Ghost_Recon 15300 win Jul 15, 2008 None 9.99 None
# 94 200 23 VR_Dungeon_Knight 566860 win,vr_required Apr 24, 2017 None 19.99 None
# 94 200 24 Spirit_of_the_North 1213700 win May 7, 2020 None 19.99 None
# 94 200 25 Cube_Escape_Collection 1292940 win,mac Oct 14, 2020 None 4.99 None
# Retrieved listings from search results page 94.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_94_20211019_145707.parquet.gzip...done.
# Exported search results for page 94.
#
# Completed page 94 [collected 2325-2350 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 95...Pausing for 2.98 sec...done.
# 95 200 1 Transcendence 364510 win Jul 24, 2015 -50% 8.99 4.49
# 95 200 2 Touhou_Monster_TD__幻想乡妖怪塔防 1671350 win,mac,linux Oct 1, 2021 None 18.99 None
# 95 200 3 Grim_Nights_2 1522280 win Oct 12, 2021 -40% 7.99 4.79
# 95 200 4 RWBY_Grimm_Eclipse 418340 win,mac Jul 5, 2016 None 19.99 None
# 95 200 5 Kingdom_Under_Fire_Heroes 1315200 win Jun 24, 2020 None 19.99 None
# 95 200 6 Star_Traders_Frontiers 335620 win,mac,linux Jul 31, 2018 None 14.99 None
# 95 200 7 When_The_Past_Was_Around 1164050 win,mac Sep 22, 2020 None 7.99 None
# 95 200 8 Cogmind 722730 win Oct 16, 2017 None 19.99 None
# 95 200 9 Sanctum_2 210770 win,mac,linux May 15, 2013 None 14.99 None
# 95 200 10 Pixel_Worlds_MMO_Sandbox 636040 win,mac Jun 8, 2017 None Free To Play None
# 95 200 11 Genesis_Noir 735290 win,mac Mar 26, 2021 None 14.99 None
# 95 200 12 Venineth 976500 win Apr 16, 2020 None 19.99 None
# 95 200 13 Nexomon 1191580 win,mac Jul 10, 2020 None 9.99 None
# 95 200 14 Trader_Life_Simulator 1415660 win Feb 18, 2021 None 29.99 None
# 95 200 15 Cats_in_Time 1599880 win Aug 26, 2021 -10% 4.99 4.49
# 95 200 16 Wild_Terra_2_New_Lands 1134700 win Jan 28, 2021 None 34.99 None
# 95 200 17 Orbital_Bullet__The_360_Roguelite 1167680 win Apr 22, 2021 -25% 12.99 9.74
# 95 200 18 TIS100 370360 win,mac,linux Jul 20, 2015 None 6.99 None
# 95 200 19 Atelier_Lulua_The_Scion_of_Arland__ルルアのアトリエ_アーランドの錬金術士４ 1045620 win May 20, 2019 None 59.99 None
# 95 200 20 DOOM_VFR 650000 win,vr_required Nov 30, 2017 None 14.99 None
# 95 200 21 Secret_of_Mana 637670 win Feb 15, 2018 None 39.99 None
# 95 200 22 Tom_Clancys_Splinter_Cell_Chaos_Theory 13570 win Aug 27, 2009 None 9.99 None
# 95 200 23 One_Hand_Clapping 893720 win Jun 10, 2021 None 11.99 None
# 95 200 24 Bastion 107100 win,mac,linux Aug 16, 2011 None 14.99 None
# 95 200 25 CryoFall 829590 win Apr 29, 2021 None 19.99 None
# Retrieved listings from search results page 95.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_95_20211019_145710.parquet.gzip...done.
# Exported search results for page 95.
#
# Completed page 95 [collected 2350-2375 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 96...Pausing for 4.11 sec...done.
# 96 200 1 Totally_Reliable_Delivery_Service 1011670 win,mac,linux Apr 1, 2021 None 14.99 None
# 96 200 2 Ash_of_Gods_Redemption 691690 win,mac,linux Mar 23, 2018 -70% 24.99 7.49
# 96 200 3 F1_2017 515220 win,mac,linux Aug 24, 2017 None 9.99 None
# 96 200 4 Umineko_When_They_Cry__Question_Arcs 406550 win,mac,linux Jul 8, 2016 None 24.99 None
# 96 200 5 DARK_SOULS_III_Deluxe_Edition 374320,442010 win Apr 11, 2016 None 84.98 None
# 96 200 6 Necromunda_Underhive_Wars 566440 win Sep 7, 2020 None 19.99 None
# 96 200 7 Dude_Stop 574560 win,mac,linux Jun 1, 2018 None 14.99 None
# 96 200 8 My_Little_Blacksmith_Shop 980940 win Dec 22, 2019 None 9.99 None
# 96 200 9 Project_CARS 234630 win,vr_supported Mar 15, 2015 None 14.99 None
# 96 200 10 Somewhere_in_the_Shadow 1577320 win Aug 23, 2021 None 2.99 None
# 96 200 11 Hundred_Days__Winemaking_Simulator 1042380 win,mac May 13, 2021 None 24.99 None
# 96 200 12 Zoombinis 397430 win,mac Oct 28, 2015 None 9.99 None
# 96 200 13 Kart_Racing_Pro 415600 win,vr_supported Jul 14, 2017 None 39.99 None
# 96 200 14 Slow_living_with_Princess 1581800 win Oct 6, 2021 None 11.99 None
# 96 200 15 ATRI_My_Dear_Moments 1230140 win Jun 18, 2020 None 20.99 None
# 96 200 16 EVERSLAUGHT 1530750 win,vr_required Jul 31, 2021 None 19.99 None
# 96 200 17 I_Am_Bread 327890 win,mac Apr 9, 2015 None 12.99 None
# 96 200 18 Project_Gorgon 342940 win,mac,linux Mar 12, 2018 None 39.99 None
# 96 200 19 DiRT_Rally 310560 win,mac,linux,vr_supported Dec 7, 2015 None 14.99 None
# 96 200 20 THE_KING_OF_FIGHTERS_XIII_STEAM_EDITION 222940 win Sep 13, 2013 None 19.99 None
# 96 200 21 Yomawari_Midnight_Shadows 625980 win Oct 24, 2017 None 19.99 None
# 96 200 22 Risen_3__Titan_Lords 249230 win Aug 12, 2014 None 14.99 None
# 96 200 23 Skeletal_Avenger 1277500 win Sep 29, 2021 None 16.99 None
# 96 200 24 Shift_Happens 359840 win Feb 22, 2017 None 14.99 None
# 96 200 25 Retro_Machina 1127970 win May 12, 2021 None 16.99 None
# Retrieved listings from search results page 96.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_96_20211019_145715.parquet.gzip...done.
# Exported search results for page 96.
#
# Completed page 96 [collected 2375-2400 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 97...Pausing for 3.24 sec...done.
# 97 200 1 Soundodger_2 1400910 win Oct 11, 2021 None 19.99 None
# 97 200 2 What_The_Dub 1495860 win,mac Apr 8, 2021 None 7.99 None
# 97 200 3 Skinwalker_Hunt 993110 win Jun 4, 2021 None 9.99 None
# 97 200 4 Coming_Out_on_Top 642090 win,mac,linux Oct 12, 2017 None 14.99 None
# 97 200 5 Team_Sonic_Racing 785260 win May 21, 2019 None 39.99 None
# 97 200 6 Brave_Alchemist_Colette 1135830 win Apr 27, 2020 None 24.99 None
# 97 200 7 Do_Not_Feed_the_Monkeys 658850 win,mac,linux Oct 23, 2018 None 11.99 None
# 97 200 8 Bonfire_Peaks 1147890 win,mac,linux Sep 30, 2021 None 19.99 None
# 97 200 9 Tribal_Hunter 1379870 win Feb 24, 2021 None 14.99 None
# 97 200 10 Eastern_Exorcist 1120810 win Jul 7, 2021 None 17.99 None
# 97 200 11 Machinarium 40700 win,mac Oct 16, 2009 None 14.99 None
# 97 200 12 Worms_Reloaded 22600 win,mac,linux Aug 26, 2010 None 19.99 None
# 97 200 13 WW2_Bunker_Simulator 1155870 win Sep 1, 2021 None 11.99 None
# 97 200 14 Zuma_Deluxe 3330 win,mac Aug 30, 2006 None 4.99 None
# 97 200 15 Trainz_A_New_Era 315660 win,mac May 14, 2015 None 19.99 None
# 97 200 16 Tracks__The_Train_Set_Game 657240 win Nov 14, 2019 None 19.99 None
# 97 200 17 DemonCrawl 1141220 win,mac,linux Nov 5, 2019 None 14.99 None
# 97 200 18 Richies_Plank_Experience 517160 win,vr_required Dec 18, 2017 None 14.99 None
# 97 200 19 Way_of_the_Samurai_4 312780 win Jul 23, 2015 None 24.99 None
# 97 200 20 LoveBeat 354290 win Jan 13, 2016 None Free None
# 97 200 21 Kingdom_New_Lands 496300 win,mac,linux Aug 9, 2016 None 14.99 None
# 97 200 22 ROMANCE_OF_THE_THREE_KINGDOMS_XIII 363150 win Feb 15, 2017 None 59.99 None
# 97 200 23 Heroes_of_Might__Magic_V 15170 win May 13, 2008 None 9.99 None
# 97 200 24 This_Is_the_Police_2 785740 win,mac,linux Jul 31, 2018 None 14.99 None
# 97 200 25 Combat_Mission_Black_Sea 1502380 win Jan 21, 2021 None 59.99 None
# Retrieved listings from search results page 97.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_97_20211019_145719.parquet.gzip...done.
# Exported search results for page 97.
#
# Completed page 97 [collected 2400-2425 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 98...Pausing for 3.79 sec...done.
# 98 200 1 Combat_Mission_Black_Sea 1502380 win Jan 21, 2021 None 59.99 None
# 98 200 2 MY_HERO_ONES_JUSTICE 748360 win Oct 25, 2018 None 59.99 None
# 98 200 3 Love_n_War_Warlord_by_Chance 1508680 win May 28, 2021 None 2.99 None
# 98 200 4 Patch_Quest 1347970 win May 7, 2021 None 19.99 None
# 98 200 5 Tested_on_Humans_Escape_Room 1483780 win Feb 24, 2021 None 9.99 None
# 98 200 6 My_Beautiful_Paper_Smile 1036700 win Oct 14, 2021 -10% 14.99 13.49
# 98 200 7 The_Curse_of_Monkey_Island 730820 win,mac Mar 22, 2018 None 6.99 None
# 98 200 8 Sea_of_Solitude 1225590 win Jun 4, 2020 -75% 19.99 4.99
# 98 200 9 Budget_Cuts 400940 win,vr_required Jun 14, 2018 None 29.99 None
# 98 200 10 Freddi_Fish_2_The_Case_of_the_Haunted_Schoolhouse 294530 win,mac,linux May 1, 2014 None 6.99 None
# 98 200 11 Idle_Wizard 992070 win,mac,linux Jan 24, 2019 None Free To Play None
# 98 200 12 GemCraft__Chasing_Shadows 296490 win Apr 30, 2015 None 9.99 None
# 98 200 13 YORGio 880580 win May 23, 2019 None 3.99 None
# 98 200 14 Gordian_Quest 981430 win Mar 27, 2020 None 19.99 None
# 98 200 15 War_Room 1175880 win Nov 18, 2020 None 29.99 None
# 98 200 16 XERA_Survival 625340 win Sep 26, 2021 None Free to Play None
# 98 200 17 Blacksad_Under_the_Skin 1003890 win,mac Nov 14, 2019 None 39.99 None
# 98 200 18 Chef_A_Restaurant_Tycoon_Game 886900 win Aug 20, 2020 None 19.99 None
# 98 200 19 Signal_Simulator 839310 win,linux Apr 29, 2018 None 19.99 None
# 98 200 20 King_Arthur_Knights_Tale 1157390 win Jan 26, 2021 None 34.99 None
# 98 200 21 Tannenberg 633460 win,mac,linux Nov 16, 2017 None 19.99 None
# 98 200 22 Chrono_Ark 1188930 win Dec 19, 2019 None 19.99 None
# 98 200 23 Agrou 1305420 win Jul 25, 2020 None 4.99 None
# 98 200 24 TrackMania²_Stadium 232910 win Jun 20, 2013 None 9.99 None
# 98 200 25 Zaccaria_Pinball 444930 win,mac,linux,vr_supported Jun 16, 2016 None Free To Play None
# Retrieved listings from search results page 98.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_98_20211019_145723.parquet.gzip...done.
# Exported search results for page 98.
#
# Completed page 98 [collected 2425-2450 search results (max. search result index wanted = 2475)].
#
# Received response to request from page 99...Pausing for 3.78 sec...done.
# 99 200 1 Condemned_Criminal_Origins 4720 win Oct 29, 2012 None 14.95 None
# 99 200 2 Stay_Close 455120 win Oct 14, 2016 None 8.99 None
# 99 200 3 THE_KING_OF_FIGHTERS_98_ULTIMATE_MATCH_FINAL_EDITION 222420 win Dec 16, 2014 None 14.99 None
# 99 200 4 Ghosts_n_Goblins_Resurrection 1375400 win May 31, 2021 None 29.99 None
# 99 200 5 Phantom_Doctrine 559100 win Aug 14, 2018 None 39.99 None
# 99 200 6 The_Ramp 1506510 win Aug 3, 2021 None 5.99 None
# 99 200 7 Ragnorium 474020 win Sep 16, 2020 None 24.99 None
# 99 200 8 Stranded_Sails__Explorers_of_the_Cursed_Islands 943260 win Oct 17, 2019 -65% 24.99 8.74
# 99 200 9 Rogue_State_Revolution 1145340 win,linux Mar 18, 2021 -33% 14.99 10.04
# 99 200 10 Granny 962400 win Nov 20, 2018 None 4.99 None
# 99 200 11 Tabletopia 402560 win,mac Nov 30, 2016 None Free to Play None
# 99 200 12 The_Darkside_Detective_A_Fumble_in_the_Dark 795420 win,mac,linux Apr 15, 2021 None 12.99 None
# 99 200 13 When_The_Night_Comes 1400870 win,mac,linux Aug 9, 2021 None 12.99 None
# 99 200 14 Transport_Fever 446800 win,mac,linux Nov 8, 2016 None 29.99 None
# 99 200 15 Lightmatter 994140 win Jan 15, 2020 None Free None
# 99 200 16 Far_Cry 13520 win Apr 1, 2008 None 9.99 None
# 99 200 17 Kings_Quest 345390 win Jul 28, 2015 None None None
# 99 200 18 Final_Fantasy_III_3D_Remake 239120 win May 27, 2014 None 15.99 None
# 99 200 19 The_Elder_Scrolls_Legends 364470 win,mac May 31, 2017 None Free to Play None
# 99 200 20 Puyo_PuyoTetris 546050 win Feb 27, 2018 None 19.99 None
# 99 200 21 Sid_Meiers_Civilization_III_Complete 3910 win Oct 25, 2006 None 4.99 None
# 99 200 22 FATE_Undiscovered_Realms 276890 win Apr 17, 2014 None 7.99 None
# 99 200 23 Haven_Park 1549550 win,mac,linux Aug 5, 2021 None 8.99 None
# 99 200 24 Peggle_Nights 3540 win,mac Oct 15, 2008 None 4.99 None
# 99 200 25 Internet_Cafe_Simulator 1136160 win Oct 25, 2019 -50% 9.99 4.99
# Retrieved listings from search results page 99.
# Saving data to /home/edesz/notebooks/data/raw/requests/search_results_page_99_20211019_145728.parquet.gzip...done.
# Exported search results for page 99.
#
# Completed page 99 [collected 2450-2475 search results (max. search result index wanted = 2475)].
#
# CPU times: user 17.4 s, sys: 837 ms, total: 18.3 s
# Wall time: 3min 30s

# %% [markdown]
# <a id="examine-collected-outputs"></a>
#
# ## 3. [Examine collected outputs](#examine-collected-outputs)

# %% [markdown]
# Get a list of the created Parquet filepaths

# %%
parquet_file_list = glob(os.path.join(requests_data_dir, "*.parquet.gzip"))
parquet_file_list.sort(key=lambda f: int(re.sub("\D", "", f)))
print(f"Found {len(parquet_file_list)} Parquet files of search results.")
# Out:
# Found 50 Parquet files of search results.

# %% [markdown]
# Vertically concatenate all Parquet files into a single `DataFrame` and show this output

# %%
# %%time
df_search_results = pd.concat(
    [pd.read_parquet(f, engine="auto") for f in parquet_file_list],
    ignore_index=True,
).drop_duplicates()
display(df_search_results.head(5).append(df_search_results.tail(5)))
display(
    df_search_results.isna().sum().rename("num_missing").to_frame().merge(
        df_search_results.dtypes.rename("dtype").to_frame(),
        left_index=True,
        right_index=True,
    )
)
# Out:
#       page  request_status_code  listing_counter  \
# 0       50                  200                1
# 1       50                  200                2
# 2       50                  200                3
# 3       50                  200                4
# 4       50                  200                5
# 1245    99                  200               21
# 1246    99                  200               22
# 1247    99                  200               23
# 1248    99                  200               24
# 1249    99                  200               25
#
#                                      title  \
# 0                            Blazing_Sails
# 1               LEGO_Harry_Potter_Years_14
# 2                        Source_of_Madness
# 3                                     Roll
# 4                            Cloud_Gardens
# 1245  Sid_Meiers_Civilization_III_Complete
# 1246              FATE_Undiscovered_Realms
# 1247                            Haven_Park
# 1248                         Peggle_Nights
# 1249               Internet_Cafe_Simulator
#
#                                                     url platform_names  \
# 0     https://store.steampowered.com/app/1158940/Bla...            win
# 1     https://store.steampowered.com/app/21130/LEGO_...            win
# 2     https://store.steampowered.com/app/1315610/Sou...            win
# 3      https://store.steampowered.com/app/1585910/Roll/        win,mac
# 4     https://store.steampowered.com/app/1372320/Clo...        win,mac
# 1245  https://store.steampowered.com/app/3910/Sid_Me...            win
# 1246  https://store.steampowered.com/app/276890/FATE...            win
# 1247  https://store.steampowered.com/app/1549550/Hav...  win,mac,linux
# 1248  https://store.steampowered.com/app/3540/Peggle...        win,mac
# 1249  https://store.steampowered.com/app/1136160/Int...            win
#
#       release_date discount_pct original_price discount_price
# 0      Nov 5, 2020         -30%          14.99          10.49
# 1     Jun 25, 2010         None          19.99           None
# 2     Sep 22, 2021         None          16.99           None
# 3     May 13, 2021         None           4.99           None
# 4      Sep 1, 2021         None          17.99           None
# 1245  Oct 25, 2006         None           4.99           None
# 1246  Apr 17, 2014         None           7.99           None
# 1247   Aug 5, 2021         None           8.99           None
# 1248  Oct 15, 2008         None           4.99           None
# 1249  Oct 25, 2019         -50%           9.99           4.99
#                      num_missing   dtype
# page                           0   int64
# request_status_code            0   int64
# listing_counter                0   int64
# title                          0  object
# url                            0  object
# platform_names                 0  object
# release_date                   0  object
# discount_pct                1180  object
# original_price                 7  object
# discount_price              1180  object
# CPU times: user 152 ms, sys: 21.3 ms, total: 173 ms
# Wall time: 424 ms

# %% [markdown]
# ---

# %% [markdown]
# <a href="./2_selenium.ipynb"><< 2 - Navigating webstore with Selenium webdriver</a>
#
# <span style="float:right">
#     <a href="./4_filter_requests_listings.ipynb">4 - Filter search results scraped with the requests library >></a>
# </span>
