# %% [markdown]
# # Upload data to Cloud Storage

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import os
import re
import time
from glob import glob
from zipfile import ZipFile

from azure.storage.blob import BlobServiceClient
from prefect import Flow, context as prefect_context, task, unmapped

# %% [markdown]
# <a href="table-of-contents"></a>
#
# ## [Table of Contents](#table-of-contents)
# 0. [About](#about)
# 1. [User Inputs](#user-inputs)
# 2. [Create archives from scraped files and Upload to Blob Storage](#create-archives-from-scraped-files-and-upload-to-blob-storage)
#    - 2.1. [Listings](#listings)
#    - 2.2. [Search Results](#search-results)

# %% [markdown]
# <a id="about"></a>
#
# ## 0. [About](#about)

# %% [markdown]
# All scraped single-row CSV files of listings and upto 25-row CSV files of search results are combined into batches, of a desired size and uploaded to [Azure blob storage](https://azure.microsoft.com/en-us/services/storage/blobs/).
#
# A batch of size 12 for the search results will mean that every 12 pages (each page has upto 25 rows of search results) of scraped CSV files will be archived together. A batch of size 1 for the listings will mean that every 1 row of scraped CSV listings will be archived together.
#
# **Requirements**
#
# The following four environment variables should be exported before running this notebook
# - `BLOB_NAME_PREFIX`
#   - for each combined archive to be uploaded (listings and search results), a unique number will be appended to this value
# - `AZURE_STORAGE_ACCOUNT`
# - `AZURE_STORAGE_KEY`
# - `ENDPOINT_SUFFIX`
#
# **Notes**
# 1. This should be done for the raw scraped data only. In this way, subsequent runs of the exploratory data analysis phase of this project can use the following workflow that does not require web-scraping to access any previously downloaded data
#    - download this previously scraped data from cloud storage (`9_*.ipynb`)
#    - cleaning/merging using `6_merge_searches_listings.ipynb`
#    - exploring the data with `7_eda.ipynb`
#
#    In this way, the notebooks responsible for web-scraping (`0_*.ipynb` to `5_*.ipynb`) will not be run.
# 2. The workflow used here is executed using a workflow management tool. This was optional, but has been used here.

# %% [markdown]
# <a id="user-inputs"></a>
#
# ## 1. [User Inputs](#user-inputs)

# %%
PROJ_ROOT_DIR = os.getcwd()

# %%
# Last page number for listings or search results to be archived and uploaded
max_page_num_to_check = 50 + 1

min_page_num_to_check_requests = 50
max_page_num_to_check_requests = 525
max_page_num_to_check_sr_requests = 2235 + 1

# Size of batch of CSV files of scraped listings
page_batch_size = 5
page_batch_size_requests = 25

# Size of batch of CSV files of scraped search results
page_batch_size_sr = 10
page_batch_size_sr_requests = 25

# Suffixes (of filenames) to upload combined archives of listings and
# search results to Azure blob storage
blob_name_suffixes = {
    "listings": 80,
    "search_results": 81,
    "listings_requests": 82,
    "search_results_requests": 83,
}

# %%
data_dir = os.path.join(PROJ_ROOT_DIR, "data")
raw_data_dir = os.path.join(data_dir, "raw")
requests_files_dir = os.path.join(raw_data_dir, "requests")
selenium_files_dir = os.path.join(raw_data_dir, "selenium")

conn_str = (
    "DefaultEndpointsProtocol=https;"
    f"AccountName={os.getenv('AZURE_STORAGE_ACCOUNT')};"
    f"AccountKey={os.getenv('AZURE_STORAGE_KEY')};"
    f"EndpointSuffix={os.getenv('ENDPOINT_SUFFIX')}"
)
blob_name_prefix = os.getenv("BLOB_NAME_PREFIX")

# Selenium - LISTINGS
# - listings on search results pages 2-49 were scraped
# - this list should cover pages 1 to 50, inclusive
# - with a step size of 5, every 5 pages (25 listings per page) will be placed in a separate batch (5, 10, 15, 20, etc.)
d = [
    k + page_batch_size - 1
    for k in range(1, (max_page_num_to_check - 1) + 1, page_batch_size)
]
print(d)

# Selenium - SEARCH RESULTS
# - pages 2-49 of search results were scraped
# - this list should cover pages 1 to 50, inclusive
# - with a step size of 10, every 10 pages (25 listings per page) will be placed in a separate batch
#   - the first batch will cover pages 1 to 10, the second batch covers pages 11 - 20, etc.
d_sr = [
    k + page_batch_size_sr - 1
    for k in range(
        1,
        (max_page_num_to_check - 1) + 1,
        page_batch_size_sr,
    )
]
print(d_sr)

# Requests - LISTINGS
# - listings on search results pages 50-505 were scraped
# - this list should cover pages 50 to 505, inclusive
# - with a step size of 25, every 25 pages (25 listings per page) will be placed in a separate batch (74, 99, 124)
d_requests = [
    k + page_batch_size_requests - 1
    for k in range(
        min_page_num_to_check_requests,
        (max_page_num_to_check_requests - 1) + 1,
        page_batch_size_requests,
    )
]
print(d_requests)

# Requests - SEARCH RESULTS
# - pages 50-2232 of search results were scraped
# - this list should cover pages 50 to 2250, inclusive
# - with a step size of 25, every 25 pages (25 listings per page) will be placed in a separate batch
#   - the first batch will cover pages 50 to (50 + 25) - 1 = 74, the second batch covers pages 75 - 99, etc.
d_sr_requests = [
    k + page_batch_size_sr_requests - 1
    for k in range(
        min_page_num_to_check_requests,
        (max_page_num_to_check_sr_requests - 1) + 1,
        page_batch_size_sr_requests,
    )
]
print(d_sr_requests)
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# [10, 20, 30, 40, 50]
# [74, 99, 124, 149, 174, 199, 224, 249, 274, 299, 324, 349, 374, 399, 424, 449, 474, 499, 524]
# [74, 99, 124, 149, 174, 199, 224, 249, 274, 299, 324, 349, 374, 399, 424, 449, 474, 499, 524, 549, 574, 599, 624, 649, 674, 699, 724, 749, 774, 799, 824, 849, 874, 899, 924, 949, 974, 999, 1024, 1049, 1074, 1099, 1124, 1149, 1174, 1199, 1224, 1249, 1274, 1299, 1324, 1349, 1374, 1399, 1424, 1449, 1474, 1499, 1524, 1549, 1574, 1599, 1624, 1649, 1674, 1699, 1724, 1749, 1774, 1799, 1824, 1849, 1874, 1899, 1924, 1949, 1974, 1999, 2024, 2049, 2074, 2099, 2124, 2149, 2174, 2199, 2224, 2249]

# %%
@task
def get_files_single_page(
    page_num_max,
    search_results_file_list,
    prefix="p",
    file_type="listings",
    step_size=100,
):
    """Create archive."""
    logger = prefect_context.get("logger")
    matching_filepaths = []
    fname = (
        f"batched_{file_type}__{page_num_max-(step_size-1)}_"
        f"{page_num_max}__{time.strftime('%Y%m%d_%H%M%S')}.zip"
    )
    if not os.path.exists(fname):
        for f in search_results_file_list:
            p_str = re.search(fr"{prefix}(\d+)_", f).group(0)
            p_num_str = (
                p_str.replace("_", "").replace("p", "")
                if prefix == "p"
                else p_str.split("_")[-2]
            )
            if step_size == 1:
                if int(p_num_str) == page_num_max:
                    matching_filepaths.append(f)
            else:
                if (page_num_max - step_size) + 1 <= int(p_num_str) <= page_num_max:
                    # print(f)
                    matching_filepaths.append(f)
    logger.info(
        f"Page start = {page_num_max - (step_size - 1)}, "
        f"Page stop = {page_num_max}, "
        f"Files Found = {len(matching_filepaths)}"
    )
    return {fname: matching_filepaths}


@task
def create_archive(files_dict):
    logger = prefect_context.get("logger")
    archives_created = []
    for archive_fname, matching_filepaths in files_dict.items():
        if len(matching_filepaths) > 0:
            with ZipFile(archive_fname, "w") as zip_file:
                for matching in matching_filepaths:
                    zip_file.write(matching)
            archives_created.append(archive_fname)
            logger.info(f"Creating archive {archive_fname}")
        else:
            pass
            logger.info(
                f"Did not find any filepaths for {archive_fname}. "
                "Will not create archive."
            )
    return archives_created


@task
def upload_az_file_blobs(
    blob_names_dict, conn_str, flatten_filepaths=True, az_container_name="myconedesx7"
):
    logger = prefect_context.get("logger")
    if flatten_filepaths:
        blob_names_dict = {k: l for k, v in blob_names_dict.items() for l in v}
    # print(type(blob_names_dict), blob_names_dict)
    blob_service_client = BlobServiceClient.from_connection_string(conn_str=conn_str)
    for az_blob_name, local_file_path in blob_names_dict.items():
        blob_client = blob_service_client.get_blob_client(
            container=az_container_name, blob=az_blob_name
        )
        # print(az_blob_name, local_file_path)
        if not list(
            blob_service_client.get_container_client(az_container_name).list_blobs(
                name_starts_with=az_blob_name
            )
        ):
            with open(local_file_path, "rb") as data:
                blob_client.upload_blob(data)
            logger.info(f"Blob {az_blob_name} not found. Uploaded {local_file_path}.")
        else:
            logger.info(f"Blob {az_blob_name} found. Did not upload {local_file_path}.")

# %% [markdown]
# <a id="create-archives-from-scraped-files-and-upload-to-blob-storage"></a>
#
# ## 2. [Create archives from scraped files and Upload to Blob Storage](#create-archives-from-scraped-files-and-upload-to-blob-storage)

# %% [markdown]
# <a id="selenium-listings"></a>
#
# ### 2.1. [Selenium Listings](#selenium-listings)

# %% [markdown]
# Change into the sub-directory containing the downloaded single-row CSV files with the scraped contents of each listing scraped with `requests`

# %%
os.chdir(selenium_files_dir)
print(f"Current working directory is {os.getcwd()}")
# Out:
# Current working directory is /home/edesz/Downloads/web-scraping/data/raw/selenium

# %% [markdown]
# Create an archive of batches of listings files, where the size of each batch is the difference between successive elements in the list `d` defined earlier

# %%
with Flow("Archive Listings Scraped with Selenium") as flow:
    files = get_files_single_page.map(
        d,
        unmapped(glob("*.csv")),
        unmapped("p"),
        unmapped("listings"),
        unmapped(d[1] - d[0]),
    )
    _ = create_archive.map(files)

state = flow.run()
# Out:
# [2021-10-26 23:28:13-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Archive Listings Scraped with Selenium'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[0] | Page start = 1, Page stop = 5, Files Found = 93
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[1] | Page start = 6, Page stop = 10, Files Found = 107
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[2] | Page start = 11, Page stop = 15, Files Found = 97
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[3] | Page start = 16, Page stop = 20, Files Found = 90
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[4] | Page start = 21, Page stop = 25, Files Found = 88
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[5] | Page start = 26, Page stop = 30, Files Found = 80
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[6] | Page start = 31, Page stop = 35, Files Found = 81
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[7] | Page start = 36, Page stop = 40, Files Found = 86
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[8] | Page start = 41, Page stop = 45, Files Found = 81
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.get_files_single_page[9] | Page start = 46, Page stop = 50, Files Found = 71
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[0] | Creating archive batched_listings__1_5__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[1] | Creating archive batched_listings__6_10__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[2] | Creating archive batched_listings__11_15__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[3] | Creating archive batched_listings__16_20__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[4] | Creating archive batched_listings__21_25__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[5] | Creating archive batched_listings__26_30__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[6] | Creating archive batched_listings__31_35__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[7] | Creating archive batched_listings__36_40__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[8] | Creating archive batched_listings__41_45__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Starting task run...
# [2021-10-26 23:28:13-0400] INFO - prefect.create_archive[9] | Creating archive batched_listings__46_50__20211026_232813.zip
# [2021-10-26 23:28:13-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:13-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded

# %% [markdown]
# Create a single archive with the combination of all batched listings archives created above and upload to Azure blob storage

# %%
with Flow("Combine and Upload Selenium-Based Listings Archives") as flow:
    combined_archive_fname = (
        f"combo_batched_listings__{time.strftime('%Y%m%d_%H%M%S')}.zip"
    )
    combo_archive = create_archive(
        {combined_archive_fname: glob("batched_listings__*.zip")}
    )
    upload_az_file_blobs(
        {f"{blob_name_prefix}{blob_name_suffixes['listings']}": combo_archive},
        conn_str,
        True,
    )

state_combo = flow.run()
# state_combo.result[combo_archive].result
# Out:
# [2021-10-26 23:28:22-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Combine and Upload Selenium-Based Listings Archives'
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:28:22-0400] INFO - prefect.create_archive | Creating archive combo_batched_listings__20211026_232822.zip
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'Dict': Starting task run...
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'Dict': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Starting task run...
# [2021-10-26 23:28:22-0400] INFO - prefect.upload_az_file_blobs | Blob blobedesz80 not found. Uploaded combo_batched_listings__20211026_232822.zip.
# [2021-10-26 23:28:22-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:22-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded

# %% [markdown]
# **Note**
# 1. It seems like this has to be called after the above `Flow`, since Prefect can't handle re-using the same task (here, this would be `create_archive()`) with different inputs ([link](https://github.com/PrefectHQ/prefect/issues/4603)) while also having the second run of the task dependent on the output of the first run.
# 2. An attempt at capturing the output of the first run of the task and feeding it into the second run (thereby forcing the second run to be dependent on the first, by replacing `glob("batched_listings__*.zip")`) did not work. Future work should further investigate this as a workaround for the above.

# %% [markdown]
# <a id="requests-listings"></a>
#
# ### 2.2. [Requests Listings](#requests-listings)

# %% [markdown]
# Change into the sub-directory containing the downloaded single-row CSV files with the scraped contents of each listing scraped with Selenium

# %%
os.chdir(requests_files_dir)
print(f"Current working directory is {os.getcwd()}")
# Out:
# Current working directory is /home/edesz/Downloads/web-scraping/data/raw/requests

# %% [markdown]
# Create an archive of batches of listings files, where the size of each batch is the difference between successive elements in the list `d_requests` defined earlier

# %%
with Flow("Archive Listings Scraped with Requests") as flow:
    files = get_files_single_page.map(
        d_requests,
        unmapped(glob("p*.csv")),
        unmapped("p"),
        unmapped("listings"),
        unmapped(d_requests[1] - d_requests[0]),
    )
    _ = create_archive.map(files)

state = flow.run()
# Out:
# [2021-10-26 23:28:35-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Archive Listings Scraped with Requests'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[0] | Page start = 50, Page stop = 74, Files Found = 613
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[1] | Page start = 75, Page stop = 99, Files Found = 615
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[2] | Page start = 100, Page stop = 124, Files Found = 522
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[3] | Page start = 125, Page stop = 149, Files Found = 606
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[4] | Page start = 150, Page stop = 174, Files Found = 593
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[5] | Page start = 175, Page stop = 199, Files Found = 607
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[6] | Page start = 200, Page stop = 224, Files Found = 609
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[7] | Page start = 225, Page stop = 249, Files Found = 612
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[8] | Page start = 250, Page stop = 274, Files Found = 609
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[9] | Page start = 275, Page stop = 299, Files Found = 611
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[10]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[10] | Page start = 300, Page stop = 324, Files Found = 530
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[10]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[11]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[11] | Page start = 325, Page stop = 349, Files Found = 596
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[11]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[12]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[12] | Page start = 350, Page stop = 374, Files Found = 584
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[12]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[13]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[13] | Page start = 375, Page stop = 399, Files Found = 602
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[13]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[14]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[14] | Page start = 400, Page stop = 424, Files Found = 604
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[14]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[15]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[15] | Page start = 425, Page stop = 449, Files Found = 610
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[15]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[16]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[16] | Page start = 450, Page stop = 474, Files Found = 609
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[16]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[17]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[17] | Page start = 475, Page stop = 499, Files Found = 598
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[17]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[18]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.get_files_single_page[18] | Page start = 500, Page stop = 524, Files Found = 146
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[18]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.create_archive[0] | Creating archive batched_listings__50_74__20211026_232835.zip
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.create_archive[1] | Creating archive batched_listings__75_99__20211026_232835.zip
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.create_archive[2] | Creating archive batched_listings__100_124__20211026_232835.zip
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.create_archive[3] | Creating archive batched_listings__125_149__20211026_232835.zip
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Starting task run...
# [2021-10-26 23:28:35-0400] INFO - prefect.create_archive[4] | Creating archive batched_listings__150_174__20211026_232835.zip
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:35-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[5] | Creating archive batched_listings__175_199__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[6] | Creating archive batched_listings__200_224__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[7] | Creating archive batched_listings__225_249__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[8] | Creating archive batched_listings__250_274__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[9] | Creating archive batched_listings__275_299__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[10]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[10] | Creating archive batched_listings__300_324__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[10]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[11]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[11] | Creating archive batched_listings__325_349__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[11]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[12]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[12] | Creating archive batched_listings__350_374__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[12]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[13]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[13] | Creating archive batched_listings__375_399__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[13]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[14]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[14] | Creating archive batched_listings__400_424__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[14]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[15]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[15] | Creating archive batched_listings__425_449__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[15]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[16]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[16] | Creating archive batched_listings__450_474__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[16]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[17]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[17] | Creating archive batched_listings__475_499__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[17]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[18]': Starting task run...
# [2021-10-26 23:28:36-0400] INFO - prefect.create_archive[18] | Creating archive batched_listings__500_524__20211026_232835.zip
# [2021-10-26 23:28:36-0400] INFO - prefect.TaskRunner | Task 'create_archive[18]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:28:36-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded

# %% [markdown]
# Create a single archive with the combination of all batched listings archives created above and upload to Azure blob storage

# %%
with Flow("Combine and Upload Requests-Based Listings Archives") as flow:
    combined_archive_fname = (
        f"combo_batched_listings__{time.strftime('%Y%m%d_%H%M%S')}.zip"
    )
    combo_archive = create_archive(
        {combined_archive_fname: glob("batched_listings__*.zip")}
    )
    upload_az_file_blobs(
        {f"{blob_name_prefix}{blob_name_suffixes['listings_requests']}": combo_archive},
        conn_str,
        True,
    )

state_combo = flow.run()
# state_combo.result[combo_archive].result
# Out:
# [2021-10-26 23:29:00-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Combine and Upload Requests-Based Listings Archives'
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:29:00-0400] INFO - prefect.create_archive | Creating archive combo_batched_listings__20211026_232900.zip
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'Dict': Starting task run...
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'Dict': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:00-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Starting task run...
# [2021-10-26 23:29:01-0400] INFO - prefect.upload_az_file_blobs | Blob blobedesz82 not found. Uploaded combo_batched_listings__20211026_232900.zip.
# [2021-10-26 23:29:01-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:01-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded

# %% [markdown]
# <a id="selenium-search-results"></a>
#
# ### 2.3. [Selenium Search Results](#selenium-search-results)

# %% [markdown]
# Change into the sub-directory containing the downloaded single-row CSV files with the scraped contents of each listing scraped with Selenium

# %%
os.chdir(selenium_files_dir)
print(f"Current working directory is {os.getcwd()}")
# Out:
# Current working directory is /home/edesz/Downloads/web-scraping/data/raw/selenium

# %% [markdown]
# Create an archive of batches of search results files, where the size of each batch is the difference between successive elements in the list `d_sr` defined earlier

# %%
# %%time
with Flow("Archive Search Results Pages Scraped with Selenium") as flow:
    files = get_files_single_page.map(
        d_sr,
        unmapped(glob("*.parquet.gzip")),
        unmapped("search_results_page_"),
        unmapped("search_results"),
        unmapped(d_sr[1] - d_sr[0]),
    )
    _ = create_archive.map(files)

state_sr = flow.run()
# Out:
# [2021-10-26 23:29:27-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Archive Search Results Pages Scraped with Selenium'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.get_files_single_page[0] | Page start = 1, Page stop = 10, Files Found = 9
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.get_files_single_page[1] | Page start = 11, Page stop = 20, Files Found = 10
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.get_files_single_page[2] | Page start = 21, Page stop = 30, Files Found = 10
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.get_files_single_page[3] | Page start = 31, Page stop = 40, Files Found = 10
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.get_files_single_page[4] | Page start = 41, Page stop = 50, Files Found = 10
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Starting task run...
# [2021-10-26 23:29:27-0400] INFO - prefect.create_archive[0] | Creating archive batched_search_results__1_10__20211026_232927.zip
# [2021-10-26 23:29:27-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Starting task run...
# [2021-10-26 23:29:28-0400] INFO - prefect.create_archive[1] | Creating archive batched_search_results__11_20__20211026_232927.zip
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Starting task run...
# [2021-10-26 23:29:28-0400] INFO - prefect.create_archive[2] | Creating archive batched_search_results__21_30__20211026_232927.zip
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Starting task run...
# [2021-10-26 23:29:28-0400] INFO - prefect.create_archive[3] | Creating archive batched_search_results__31_40__20211026_232927.zip
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Starting task run...
# [2021-10-26 23:29:28-0400] INFO - prefect.create_archive[4] | Creating archive batched_search_results__41_50__20211026_232927.zip
# [2021-10-26 23:29:28-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:28-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# CPU times: user 267 ms, sys: 7.68 ms, total: 275 ms
# Wall time: 268 ms

# %% [markdown]
# Create a single archive with the combination of all batched search results archives created above and upload to Azure blob storage

# %%
# %%time
with Flow("Combine and Upload Selenium-Based Search Results Archives") as flow:
    combined_archive_fname = (
        f"combo_batched_search_results__{time.strftime('%Y%m%d_%H%M%S')}.zip"
    )
    combo_archive = create_archive({combined_archive_fname: glob("batched_search_results__*.zip")})
    upload_az_file_blobs(
        {f"{blob_name_prefix}{blob_name_suffixes['search_results']}": combo_archive}, conn_str, True
    )

state_sr_combo = flow.run()
# state_sr_combo.result[combo_archive].result
# Out:
# [2021-10-26 23:29:46-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Combine and Upload Selenium-Based Search Results Archives'
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:29:46-0400] INFO - prefect.create_archive | Creating archive combo_batched_search_results__20211026_232946.zip
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'Dict': Starting task run...
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'Dict': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:46-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Starting task run...
# [2021-10-26 23:29:47-0400] INFO - prefect.upload_az_file_blobs | Blob blobedesz81 not found. Uploaded combo_batched_search_results__20211026_232946.zip.
# [2021-10-26 23:29:47-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Finished task run for task with final state: 'Success'
# [2021-10-26 23:29:47-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# CPU times: user 124 ms, sys: 11.3 ms, total: 136 ms
# Wall time: 435 ms

# %% [markdown]
# <a id="requests-search-results"></a>
#
# ### 2.4. [Requests Search Results](#requests-search-results)

# %% [markdown]
# Change into the sub-directory containing the downloaded single-row CSV files with the scraped contents of each listing scraped with `requests`

# %%
os.chdir(requests_files_dir)
print(f"Current working directory is {os.getcwd()}")
# Out:
# Current working directory is /home/edesz/Downloads/web-scraping/data/raw/requests

# %% [markdown]
# Create an archive of batches of search results files, where the size of each batch is the difference between successive elements in the list `d_sr` defined earlier

# %%
# %%time
with Flow("Archive Search Results Pages Scraped with Requests") as flow:
    files = get_files_single_page.map(
        d_sr_requests,
        unmapped(glob("search_results_page_*.parquet.gzip")),
        unmapped("search_results_page_"),
        unmapped("search_results"),
        unmapped(d_sr_requests[1] - d_sr_requests[0]),
    )
    _ = create_archive.map(files)

state_sr = flow.run()
# Out:
# [2021-10-26 23:30:03-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Archive Search Results Pages Scraped with Requests'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[0] | Page start = 50, Page stop = 74, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[1] | Page start = 75, Page stop = 99, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[2] | Page start = 100, Page stop = 124, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[3] | Page start = 125, Page stop = 149, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[4] | Page start = 150, Page stop = 174, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[5] | Page start = 175, Page stop = 199, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[6] | Page start = 200, Page stop = 224, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[7] | Page start = 225, Page stop = 249, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[8] | Page start = 250, Page stop = 274, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[9] | Page start = 275, Page stop = 299, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[10]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[10] | Page start = 300, Page stop = 324, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[10]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[11]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[11] | Page start = 325, Page stop = 349, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[11]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[12]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[12] | Page start = 350, Page stop = 374, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[12]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[13]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[13] | Page start = 375, Page stop = 399, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[13]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[14]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[14] | Page start = 400, Page stop = 424, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[14]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[15]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[15] | Page start = 425, Page stop = 449, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[15]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[16]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[16] | Page start = 450, Page stop = 474, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[16]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[17]': Starting task run...
# [2021-10-26 23:30:03-0400] INFO - prefect.get_files_single_page[17] | Page start = 475, Page stop = 499, Files Found = 25
# [2021-10-26 23:30:03-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[17]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[18]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[18] | Page start = 500, Page stop = 524, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[18]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[19]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[19] | Page start = 525, Page stop = 549, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[19]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[20]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[20] | Page start = 550, Page stop = 574, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[20]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[21]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[21] | Page start = 575, Page stop = 599, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[21]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[22]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[22] | Page start = 600, Page stop = 624, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[22]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[23]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[23] | Page start = 625, Page stop = 649, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[23]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[24]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[24] | Page start = 650, Page stop = 674, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[24]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[25]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[25] | Page start = 675, Page stop = 699, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[25]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[26]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[26] | Page start = 700, Page stop = 724, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[26]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[27]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[27] | Page start = 725, Page stop = 749, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[27]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[28]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[28] | Page start = 750, Page stop = 774, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[28]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[29]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[29] | Page start = 775, Page stop = 799, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[29]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[30]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[30] | Page start = 800, Page stop = 824, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[30]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[31]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[31] | Page start = 825, Page stop = 849, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[31]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[32]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[32] | Page start = 850, Page stop = 874, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[32]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[33]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[33] | Page start = 875, Page stop = 899, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[33]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[34]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[34] | Page start = 900, Page stop = 924, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[34]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[35]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[35] | Page start = 925, Page stop = 949, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[35]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[36]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[36] | Page start = 950, Page stop = 974, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[36]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[37]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[37] | Page start = 975, Page stop = 999, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[37]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[38]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[38] | Page start = 1000, Page stop = 1024, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[38]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[39]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[39] | Page start = 1025, Page stop = 1049, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[39]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[40]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[40] | Page start = 1050, Page stop = 1074, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[40]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[41]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[41] | Page start = 1075, Page stop = 1099, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[41]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[42]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[42] | Page start = 1100, Page stop = 1124, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[42]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[43]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[43] | Page start = 1125, Page stop = 1149, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[43]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[44]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[44] | Page start = 1150, Page stop = 1174, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[44]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[45]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[45] | Page start = 1175, Page stop = 1199, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[45]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[46]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[46] | Page start = 1200, Page stop = 1224, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[46]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[47]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[47] | Page start = 1225, Page stop = 1249, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[47]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[48]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[48] | Page start = 1250, Page stop = 1274, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[48]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[49]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[49] | Page start = 1275, Page stop = 1299, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[49]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[50]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[50] | Page start = 1300, Page stop = 1324, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[50]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[51]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[51] | Page start = 1325, Page stop = 1349, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[51]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[52]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[52] | Page start = 1350, Page stop = 1374, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[52]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[53]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[53] | Page start = 1375, Page stop = 1399, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[53]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[54]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[54] | Page start = 1400, Page stop = 1424, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[54]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[55]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[55] | Page start = 1425, Page stop = 1449, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[55]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[56]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[56] | Page start = 1450, Page stop = 1474, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[56]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[57]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[57] | Page start = 1475, Page stop = 1499, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[57]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[58]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[58] | Page start = 1500, Page stop = 1524, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[58]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[59]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[59] | Page start = 1525, Page stop = 1549, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[59]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[60]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[60] | Page start = 1550, Page stop = 1574, Files Found = 25
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[60]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:04-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[61]': Starting task run...
# [2021-10-26 23:30:04-0400] INFO - prefect.get_files_single_page[61] | Page start = 1575, Page stop = 1599, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[61]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[62]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[62] | Page start = 1600, Page stop = 1624, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[62]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[63]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[63] | Page start = 1625, Page stop = 1649, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[63]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[64]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[64] | Page start = 1650, Page stop = 1674, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[64]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[65]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[65] | Page start = 1675, Page stop = 1699, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[65]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[66]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[66] | Page start = 1700, Page stop = 1724, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[66]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[67]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[67] | Page start = 1725, Page stop = 1749, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[67]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[68]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[68] | Page start = 1750, Page stop = 1774, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[68]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[69]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[69] | Page start = 1775, Page stop = 1799, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[69]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[70]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[70] | Page start = 1800, Page stop = 1824, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[70]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[71]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[71] | Page start = 1825, Page stop = 1849, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[71]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[72]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[72] | Page start = 1850, Page stop = 1874, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[72]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[73]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[73] | Page start = 1875, Page stop = 1899, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[73]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[74]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[74] | Page start = 1900, Page stop = 1924, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[74]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[75]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[75] | Page start = 1925, Page stop = 1949, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[75]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[76]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[76] | Page start = 1950, Page stop = 1974, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[76]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[77]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[77] | Page start = 1975, Page stop = 1999, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[77]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[78]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[78] | Page start = 2000, Page stop = 2024, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[78]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[79]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[79] | Page start = 2025, Page stop = 2049, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[79]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[80]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[80] | Page start = 2050, Page stop = 2074, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[80]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[81]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[81] | Page start = 2075, Page stop = 2099, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[81]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[82]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[82] | Page start = 2100, Page stop = 2124, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[82]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[83]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[83] | Page start = 2125, Page stop = 2149, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[83]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[84]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[84] | Page start = 2150, Page stop = 2174, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[84]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[85]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[85] | Page start = 2175, Page stop = 2199, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[85]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[86]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[86] | Page start = 2200, Page stop = 2224, Files Found = 25
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[86]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[87]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.get_files_single_page[87] | Page start = 2225, Page stop = 2249, Files Found = 8
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'get_files_single_page[87]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Mapped'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[0] | Creating archive batched_search_results__50_74__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[0]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[1] | Creating archive batched_search_results__75_99__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[1]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[2] | Creating archive batched_search_results__100_124__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[2]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[3] | Creating archive batched_search_results__125_149__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[3]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[4] | Creating archive batched_search_results__150_174__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[4]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[5] | Creating archive batched_search_results__175_199__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[5]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[6] | Creating archive batched_search_results__200_224__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[6]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[7] | Creating archive batched_search_results__225_249__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[7]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[8] | Creating archive batched_search_results__250_274__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[8]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[9] | Creating archive batched_search_results__275_299__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[9]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[10]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[10] | Creating archive batched_search_results__300_324__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[10]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[11]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[11] | Creating archive batched_search_results__325_349__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[11]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[12]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[12] | Creating archive batched_search_results__350_374__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[12]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[13]': Starting task run...
# [2021-10-26 23:30:05-0400] INFO - prefect.create_archive[13] | Creating archive batched_search_results__375_399__20211026_233003.zip
# [2021-10-26 23:30:05-0400] INFO - prefect.TaskRunner | Task 'create_archive[13]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[14]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[14] | Creating archive batched_search_results__400_424__20211026_233003.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[14]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[15]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[15] | Creating archive batched_search_results__425_449__20211026_233003.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[15]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[16]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[16] | Creating archive batched_search_results__450_474__20211026_233003.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[16]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[17]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[17] | Creating archive batched_search_results__475_499__20211026_233003.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[17]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[18]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[18] | Creating archive batched_search_results__500_524__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[18]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[19]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[19] | Creating archive batched_search_results__525_549__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[19]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[20]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[20] | Creating archive batched_search_results__550_574__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[20]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[21]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[21] | Creating archive batched_search_results__575_599__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[21]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[22]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[22] | Creating archive batched_search_results__600_624__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[22]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[23]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[23] | Creating archive batched_search_results__625_649__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[23]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[24]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[24] | Creating archive batched_search_results__650_674__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[24]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[25]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[25] | Creating archive batched_search_results__675_699__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[25]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[26]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[26] | Creating archive batched_search_results__700_724__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[26]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[27]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[27] | Creating archive batched_search_results__725_749__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[27]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[28]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[28] | Creating archive batched_search_results__750_774__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[28]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[29]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[29] | Creating archive batched_search_results__775_799__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[29]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[30]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[30] | Creating archive batched_search_results__800_824__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[30]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[31]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[31] | Creating archive batched_search_results__825_849__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[31]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[32]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[32] | Creating archive batched_search_results__850_874__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[32]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[33]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[33] | Creating archive batched_search_results__875_899__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[33]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[34]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[34] | Creating archive batched_search_results__900_924__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[34]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[35]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[35] | Creating archive batched_search_results__925_949__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[35]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[36]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[36] | Creating archive batched_search_results__950_974__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[36]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[37]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[37] | Creating archive batched_search_results__975_999__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[37]': Finished task run for task with final state: 'Success'
# ...
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[46]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[46] | Creating archive batched_search_results__1200_1224__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[46]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[47]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[47] | Creating archive batched_search_results__1225_1249__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[47]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[48]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[48] | Creating archive batched_search_results__1250_1274__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[48]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[49]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[49] | Creating archive batched_search_results__1275_1299__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[49]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[50]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[50] | Creating archive batched_search_results__1300_1324__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[50]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[51]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[51] | Creating archive batched_search_results__1325_1349__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[51]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[52]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[52] | Creating archive batched_search_results__1350_1374__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[52]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[53]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[53] | Creating archive batched_search_results__1375_1399__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[53]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[54]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[54] | Creating archive batched_search_results__1400_1424__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[54]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[55]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[55] | Creating archive batched_search_results__1425_1449__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[55]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[56]': Starting task run...
# [2021-10-26 23:30:06-0400] INFO - prefect.create_archive[56] | Creating archive batched_search_results__1450_1474__20211026_233004.zip
# [2021-10-26 23:30:06-0400] INFO - prefect.TaskRunner | Task 'create_archive[56]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[57]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[57] | Creating archive batched_search_results__1475_1499__20211026_233004.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[57]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[58]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[58] | Creating archive batched_search_results__1500_1524__20211026_233004.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[58]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[59]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[59] | Creating archive batched_search_results__1525_1549__20211026_233004.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[59]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[60]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[60] | Creating archive batched_search_results__1550_1574__20211026_233004.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[60]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[61]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[61] | Creating archive batched_search_results__1575_1599__20211026_233004.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[61]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[62]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[62] | Creating archive batched_search_results__1600_1624__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[62]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[63]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[63] | Creating archive batched_search_results__1625_1649__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[63]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[64]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[64] | Creating archive batched_search_results__1650_1674__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[64]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[65]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[65] | Creating archive batched_search_results__1675_1699__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[65]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[66]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[66] | Creating archive batched_search_results__1700_1724__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[66]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[67]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[67] | Creating archive batched_search_results__1725_1749__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[67]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[68]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[68] | Creating archive batched_search_results__1750_1774__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[68]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[69]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[69] | Creating archive batched_search_results__1775_1799__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[69]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[70]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[70] | Creating archive batched_search_results__1800_1824__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[70]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[71]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[71] | Creating archive batched_search_results__1825_1849__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[71]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[72]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[72] | Creating archive batched_search_results__1850_1874__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[72]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[73]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[73] | Creating archive batched_search_results__1875_1899__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[73]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[74]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[74] | Creating archive batched_search_results__1900_1924__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[74]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[75]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[75] | Creating archive batched_search_results__1925_1949__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[75]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[76]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[76] | Creating archive batched_search_results__1950_1974__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[76]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[77]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[77] | Creating archive batched_search_results__1975_1999__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[77]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[78]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[78] | Creating archive batched_search_results__2000_2024__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[78]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[79]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[79] | Creating archive batched_search_results__2025_2049__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[79]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[80]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[80] | Creating archive batched_search_results__2050_2074__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[80]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[81]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[81] | Creating archive batched_search_results__2075_2099__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[81]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[82]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[82] | Creating archive batched_search_results__2100_2124__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[82]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[83]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[83] | Creating archive batched_search_results__2125_2149__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[83]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[84]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[84] | Creating archive batched_search_results__2150_2174__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[84]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[85]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[85] | Creating archive batched_search_results__2175_2199__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[85]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[86]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[86] | Creating archive batched_search_results__2200_2224__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[86]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[87]': Starting task run...
# [2021-10-26 23:30:07-0400] INFO - prefect.create_archive[87] | Creating archive batched_search_results__2225_2249__20211026_233005.zip
# [2021-10-26 23:30:07-0400] INFO - prefect.TaskRunner | Task 'create_archive[87]': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:07-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# CPU times: user 4.24 s, sys: 138 ms, total: 4.38 s
# Wall time: 4.28 s

# %% [markdown]
# Create a single archive with the combination of all batched search results archives created above and upload to Azure blob storage

# %%
# %%time
with Flow("Combine and Upload Requests-Based Search Results Archives") as flow:
    combined_archive_fname = (
        f"combo_batched_search_results__{time.strftime('%Y%m%d_%H%M%S')}.zip"
    )
    combo_archive = create_archive({combined_archive_fname: glob("batched_search_results__*.zip")})
    upload_az_file_blobs(
        {f"{blob_name_prefix}{blob_name_suffixes['search_results_requests']}": combo_archive}, conn_str, True
    )

state_sr_combo = flow.run()
# state_sr_combo.result[combo_archive].result
# Out:
# [2021-10-26 23:30:46-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'Combine and Upload Requests-Based Search Results Archives'
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'create_archive': Starting task run...
# [2021-10-26 23:30:46-0400] INFO - prefect.create_archive | Creating archive combo_batched_search_results__20211026_233046.zip
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'create_archive': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'Dict': Starting task run...
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'Dict': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:46-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Starting task run...
# [2021-10-26 23:30:47-0400] INFO - prefect.upload_az_file_blobs | Blob blobedesz83 not found. Uploaded combo_batched_search_results__20211026_233046.zip.
# [2021-10-26 23:30:47-0400] INFO - prefect.TaskRunner | Task 'upload_az_file_blobs': Finished task run for task with final state: 'Success'
# [2021-10-26 23:30:47-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# CPU times: user 175 ms, sys: 28.6 ms, total: 203 ms
# Wall time: 1.59 s

# %% [markdown]
# ---

# %% [markdown]
# <span style="float:left">
#     <a href="./7_eda.ipynb"><< 7 - Exploratory Data Analysis</a>
# </span>
#
# <span style="float:right">
#     <a href="./9_download_cloud.ipynb">9 - Download all scraped data (with requests and selenium) from cloud storage >></a>
# </span>
