# %% [markdown]
# # Merging scraped Search Results with scraped Listings

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import Python modules

# %%
import os
from glob import glob

import pandas as pd

# %% [markdown]
# Import any custom modules

# %%
# %aimport src.utils
from src.utils import (
    show_df,  # Display first and last n rows of a DataFrame
    show_df_dtypes_nans,  # Show the missing values and column datatypes side-by-side
)

# %% [markdown]
# <a href="table-of-contents"></a>
#
# ## [Table of Contents](#table-of-contents)
# 0. [About](#about)
# 1. [User Inputs](#user-inputs)
# 2. [Combine `selenium`-based files](#combine-`selenium`-based-files)
#    - 2.1. [Load and Process all Listings files acquired using `selenium`](#load-and-process-all-listings-files-acquired-using-`selenium`)
#    - 2.2. [Load and Process all Search Results files acquired using `selenium`](#load-and-process-all-search-results-files-acquired-using-`selenium`)
#    - 2.3. [Merge with Price from Search Results dataset acquired using `selenium`](#merge-with-price-from-search-results-dataset-acquired-using-`selenium`)
# 3. [Combine `requests`-based files](#combine-`requests`-based-files)
#    - 3.1. [Load and Process all Search Results files acquired using `requests`](#load-and-process-all-search-results-files-acquired-using-`requests`)
#    - 3.2. [Load and Process all Listings files acquired using `requests`](#load-and-process-all-listings-files-acquired-using-`requests`)
#    - 3.3. [Merge with Price from Search Results dataset acquired using `requests`](#merge-with-price-from-search-results-dataset-acquired-using-`requests`)
# 4. [Export combined dataset to disk](#export-combined-dataset-to-disk)

# %% [markdown]
# <a id="about"></a>
#
# ## 0. [About](#about)

# %% [markdown]
# In this notebook, we'll combine the search results and listings datasets scraped separately with `selenium` and `requests`. The combined dataset will then be processed (for example, to remove duplicate listings) and then exported to a single CSV file that can be used in further analysis.

# %% [markdown]
# <a id="user-inputs"></a>
#
# ## 1. [User Inputs](#user-inputs)

# %% [markdown]
# Define variables that can be changed when running this notebook

# %%
PROJ_ROOT_DIR = os.getcwd()

# %%
proc_data_filename = "processed_data.csv"

# %%
# Path to data/raw
data_dir = os.path.join(PROJ_ROOT_DIR, "data")
raw_data_dir = os.path.join(data_dir, "raw")
# Path to data/processed
processed_data_dir = os.path.join(data_dir, "processed")

# Path to processed data file to be created as combination of datasets
# scraped with selenium and requests
processed_data_filepath = os.path.join(processed_data_dir, proc_data_filename)

# Path to data/raw/requests
requests_files_dir = os.path.join(raw_data_dir, "requests")

# Path to data/raw/selenium
selenium_files_dir = os.path.join(raw_data_dir, "selenium")

# List of listings CSV files created using requests
fpaths_requests = glob(os.path.join(requests_files_dir, "p*_*.csv"))

# List of listings CSV files created using selenium
fpaths_selenium = glob(os.path.join(selenium_files_dir, "p*_*.csv"))

# List of search results files created by Selenium
selenium_search_results_pages = glob(
    os.path.join(selenium_files_dir, "search_results_page_*_*.parquet.gzip")
)

# List of search results files created by requests
requests_search_results_pages = glob(
    os.path.join(requests_files_dir, "search_results_page_*_*.parquet.gzip")
)

# %% [markdown]
# <a id="combine-`selenium`-based-files"></a>
#
# ## 2. [Combine `selenium`-based files](#combine-`selenium`-based-files)

# %% [markdown]
# <a id="load-and-process-all-listings-files-acquired-using-`selenium`"></a>
#
# ### 2.1. [Load and Process all Listings files acquired using `selenium`](#load-and-process-all-listings-files-acquired-using-`selenium`)

# %% [markdown]
# We'll start by loading the listings scraped using Selenium. As discussed in `4_filter_requests_listings.ipynb`, we can merge listings with the search results acquired using Selenium on the `Title` column. So, we'll drop any rows with a missing value in the `Title` column. Finally, we'll sort the dataset by page and listing number

# %%
# %%time
df_listings_sel = pd.concat(
    [
        pd.read_csv(fpath)
        for fpath in fpaths_selenium
    ],
    ignore_index=True,
).dropna(subset=["Title"]).sort_values(by=["page_num", "listing_num"]).reset_index(drop=True)
print(len(df_listings_sel))
show_df(df_listings_sel, 1)
show_df_dtypes_nans(df_listings_sel)
# Out:
# 817
# <style type="text/css">
# </style>
# <table id="T_b2ebe_">
#   <caption>First & Last 1 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >review_type_all</th>
#       <th class="col_heading level0 col1" >overall_review_rating</th>
#       <th class="col_heading level0 col2" >pct_overall</th>
#       <th class="col_heading level0 col3" >pct_overall_threshold</th>
#       <th class="col_heading level0 col4" >pct_overall_lang</th>
#       <th class="col_heading level0 col5" >pct_overall_threshold_lang</th>
#       <th class="col_heading level0 col6" >platforms</th>
#       <th class="col_heading level0 col7" >user_defined_tags</th>
#       <th class="col_heading level0 col8" >num_steam_achievements</th>
#       <th class="col_heading level0 col9" >drm</th>
#       <th class="col_heading level0 col10" >rating</th>
#       <th class="col_heading level0 col11" >rating_descriptors</th>
#       <th class="col_heading level0 col12" >review_type_positive</th>
#       <th class="col_heading level0 col13" >review_type_negative</th>
#       <th class="col_heading level0 col14" >review_language_mine</th>
#       <th class="col_heading level0 col15" >Title</th>
#       <th class="col_heading level0 col16" >Genre</th>
#       <th class="col_heading level0 col17" >Release Date</th>
#       <th class="col_heading level0 col18" >Early Access Release Date</th>
#       <th class="col_heading level0 col19" >Developer</th>
#       <th class="col_heading level0 col20" >Publisher</th>
#       <th class="col_heading level0 col21" >Franchise</th>
#       <th class="col_heading level0 col22" >languages</th>
#       <th class="col_heading level0 col23" >num_languages</th>
#       <th class="col_heading level0 col24" >page_num</th>
#       <th class="col_heading level0 col25" >listing_num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2ebe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2ebe_row0_col0" class="data row0 col0" >1014.000000</td>
#       <td id="T_b2ebe_row0_col1" class="data row0 col1" >Very Positive</td>
#       <td id="T_b2ebe_row0_col2" class="data row0 col2" >93.000000</td>
#       <td id="T_b2ebe_row0_col3" class="data row0 col3" >positive</td>
#       <td id="T_b2ebe_row0_col4" class="data row0 col4" >92.000000</td>
#       <td id="T_b2ebe_row0_col5" class="data row0 col5" >positive</td>
#       <td id="T_b2ebe_row0_col6" class="data row0 col6" >win</td>
#       <td id="T_b2ebe_row0_col7" class="data row0 col7" >Base Building, Strategy, Survival, Tower Defense, Hack and Slash, Action RPG, Crafting, Adventure, Simulation, RPG, Sci-fi, Resource Management, Exploration, Loot, Isometric, Building, Sandbox, Atmospheric, Action, Aliens</td>
#       <td id="T_b2ebe_row0_col8" class="data row0 col8" >30.000000</td>
#       <td id="T_b2ebe_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_b2ebe_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_b2ebe_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_b2ebe_row0_col12" class="data row0 col12" >938.000000</td>
#       <td id="T_b2ebe_row0_col13" class="data row0 col13" >76.000000</td>
#       <td id="T_b2ebe_row0_col14" class="data row0 col14" >412.000000</td>
#       <td id="T_b2ebe_row0_col15" class="data row0 col15" >The Riftbreaker</td>
#       <td id="T_b2ebe_row0_col16" class="data row0 col16" >Action, Adventure, Indie, RPG, Simulation, Strategy</td>
#       <td id="T_b2ebe_row0_col17" class="data row0 col17" >14 Oct, 2021</td>
#       <td id="T_b2ebe_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_b2ebe_row0_col19" class="data row0 col19" >EXOR Studios</td>
#       <td id="T_b2ebe_row0_col20" class="data row0 col20" >EXOR Studios, Surefire.Games</td>
#       <td id="T_b2ebe_row0_col21" class="data row0 col21" >EXOR Studios, surefiregames</td>
#       <td id="T_b2ebe_row0_col22" class="data row0 col22" >English, French, German, Spanish - Spain, Japanese, Korean, Polish, Russian, Simplified Chinese, Portuguese - Brazil</td>
#       <td id="T_b2ebe_row0_col23" class="data row0 col23" >10.000000</td>
#       <td id="T_b2ebe_row0_col24" class="data row0 col24" >2</td>
#       <td id="T_b2ebe_row0_col25" class="data row0 col25" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b2ebe_level0_row1" class="row_heading level0 row1" >816</th>
#       <td id="T_b2ebe_row1_col0" class="data row1 col0" >3787.000000</td>
#       <td id="T_b2ebe_row1_col1" class="data row1 col1" >Very Positive</td>
#       <td id="T_b2ebe_row1_col2" class="data row1 col2" >79.000000</td>
#       <td id="T_b2ebe_row1_col3" class="data row1 col3" >positive</td>
#       <td id="T_b2ebe_row1_col4" class="data row1 col4" >76.000000</td>
#       <td id="T_b2ebe_row1_col5" class="data row1 col5" >positive</td>
#       <td id="T_b2ebe_row1_col6" class="data row1 col6" >win</td>
#       <td id="T_b2ebe_row1_col7" class="data row1 col7" >Simulation, Casual, Indie, Singleplayer, Adventure, Life Sim, Nudity, Strategy, Open World, Sexual Content, First-Person, Action, Realistic, Funny, Hacking, Sandbox, Immersive Sim, Walking Simulator, Replay Value, Atmospheric</td>
#       <td id="T_b2ebe_row1_col8" class="data row1 col8" >15.000000</td>
#       <td id="T_b2ebe_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_b2ebe_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_b2ebe_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_b2ebe_row1_col12" class="data row1 col12" >2988.000000</td>
#       <td id="T_b2ebe_row1_col13" class="data row1 col13" >799.000000</td>
#       <td id="T_b2ebe_row1_col14" class="data row1 col14" >1010.000000</td>
#       <td id="T_b2ebe_row1_col15" class="data row1 col15" >Streamer Life Simulator</td>
#       <td id="T_b2ebe_row1_col16" class="data row1 col16" >Action, Adventure, Casual, Indie, Simulation, Strategy</td>
#       <td id="T_b2ebe_row1_col17" class="data row1 col17" >21 Aug, 2020</td>
#       <td id="T_b2ebe_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_b2ebe_row1_col19" class="data row1 col19" >Cheesecake Dev</td>
#       <td id="T_b2ebe_row1_col20" class="data row1 col20" >Cheesecake Dev</td>
#       <td id="T_b2ebe_row1_col21" class="data row1 col21" >Cheesecake Dev</td>
#       <td id="T_b2ebe_row1_col22" class="data row1 col22" >English, French, German, Spanish - Spain, Simplified Chinese, Japanese, Polish, Portuguese, Russian, Turkish</td>
#       <td id="T_b2ebe_row1_col23" class="data row1 col23" >10.000000</td>
#       <td id="T_b2ebe_row1_col24" class="data row1 col24" >50</td>
#       <td id="T_b2ebe_row1_col25" class="data row1 col25" >23</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_33d48_">
#   <caption>Column Datatypes and Missing Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_missing</th>
#       <th class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33d48_level0_row0" class="row_heading level0 row0" >review_type_all</th>
#       <td id="T_33d48_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_33d48_row0_col1" class="data row0 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row1" class="row_heading level0 row1" >overall_review_rating</th>
#       <td id="T_33d48_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_33d48_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row2" class="row_heading level0 row2" >pct_overall</th>
#       <td id="T_33d48_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_33d48_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row3" class="row_heading level0 row3" >pct_overall_threshold</th>
#       <td id="T_33d48_row3_col0" class="data row3 col0" >13</td>
#       <td id="T_33d48_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row4" class="row_heading level0 row4" >pct_overall_lang</th>
#       <td id="T_33d48_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_33d48_row4_col1" class="data row4 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row5" class="row_heading level0 row5" >pct_overall_threshold_lang</th>
#       <td id="T_33d48_row5_col0" class="data row5 col0" >14</td>
#       <td id="T_33d48_row5_col1" class="data row5 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row6" class="row_heading level0 row6" >platforms</th>
#       <td id="T_33d48_row6_col0" class="data row6 col0" >29</td>
#       <td id="T_33d48_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row7" class="row_heading level0 row7" >user_defined_tags</th>
#       <td id="T_33d48_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_33d48_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row8" class="row_heading level0 row8" >num_steam_achievements</th>
#       <td id="T_33d48_row8_col0" class="data row8 col0" >183</td>
#       <td id="T_33d48_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row9" class="row_heading level0 row9" >drm</th>
#       <td id="T_33d48_row9_col0" class="data row9 col0" >551</td>
#       <td id="T_33d48_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row10" class="row_heading level0 row10" >rating</th>
#       <td id="T_33d48_row10_col0" class="data row10 col0" >411</td>
#       <td id="T_33d48_row10_col1" class="data row10 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row11" class="row_heading level0 row11" >rating_descriptors</th>
#       <td id="T_33d48_row11_col0" class="data row11 col0" >454</td>
#       <td id="T_33d48_row11_col1" class="data row11 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row12" class="row_heading level0 row12" >review_type_positive</th>
#       <td id="T_33d48_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_33d48_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row13" class="row_heading level0 row13" >review_type_negative</th>
#       <td id="T_33d48_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_33d48_row13_col1" class="data row13 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row14" class="row_heading level0 row14" >review_language_mine</th>
#       <td id="T_33d48_row14_col0" class="data row14 col0" >13</td>
#       <td id="T_33d48_row14_col1" class="data row14 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row15" class="row_heading level0 row15" >Title</th>
#       <td id="T_33d48_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_33d48_row15_col1" class="data row15 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row16" class="row_heading level0 row16" >Genre</th>
#       <td id="T_33d48_row16_col0" class="data row16 col0" >3</td>
#       <td id="T_33d48_row16_col1" class="data row16 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row17" class="row_heading level0 row17" >Release Date</th>
#       <td id="T_33d48_row17_col0" class="data row17 col0" >3</td>
#       <td id="T_33d48_row17_col1" class="data row17 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row18" class="row_heading level0 row18" >Early Access Release Date</th>
#       <td id="T_33d48_row18_col0" class="data row18 col0" >682</td>
#       <td id="T_33d48_row18_col1" class="data row18 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row19" class="row_heading level0 row19" >Developer</th>
#       <td id="T_33d48_row19_col0" class="data row19 col0" >0</td>
#       <td id="T_33d48_row19_col1" class="data row19 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row20" class="row_heading level0 row20" >Publisher</th>
#       <td id="T_33d48_row20_col0" class="data row20 col0" >2</td>
#       <td id="T_33d48_row20_col1" class="data row20 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row21" class="row_heading level0 row21" >Franchise</th>
#       <td id="T_33d48_row21_col0" class="data row21 col0" >378</td>
#       <td id="T_33d48_row21_col1" class="data row21 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row22" class="row_heading level0 row22" >languages</th>
#       <td id="T_33d48_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_33d48_row22_col1" class="data row22 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row23" class="row_heading level0 row23" >num_languages</th>
#       <td id="T_33d48_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_33d48_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row24" class="row_heading level0 row24" >page_num</th>
#       <td id="T_33d48_row24_col0" class="data row24 col0" >0</td>
#       <td id="T_33d48_row24_col1" class="data row24 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_33d48_level0_row25" class="row_heading level0 row25" >listing_num</th>
#       <td id="T_33d48_row25_col0" class="data row25 col0" >0</td>
#       <td id="T_33d48_row25_col1" class="data row25 col1" >int64</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 2.15 s, sys: 21.1 ms, total: 2.17 s
# Wall time: 2.17 s

# %% [markdown]
# <a id="load-and-process-all-search-results-files-acquired-using-`selenium`"></a>
#
# ### 2.2. [Load and Process all Search Results files acquired using `selenium`](#load-and-process-all-search-results-files-acquired-using-`selenium`)

# %% [markdown]
# We'll now load the search results dataset and change the `page` (page number) column to an integer datatype. As with the listings dataset, we'll drop listings with a missing value in the `Title` column and sort the dataset

# %%
# %%time
df_search_results_sel = (
    pd.concat(
        [
            pd.read_parquet(
                selenium_search_results_page,
                engine="auto",
            )
            for selenium_search_results_page in selenium_search_results_pages
        ],
        ignore_index=True,
    )
    .astype({"page": int})
    .dropna(subset=["title"])
    .sort_values(by=["page", "listing_counter"])
    .reset_index(drop=True)
)
print(df_search_results_sel["title"].nunique(), len(df_search_results_sel))
# Out:
# 883 1225
# CPU times: user 203 ms, sys: 42.6 ms, total: 245 ms
# Wall time: 225 ms

# %% [markdown]
# All listings with a duplicated `title` are shown below

# %%
display(
    df_search_results_sel[
        df_search_results_sel.duplicated(subset=["title"], keep=False)
    ].sort_values(by="title")
)
# Out:
#       page  listing_counter                             title  \
# 351     16                2           A Dance of Fire and Ice
# 329     15                5           A Dance of Fire and Ice
# 586     25               12                     A Hat in Time
# 718     30               19                     A Hat in Time
# 149      7               25            A Total War Saga: TROY
# ...    ...              ...                               ...
# 1097    45               23  eFootball PES 2021 SEASON UPDATE
# 123      6               24                           iRacing
# 125      7                1                           iRacing
# 501     22                2                         shapez.io
# 901     38                2                         shapez.io
#
#                                                     url platform_names  \
# 351   https://store.steampowered.com/app/977950/A Da...        win,mac
# 329   https://store.steampowered.com/app/977950/A Da...        win,mac
# 586   https://store.steampowered.com/app/253230/A Ha...        win,mac
# 718   https://store.steampowered.com/app/253230/A Ha...        win,mac
# 149   https://store.steampowered.com/app/1099410/A T...        win,mac
# ...                                                 ...            ...
# 1097  https://store.steampowered.com/app/1259970/eFo...            win
# 123   https://store.steampowered.com/app/266410/iRac...            win
# 125   https://store.steampowered.com/app/266410/iRac...            win
# 501   https://store.steampowered.com/app/1318690/sha...      win,linux
# 901   https://store.steampowered.com/app/1318690/sha...      win,linux
#
#       release_date discount_pct original_price discount_price
# 351   24 Jan, 2019         None      CDN$ 6.69           None
# 329   24 Jan, 2019         None      CDN$ 6.69           None
# 586    5 Oct, 2017         None     CDN$ 32.99           None
# 718    5 Oct, 2017         None     CDN$ 32.99           None
# 149    2 Sep, 2021         None     CDN$ 44.99           None
# ...            ...          ...            ...            ...
# 1097  15 Sep, 2020         None     CDN$ 42.99           None
# 123   12 Jan, 2015         None     CDN$ 10.99           None
# 125   12 Jan, 2015         None     CDN$ 10.99           None
# 501    7 Jun, 2020         -50%     CDN$ 11.99      CDN$ 5.99
# 901    7 Jun, 2020         None     CDN$ 11.99           None
#
# [610 rows x 9 columns]

# %% [markdown]
# **Observations**
# 1. As we can see these duplicated `Title`s are also duplicated in the `url` column meaning they are the same listing that appeared on a different page number when the Selenium webdriver queried the Steam store search. We'll drop one occurrence of each duplicated listing and keep the other.

# %% [markdown]
# Drop duplicates using the Title and URL columns

# %%
df_search_results_sel = df_search_results_sel.drop_duplicates(
    subset=["title", "url"]
).reset_index(drop=True)
print(df_search_results_sel["title"].nunique(), len(df_search_results_sel))
# Out:
# 883 883

# %% [markdown]
# <a id="merge-with-price-from-search-results-dataset-acquired-using-`selenium`"></a>
#
# ### 2.3. [Merge with Price from Search Results dataset acquired using `selenium`](#merge-with-price-from-search-results-dataset-acquired-using-`selenium`)

# %% [markdown]
# We'll now proceed to merge the listings and search results scraped with Selenium.

# %% [markdown]
# We'll merge with the `title` column only since the `url` was not captured when scraping the listing data, as seen from the list of columns in section [2.1 above](#load-and-process-all-listings-files-acquired-using-`selenium`)

# %%
# %%time
dfm_sel = df_search_results_sel.merge(
    df_listings_sel,
    left_on=["title"],
    right_on=["Title"],
    how="left",
)
show_df(dfm_sel.drop(columns=["url", "user_defined_tags", "languages", "Genre"]), 1)
show_df_dtypes_nans(dfm_sel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_97ed3_">
#   <caption>First & Last 1 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >page</th>
#       <th class="col_heading level0 col1" >listing_counter</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >platform_names</th>
#       <th class="col_heading level0 col4" >release_date</th>
#       <th class="col_heading level0 col5" >discount_pct</th>
#       <th class="col_heading level0 col6" >original_price</th>
#       <th class="col_heading level0 col7" >discount_price</th>
#       <th class="col_heading level0 col8" >review_type_all</th>
#       <th class="col_heading level0 col9" >overall_review_rating</th>
#       <th class="col_heading level0 col10" >pct_overall</th>
#       <th class="col_heading level0 col11" >pct_overall_threshold</th>
#       <th class="col_heading level0 col12" >pct_overall_lang</th>
#       <th class="col_heading level0 col13" >pct_overall_threshold_lang</th>
#       <th class="col_heading level0 col14" >platforms</th>
#       <th class="col_heading level0 col15" >num_steam_achievements</th>
#       <th class="col_heading level0 col16" >drm</th>
#       <th class="col_heading level0 col17" >rating</th>
#       <th class="col_heading level0 col18" >rating_descriptors</th>
#       <th class="col_heading level0 col19" >review_type_positive</th>
#       <th class="col_heading level0 col20" >review_type_negative</th>
#       <th class="col_heading level0 col21" >review_language_mine</th>
#       <th class="col_heading level0 col22" >Title</th>
#       <th class="col_heading level0 col23" >Release Date</th>
#       <th class="col_heading level0 col24" >Early Access Release Date</th>
#       <th class="col_heading level0 col25" >Developer</th>
#       <th class="col_heading level0 col26" >Publisher</th>
#       <th class="col_heading level0 col27" >Franchise</th>
#       <th class="col_heading level0 col28" >num_languages</th>
#       <th class="col_heading level0 col29" >page_num</th>
#       <th class="col_heading level0 col30" >listing_num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97ed3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97ed3_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_97ed3_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_97ed3_row0_col2" class="data row0 col2" >The Riftbreaker</td>
#       <td id="T_97ed3_row0_col3" class="data row0 col3" >win</td>
#       <td id="T_97ed3_row0_col4" class="data row0 col4" >14 Oct, 2021</td>
#       <td id="T_97ed3_row0_col5" class="data row0 col5" >-10%</td>
#       <td id="T_97ed3_row0_col6" class="data row0 col6" >CDN$ 33.99</td>
#       <td id="T_97ed3_row0_col7" class="data row0 col7" >CDN$ 30.59</td>
#       <td id="T_97ed3_row0_col8" class="data row0 col8" >1014.000000</td>
#       <td id="T_97ed3_row0_col9" class="data row0 col9" >Very Positive</td>
#       <td id="T_97ed3_row0_col10" class="data row0 col10" >93.000000</td>
#       <td id="T_97ed3_row0_col11" class="data row0 col11" >positive</td>
#       <td id="T_97ed3_row0_col12" class="data row0 col12" >92.000000</td>
#       <td id="T_97ed3_row0_col13" class="data row0 col13" >positive</td>
#       <td id="T_97ed3_row0_col14" class="data row0 col14" >win</td>
#       <td id="T_97ed3_row0_col15" class="data row0 col15" >30.000000</td>
#       <td id="T_97ed3_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_97ed3_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_97ed3_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_97ed3_row0_col19" class="data row0 col19" >938.000000</td>
#       <td id="T_97ed3_row0_col20" class="data row0 col20" >76.000000</td>
#       <td id="T_97ed3_row0_col21" class="data row0 col21" >412.000000</td>
#       <td id="T_97ed3_row0_col22" class="data row0 col22" >The Riftbreaker</td>
#       <td id="T_97ed3_row0_col23" class="data row0 col23" >14 Oct, 2021</td>
#       <td id="T_97ed3_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_97ed3_row0_col25" class="data row0 col25" >EXOR Studios</td>
#       <td id="T_97ed3_row0_col26" class="data row0 col26" >EXOR Studios, Surefire.Games</td>
#       <td id="T_97ed3_row0_col27" class="data row0 col27" >EXOR Studios, surefiregames</td>
#       <td id="T_97ed3_row0_col28" class="data row0 col28" >10.000000</td>
#       <td id="T_97ed3_row0_col29" class="data row0 col29" >2.000000</td>
#       <td id="T_97ed3_row0_col30" class="data row0 col30" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97ed3_level0_row1" class="row_heading level0 row1" >882</th>
#       <td id="T_97ed3_row1_col0" class="data row1 col0" >50</td>
#       <td id="T_97ed3_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_97ed3_row1_col2" class="data row1 col2" >Streamer Life Simulator</td>
#       <td id="T_97ed3_row1_col3" class="data row1 col3" >win</td>
#       <td id="T_97ed3_row1_col4" class="data row1 col4" >21 Aug, 2020</td>
#       <td id="T_97ed3_row1_col5" class="data row1 col5" >-45%</td>
#       <td id="T_97ed3_row1_col6" class="data row1 col6" >CDN$ 22.79</td>
#       <td id="T_97ed3_row1_col7" class="data row1 col7" >CDN$ 12.53</td>
#       <td id="T_97ed3_row1_col8" class="data row1 col8" >3787.000000</td>
#       <td id="T_97ed3_row1_col9" class="data row1 col9" >Very Positive</td>
#       <td id="T_97ed3_row1_col10" class="data row1 col10" >79.000000</td>
#       <td id="T_97ed3_row1_col11" class="data row1 col11" >positive</td>
#       <td id="T_97ed3_row1_col12" class="data row1 col12" >76.000000</td>
#       <td id="T_97ed3_row1_col13" class="data row1 col13" >positive</td>
#       <td id="T_97ed3_row1_col14" class="data row1 col14" >win</td>
#       <td id="T_97ed3_row1_col15" class="data row1 col15" >15.000000</td>
#       <td id="T_97ed3_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_97ed3_row1_col17" class="data row1 col17" >nan</td>
#       <td id="T_97ed3_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_97ed3_row1_col19" class="data row1 col19" >2988.000000</td>
#       <td id="T_97ed3_row1_col20" class="data row1 col20" >799.000000</td>
#       <td id="T_97ed3_row1_col21" class="data row1 col21" >1010.000000</td>
#       <td id="T_97ed3_row1_col22" class="data row1 col22" >Streamer Life Simulator</td>
#       <td id="T_97ed3_row1_col23" class="data row1 col23" >21 Aug, 2020</td>
#       <td id="T_97ed3_row1_col24" class="data row1 col24" >nan</td>
#       <td id="T_97ed3_row1_col25" class="data row1 col25" >Cheesecake Dev</td>
#       <td id="T_97ed3_row1_col26" class="data row1 col26" >Cheesecake Dev</td>
#       <td id="T_97ed3_row1_col27" class="data row1 col27" >Cheesecake Dev</td>
#       <td id="T_97ed3_row1_col28" class="data row1 col28" >10.000000</td>
#       <td id="T_97ed3_row1_col29" class="data row1 col29" >50.000000</td>
#       <td id="T_97ed3_row1_col30" class="data row1 col30" >23.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4c124_">
#   <caption>Column Datatypes and Missing Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_missing</th>
#       <th class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c124_level0_row0" class="row_heading level0 row0" >page</th>
#       <td id="T_4c124_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4c124_row0_col1" class="data row0 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row1" class="row_heading level0 row1" >listing_counter</th>
#       <td id="T_4c124_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_4c124_row1_col1" class="data row1 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row2" class="row_heading level0 row2" >title</th>
#       <td id="T_4c124_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_4c124_row2_col1" class="data row2 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row3" class="row_heading level0 row3" >url</th>
#       <td id="T_4c124_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_4c124_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row4" class="row_heading level0 row4" >platform_names</th>
#       <td id="T_4c124_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_4c124_row4_col1" class="data row4 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row5" class="row_heading level0 row5" >release_date</th>
#       <td id="T_4c124_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_4c124_row5_col1" class="data row5 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row6" class="row_heading level0 row6" >discount_pct</th>
#       <td id="T_4c124_row6_col0" class="data row6 col0" >755</td>
#       <td id="T_4c124_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row7" class="row_heading level0 row7" >original_price</th>
#       <td id="T_4c124_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_4c124_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row8" class="row_heading level0 row8" >discount_price</th>
#       <td id="T_4c124_row8_col0" class="data row8 col0" >755</td>
#       <td id="T_4c124_row8_col1" class="data row8 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row9" class="row_heading level0 row9" >review_type_all</th>
#       <td id="T_4c124_row9_col0" class="data row9 col0" >82</td>
#       <td id="T_4c124_row9_col1" class="data row9 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row10" class="row_heading level0 row10" >overall_review_rating</th>
#       <td id="T_4c124_row10_col0" class="data row10 col0" >82</td>
#       <td id="T_4c124_row10_col1" class="data row10 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row11" class="row_heading level0 row11" >pct_overall</th>
#       <td id="T_4c124_row11_col0" class="data row11 col0" >82</td>
#       <td id="T_4c124_row11_col1" class="data row11 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row12" class="row_heading level0 row12" >pct_overall_threshold</th>
#       <td id="T_4c124_row12_col0" class="data row12 col0" >82</td>
#       <td id="T_4c124_row12_col1" class="data row12 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row13" class="row_heading level0 row13" >pct_overall_lang</th>
#       <td id="T_4c124_row13_col0" class="data row13 col0" >83</td>
#       <td id="T_4c124_row13_col1" class="data row13 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row14" class="row_heading level0 row14" >pct_overall_threshold_lang</th>
#       <td id="T_4c124_row14_col0" class="data row14 col0" >83</td>
#       <td id="T_4c124_row14_col1" class="data row14 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row15" class="row_heading level0 row15" >platforms</th>
#       <td id="T_4c124_row15_col0" class="data row15 col0" >98</td>
#       <td id="T_4c124_row15_col1" class="data row15 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row16" class="row_heading level0 row16" >user_defined_tags</th>
#       <td id="T_4c124_row16_col0" class="data row16 col0" >69</td>
#       <td id="T_4c124_row16_col1" class="data row16 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row17" class="row_heading level0 row17" >num_steam_achievements</th>
#       <td id="T_4c124_row17_col0" class="data row17 col0" >251</td>
#       <td id="T_4c124_row17_col1" class="data row17 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row18" class="row_heading level0 row18" >drm</th>
#       <td id="T_4c124_row18_col0" class="data row18 col0" >617</td>
#       <td id="T_4c124_row18_col1" class="data row18 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row19" class="row_heading level0 row19" >rating</th>
#       <td id="T_4c124_row19_col0" class="data row19 col0" >479</td>
#       <td id="T_4c124_row19_col1" class="data row19 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row20" class="row_heading level0 row20" >rating_descriptors</th>
#       <td id="T_4c124_row20_col0" class="data row20 col0" >522</td>
#       <td id="T_4c124_row20_col1" class="data row20 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row21" class="row_heading level0 row21" >review_type_positive</th>
#       <td id="T_4c124_row21_col0" class="data row21 col0" >82</td>
#       <td id="T_4c124_row21_col1" class="data row21 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row22" class="row_heading level0 row22" >review_type_negative</th>
#       <td id="T_4c124_row22_col0" class="data row22 col0" >82</td>
#       <td id="T_4c124_row22_col1" class="data row22 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row23" class="row_heading level0 row23" >review_language_mine</th>
#       <td id="T_4c124_row23_col0" class="data row23 col0" >82</td>
#       <td id="T_4c124_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row24" class="row_heading level0 row24" >Title</th>
#       <td id="T_4c124_row24_col0" class="data row24 col0" >69</td>
#       <td id="T_4c124_row24_col1" class="data row24 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row25" class="row_heading level0 row25" >Genre</th>
#       <td id="T_4c124_row25_col0" class="data row25 col0" >72</td>
#       <td id="T_4c124_row25_col1" class="data row25 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row26" class="row_heading level0 row26" >Release Date</th>
#       <td id="T_4c124_row26_col0" class="data row26 col0" >72</td>
#       <td id="T_4c124_row26_col1" class="data row26 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row27" class="row_heading level0 row27" >Early Access Release Date</th>
#       <td id="T_4c124_row27_col0" class="data row27 col0" >748</td>
#       <td id="T_4c124_row27_col1" class="data row27 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row28" class="row_heading level0 row28" >Developer</th>
#       <td id="T_4c124_row28_col0" class="data row28 col0" >69</td>
#       <td id="T_4c124_row28_col1" class="data row28 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row29" class="row_heading level0 row29" >Publisher</th>
#       <td id="T_4c124_row29_col0" class="data row29 col0" >71</td>
#       <td id="T_4c124_row29_col1" class="data row29 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row30" class="row_heading level0 row30" >Franchise</th>
#       <td id="T_4c124_row30_col0" class="data row30 col0" >446</td>
#       <td id="T_4c124_row30_col1" class="data row30 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_4c124_level0_row31" class="row_heading level0 row31" >languages</th>
# CPU times: user 20.2 ms, sys: 0 ns, total: 20.2 ms
# Wall time: 18.1 ms

# %% [markdown]
# <a id="combine-`requests`-based-files"></a>
#
# ## 3. [Combine `requests`-based files](#combine-`requests`-based-files)

# %% [markdown]
# <a id="load-and-process-all-search-results-files-acquired-using-`requests`"></a>
#
# ### 3.1. [Load and Process all Search Results files acquired using `requests`](#load-and-process-all-search-results-files-acquired-using-`requests`)

# %% [markdown]
# We'll now load the search results dataset scraped with the `requests` library. We'll change the page number datatype and drop rows with a missing or blank value in the `title` column. We're also doing the following
# - filtering out non-English search results
# - adding an `app_id` column (which is extracted from the URL using a regular expression)
# - (using similar logic to that for handling duplicates in the selenium dataset) we'll drop duplicates based on `url`, `title` and `platform_name` columns
#   - this choice was also discussed in more detail in section 3.1 of `4_filter_requests_listings.ipynb`

# %%
# %%time
df_search_results_requests = (
    pd.concat(
        [
            pd.read_parquet(f, engine="auto")
            for f in requests_search_results_pages
        ],
        ignore_index=True,
    )
    .drop(columns=["request_status_code"])
    .astype({"page": int}).dropna(subset=["title"])
    .sort_values(by=["page", "listing_counter"])
    .reset_index(drop=True)
)
print(f"Total number of search results scraped with requests = {len(df_search_results_requests):,}")

# Only select listing titles available in English
df_search_results_requests = df_search_results_requests[
    df_search_results_requests['title'].map(lambda x: x.isascii())
]

# Append an app_id column using a regex extract() from the URL
df_search_results_requests = df_search_results_requests.assign(
    app_id=df_search_results_requests["url"].str.extract(
        r"https://store.steampowered.com/app/(\d+)/*/"
    )
)
print(df_search_results_requests["title"].nunique())

# Remove listings that are missing a value in the title column
df_search_results_requests = df_search_results_requests[
    df_search_results_requests["title"] != ""
]

# Use the url, platform_names and title columns to drop duplicated listings
df_search_results_requests = df_search_results_requests.drop_duplicates(
    subset=["url", "title", "platform_names"]
)
show_df(df_search_results_requests, 2)
show_df_dtypes_nans(df_search_results_requests)
# Out:
# Total number of search results scraped with requests = 54,566
# 45798
# <style type="text/css">
# </style>
# <table id="T_ddbfb_">
#   <caption>First & Last 2 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >page</th>
#       <th class="col_heading level0 col1" >listing_counter</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >url</th>
#       <th class="col_heading level0 col4" >platform_names</th>
#       <th class="col_heading level0 col5" >release_date</th>
#       <th class="col_heading level0 col6" >discount_pct</th>
#       <th class="col_heading level0 col7" >original_price</th>
#       <th class="col_heading level0 col8" >discount_price</th>
#       <th class="col_heading level0 col9" >app_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddbfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ddbfb_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_ddbfb_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_ddbfb_row0_col2" class="data row0 col2" >Blazing_Sails</td>
#       <td id="T_ddbfb_row0_col3" class="data row0 col3" >https://store.steampowered.com/app/1158940/Blazing_Sails/</td>
#       <td id="T_ddbfb_row0_col4" class="data row0 col4" >win</td>
#       <td id="T_ddbfb_row0_col5" class="data row0 col5" >Nov 5, 2020</td>
#       <td id="T_ddbfb_row0_col6" class="data row0 col6" >-30%</td>
#       <td id="T_ddbfb_row0_col7" class="data row0 col7" >14.99</td>
#       <td id="T_ddbfb_row0_col8" class="data row0 col8" >10.49</td>
#       <td id="T_ddbfb_row0_col9" class="data row0 col9" >1158940</td>
#     </tr>
#     <tr>
#       <th id="T_ddbfb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ddbfb_row1_col0" class="data row1 col0" >50</td>
#       <td id="T_ddbfb_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_ddbfb_row1_col2" class="data row1 col2" >LEGO_Harry_Potter_Years_14</td>
#       <td id="T_ddbfb_row1_col3" class="data row1 col3" >https://store.steampowered.com/app/21130/LEGO_Harry_Potter_Years_14/</td>
#       <td id="T_ddbfb_row1_col4" class="data row1 col4" >win</td>
#       <td id="T_ddbfb_row1_col5" class="data row1 col5" >Jun 25, 2010</td>
#       <td id="T_ddbfb_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_ddbfb_row1_col7" class="data row1 col7" >19.99</td>
#       <td id="T_ddbfb_row1_col8" class="data row1 col8" >None</td>
#       <td id="T_ddbfb_row1_col9" class="data row1 col9" >21130</td>
#     </tr>
#     <tr>
#       <th id="T_ddbfb_level0_row2" class="row_heading level0 row2" >54560</th>
#       <td id="T_ddbfb_row2_col0" class="data row2 col0" >2232</td>
#       <td id="T_ddbfb_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_ddbfb_row2_col2" class="data row2 col2" >Animal_Shelter_Prologue</td>
#       <td id="T_ddbfb_row2_col3" class="data row2 col3" >https://store.steampowered.com/app/1661260/Animal_Shelter_Prologue/</td>
#       <td id="T_ddbfb_row2_col4" class="data row2 col4" >win</td>
#       <td id="T_ddbfb_row2_col5" class="data row2 col5" >2021- Add to Wishlist!</td>
#       <td id="T_ddbfb_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_ddbfb_row2_col7" class="data row2 col7" >Free</td>
#       <td id="T_ddbfb_row2_col8" class="data row2 col8" >None</td>
#       <td id="T_ddbfb_row2_col9" class="data row2 col9" >1661260</td>
#     </tr>
#     <tr>
#       <th id="T_ddbfb_level0_row3" class="row_heading level0 row3" >54561</th>
#       <td id="T_ddbfb_row3_col0" class="data row3 col0" >2232</td>
#       <td id="T_ddbfb_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_ddbfb_row3_col2" class="data row3 col2" >Dynasty_of_the_Sands</td>
#       <td id="T_ddbfb_row3_col3" class="data row3 col3" >https://store.steampowered.com/app/1143070/Dynasty_of_the_Sands/</td>
#       <td id="T_ddbfb_row3_col4" class="data row3 col4" >win</td>
#       <td id="T_ddbfb_row3_col5" class="data row3 col5" >TBA</td>
#       <td id="T_ddbfb_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_ddbfb_row3_col7" class="data row3 col7" >None</td>
#       <td id="T_ddbfb_row3_col8" class="data row3 col8" >None</td>
#       <td id="T_ddbfb_row3_col9" class="data row3 col9" >1143070</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7374f_">
#   <caption>Column Datatypes and Missing Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_missing</th>
#       <th class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7374f_level0_row0" class="row_heading level0 row0" >page</th>
#       <td id="T_7374f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7374f_row0_col1" class="data row0 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row1" class="row_heading level0 row1" >listing_counter</th>
#       <td id="T_7374f_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7374f_row1_col1" class="data row1 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row2" class="row_heading level0 row2" >title</th>
#       <td id="T_7374f_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_7374f_row2_col1" class="data row2 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row3" class="row_heading level0 row3" >url</th>
#       <td id="T_7374f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_7374f_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row4" class="row_heading level0 row4" >platform_names</th>
#       <td id="T_7374f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7374f_row4_col1" class="data row4 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row5" class="row_heading level0 row5" >release_date</th>
#       <td id="T_7374f_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7374f_row5_col1" class="data row5 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row6" class="row_heading level0 row6" >discount_pct</th>
#       <td id="T_7374f_row6_col0" class="data row6 col0" >44725</td>
#       <td id="T_7374f_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row7" class="row_heading level0 row7" >original_price</th>
#       <td id="T_7374f_row7_col0" class="data row7 col0" >5295</td>
#       <td id="T_7374f_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row8" class="row_heading level0 row8" >discount_price</th>
#       <td id="T_7374f_row8_col0" class="data row8 col0" >44725</td>
#       <td id="T_7374f_row8_col1" class="data row8 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_7374f_level0_row9" class="row_heading level0 row9" >app_id</th>
#       <td id="T_7374f_row9_col0" class="data row9 col0" >162</td>
#       <td id="T_7374f_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 6.6 s, sys: 827 ms, total: 7.43 s
# Wall time: 3.96 s

# %% [markdown]
# Verify no duplicated URLs in this search results dataset

# %%
assert df_search_results_requests["url"].nunique() == len(df_search_results_requests)

# %% [markdown]
# <a id="load-and-process-all-listings-files-acquired-using-`requests`"></a>
#
# ### 3.2. [Load and Process all Listings files acquired using `requests`](#load-and-process-all-listings-files-acquired-using-`requests`)

# %% [markdown]
# We'll now load the listings scraped with `requests`. Again, we've only kept listings that are offered in English and added an `app_id` column

# %%
# %%time
df_listings = pd.concat(
    [
        pd.read_csv(fpath).assign(filename=os.path.basename(fpath))
        for fpath in fpaths_requests
    ],
    ignore_index=True,
).sort_values(by=["page_num", "listing_num"])

# Select listings that support the English language
df_listings["languages"] = df_listings["languages"].str.contains("English")

# Append an app_id column using a regex extract() from the URL
df_listings = df_listings.assign(
    app_id=df_listings["url"].str.split(
        "app/", expand=True
    )[1].str.split("/", expand=True)[0]
)

df_listings = df_listings.reset_index(drop=True)

show_df(df_listings, 1)
show_df_dtypes_nans(df_listings)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a31fe_">
#   <caption>First & Last 1 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >review_type_all</th>
#       <th class="col_heading level0 col1" >overall_review_rating</th>
#       <th class="col_heading level0 col2" >pct_overall</th>
#       <th class="col_heading level0 col3" >pct_overall_threshold</th>
#       <th class="col_heading level0 col4" >pct_overall_lang</th>
#       <th class="col_heading level0 col5" >pct_overall_threshold_lang</th>
#       <th class="col_heading level0 col6" >platforms</th>
#       <th class="col_heading level0 col7" >user_defined_tags</th>
#       <th class="col_heading level0 col8" >num_steam_achievements</th>
#       <th class="col_heading level0 col9" >drm</th>
#       <th class="col_heading level0 col10" >rating</th>
#       <th class="col_heading level0 col11" >rating_descriptors</th>
#       <th class="col_heading level0 col12" >review_type_positive</th>
#       <th class="col_heading level0 col13" >review_type_negative</th>
#       <th class="col_heading level0 col14" >review_language_mine</th>
#       <th class="col_heading level0 col15" >Title</th>
#       <th class="col_heading level0 col16" >Genre</th>
#       <th class="col_heading level0 col17" >Release Date</th>
#       <th class="col_heading level0 col18" >Early Access Release Date</th>
#       <th class="col_heading level0 col19" >Developer</th>
#       <th class="col_heading level0 col20" >Publisher</th>
#       <th class="col_heading level0 col21" >Franchise</th>
#       <th class="col_heading level0 col22" >languages</th>
#       <th class="col_heading level0 col23" >num_languages</th>
#       <th class="col_heading level0 col24" >page_num</th>
#       <th class="col_heading level0 col25" >listing_num</th>
#       <th class="col_heading level0 col26" >url</th>
#       <th class="col_heading level0 col27" >filename</th>
#       <th class="col_heading level0 col28" >app_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a31fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a31fe_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a31fe_row0_col1" class="data row0 col1" >Very Positive</td>
#       <td id="T_a31fe_row0_col2" class="data row0 col2" >90.000000</td>
#       <td id="T_a31fe_row0_col3" class="data row0 col3" >positive</td>
#       <td id="T_a31fe_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a31fe_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a31fe_row0_col6" class="data row0 col6" >win</td>
#       <td id="T_a31fe_row0_col7" class="data row0 col7" >Early Access, Co-op, Naval Combat, Online Co-Op, Character Customization, FPS, Pirates, Historical, Open World, PvP, Fast-Paced, Battle Royale, First-Person, Survival, Team-Based, Competitive, Funny, Shooter, Action, Naval</td>
#       <td id="T_a31fe_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_a31fe_row0_col9" class="data row0 col9" >Requires agreement to a 3rd-party EULA, Blazing Sails EULA</td>
#       <td id="T_a31fe_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_a31fe_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_a31fe_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_a31fe_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_a31fe_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_a31fe_row0_col15" class="data row0 col15" >Blazing Sails</td>
#       <td id="T_a31fe_row0_col16" class="data row0 col16" >Action, Adventure, Casual, Indie, Early Access</td>
#       <td id="T_a31fe_row0_col17" class="data row0 col17" >Nov 5, 2020</td>
#       <td id="T_a31fe_row0_col18" class="data row0 col18" >Sep 9, 2020</td>
#       <td id="T_a31fe_row0_col19" class="data row0 col19" >Get Up Games</td>
#       <td id="T_a31fe_row0_col20" class="data row0 col20" >Iceberg Interactive</td>
#       <td id="T_a31fe_row0_col21" class="data row0 col21" >Iceberg Interactive</td>
#       <td id="T_a31fe_row0_col22" class="data row0 col22" >True</td>
#       <td id="T_a31fe_row0_col23" class="data row0 col23" >15.000000</td>
#       <td id="T_a31fe_row0_col24" class="data row0 col24" >50</td>
#       <td id="T_a31fe_row0_col25" class="data row0 col25" >1</td>
#       <td id="T_a31fe_row0_col26" class="data row0 col26" >https://store.steampowered.com/app/1158940/Blazing_Sails/</td>
#       <td id="T_a31fe_row0_col27" class="data row0 col27" >p50_l1_Blazing_Sails.csv</td>
#       <td id="T_a31fe_row0_col28" class="data row0 col28" >1158940</td>
#     </tr>
#     <tr>
#       <th id="T_a31fe_level0_row1" class="row_heading level0 row1" >10875</th>
#       <td id="T_a31fe_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_a31fe_row1_col1" class="data row1 col1" >Very Positive</td>
#       <td id="T_a31fe_row1_col2" class="data row1 col2" >91.000000</td>
#       <td id="T_a31fe_row1_col3" class="data row1 col3" >positive</td>
#       <td id="T_a31fe_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a31fe_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a31fe_row1_col6" class="data row1 col6" >win</td>
#       <td id="T_a31fe_row1_col7" class="data row1 col7" >Anime, Action, Beat 'em up, Indie, Female Protagonist, Cute, Platformer, Character Action Game, Fighting, Hack and Slash, JRPG, RPG, Singleplayer, Side Scroller</td>
#       <td id="T_a31fe_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_a31fe_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_a31fe_row1_col10" class="data row1 col10" >t</td>
#       <td id="T_a31fe_row1_col11" class="data row1 col11" >Fantasy Violence, , Mild Suggestive Themes</td>
#       <td id="T_a31fe_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_a31fe_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_a31fe_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_a31fe_row1_col15" class="data row1 col15" >Fairy Bloom Freesia</td>
#       <td id="T_a31fe_row1_col16" class="data row1 col16" >Action, Indie</td>
#       <td id="T_a31fe_row1_col17" class="data row1 col17" >Oct 17, 2012</td>
#       <td id="T_a31fe_row1_col18" class="data row1 col18" >nan</td>
#       <td id="T_a31fe_row1_col19" class="data row1 col19" >Edelweiss</td>
#       <td id="T_a31fe_row1_col20" class="data row1 col20" >Nyu Media</td>
#       <td id="T_a31fe_row1_col21" class="data row1 col21" >Nyu Media</td>
#       <td id="T_a31fe_row1_col22" class="data row1 col22" >True</td>
#       <td id="T_a31fe_row1_col23" class="data row1 col23" >2.000000</td>
#       <td id="T_a31fe_row1_col24" class="data row1 col24" >505</td>
#       <td id="T_a31fe_row1_col25" class="data row1 col25" >25</td>
#       <td id="T_a31fe_row1_col26" class="data row1 col26" >https://store.steampowered.com/app/214590/Fairy Bloom Freesia/</td>
#       <td id="T_a31fe_row1_col27" class="data row1 col27" >p505_l25_Fairy_Bloom_Freesia.csv</td>
#       <td id="T_a31fe_row1_col28" class="data row1 col28" >214590</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b3662_">
#   <caption>Column Datatypes and Missing Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_missing</th>
#       <th class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3662_level0_row0" class="row_heading level0 row0" >review_type_all</th>
#       <td id="T_b3662_row0_col0" class="data row0 col0" >10876</td>
#       <td id="T_b3662_row0_col1" class="data row0 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row1" class="row_heading level0 row1" >overall_review_rating</th>
#       <td id="T_b3662_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_b3662_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row2" class="row_heading level0 row2" >pct_overall</th>
#       <td id="T_b3662_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_b3662_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row3" class="row_heading level0 row3" >pct_overall_threshold</th>
#       <td id="T_b3662_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_b3662_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row4" class="row_heading level0 row4" >pct_overall_lang</th>
#       <td id="T_b3662_row4_col0" class="data row4 col0" >10876</td>
#       <td id="T_b3662_row4_col1" class="data row4 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row5" class="row_heading level0 row5" >pct_overall_threshold_lang</th>
#       <td id="T_b3662_row5_col0" class="data row5 col0" >10876</td>
#       <td id="T_b3662_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row6" class="row_heading level0 row6" >platforms</th>
#       <td id="T_b3662_row6_col0" class="data row6 col0" >37</td>
#       <td id="T_b3662_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row7" class="row_heading level0 row7" >user_defined_tags</th>
#       <td id="T_b3662_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_b3662_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row8" class="row_heading level0 row8" >num_steam_achievements</th>
#       <td id="T_b3662_row8_col0" class="data row8 col0" >10876</td>
#       <td id="T_b3662_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row9" class="row_heading level0 row9" >drm</th>
#       <td id="T_b3662_row9_col0" class="data row9 col0" >9521</td>
#       <td id="T_b3662_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row10" class="row_heading level0 row10" >rating</th>
#       <td id="T_b3662_row10_col0" class="data row10 col0" >8344</td>
#       <td id="T_b3662_row10_col1" class="data row10 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row11" class="row_heading level0 row11" >rating_descriptors</th>
#       <td id="T_b3662_row11_col0" class="data row11 col0" >8988</td>
#       <td id="T_b3662_row11_col1" class="data row11 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row12" class="row_heading level0 row12" >review_type_positive</th>
#       <td id="T_b3662_row12_col0" class="data row12 col0" >10876</td>
#       <td id="T_b3662_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row13" class="row_heading level0 row13" >review_type_negative</th>
#       <td id="T_b3662_row13_col0" class="data row13 col0" >10876</td>
#       <td id="T_b3662_row13_col1" class="data row13 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row14" class="row_heading level0 row14" >review_language_mine</th>
#       <td id="T_b3662_row14_col0" class="data row14 col0" >10876</td>
#       <td id="T_b3662_row14_col1" class="data row14 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row15" class="row_heading level0 row15" >Title</th>
#       <td id="T_b3662_row15_col0" class="data row15 col0" >703</td>
#       <td id="T_b3662_row15_col1" class="data row15 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row16" class="row_heading level0 row16" >Genre</th>
#       <td id="T_b3662_row16_col0" class="data row16 col0" >715</td>
#       <td id="T_b3662_row16_col1" class="data row16 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row17" class="row_heading level0 row17" >Release Date</th>
#       <td id="T_b3662_row17_col0" class="data row17 col0" >715</td>
#       <td id="T_b3662_row17_col1" class="data row17 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row18" class="row_heading level0 row18" >Early Access Release Date</th>
#       <td id="T_b3662_row18_col0" class="data row18 col0" >9768</td>
#       <td id="T_b3662_row18_col1" class="data row18 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row19" class="row_heading level0 row19" >Developer</th>
#       <td id="T_b3662_row19_col0" class="data row19 col0" >719</td>
#       <td id="T_b3662_row19_col1" class="data row19 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row20" class="row_heading level0 row20" >Publisher</th>
#       <td id="T_b3662_row20_col0" class="data row20 col0" >739</td>
#       <td id="T_b3662_row20_col1" class="data row20 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row21" class="row_heading level0 row21" >Franchise</th>
#       <td id="T_b3662_row21_col0" class="data row21 col0" >7430</td>
#       <td id="T_b3662_row21_col1" class="data row21 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row22" class="row_heading level0 row22" >languages</th>
#       <td id="T_b3662_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_b3662_row22_col1" class="data row22 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row23" class="row_heading level0 row23" >num_languages</th>
#       <td id="T_b3662_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_b3662_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row24" class="row_heading level0 row24" >page_num</th>
#       <td id="T_b3662_row24_col0" class="data row24 col0" >0</td>
#       <td id="T_b3662_row24_col1" class="data row24 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row25" class="row_heading level0 row25" >listing_num</th>
#       <td id="T_b3662_row25_col0" class="data row25 col0" >0</td>
#       <td id="T_b3662_row25_col1" class="data row25 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row26" class="row_heading level0 row26" >url</th>
#       <td id="T_b3662_row26_col0" class="data row26 col0" >0</td>
#       <td id="T_b3662_row26_col1" class="data row26 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row27" class="row_heading level0 row27" >filename</th>
#       <td id="T_b3662_row27_col0" class="data row27 col0" >0</td>
#       <td id="T_b3662_row27_col1" class="data row27 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b3662_level0_row28" class="row_heading level0 row28" >app_id</th>
#       <td id="T_b3662_row28_col0" class="data row28 col0" >0</td>
#       <td id="T_b3662_row28_col1" class="data row28 col1" >object</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 25.4 s, sys: 0 ns, total: 25.4 s
# Wall time: 25.4 s

# %% [markdown]
# Next, we'll use the added `app_id` column to append a column which indicates if a listing is actually a collection of games and not a single game
# - collections have multiple `app_id`s in the URL, where each `app_id` corresponds to a single game, and we don't want to include these as we're only scraping single game listings

# %%
# Get index of all rows with multiple app_ids
is_collection_idx = df_listings[df_listings["app_id"].str.contains(",")].index
print(len(is_collection_idx))
# Out:
# 60

# %% [markdown]
# Including each game in a collection will result in duplicating that game so we'll drop all rows that are collections

# %%
# Append a boolean column with a check of whether a listing is a collection
df_listings["is_collection"] = False
df_listings.loc[is_collection_idx, "is_collection"] = True

# %%
df_listings = df_listings.query("is_collection == False")

# %% [markdown]
# Count the number of listings with a blank string in the `Title` column

# %%
print(f"Missing title = {len(df_listings[df_listings['Title'] == ''])}")
# Out:
# Missing title = 0

# %% [markdown]
# Count the number of listings with a blank string in the `url`, `Release Date` or `platforms` columns (separately)

# %%
for c in ["url", "Release Date", "platforms"]:
    blank_values = (df_listings[c] == "").sum()
    print(f"Missing {c} = {blank_values}")
# Out:
# Missing url = 0
# Missing Release Date = 0
# Missing platforms = 0

# %% [markdown]
# Check how many unique and missing `Title`s are present in the listings

# %%
print(
    f"Number of unique titles = {df_listings['Title'].nunique():,}\n"
    f"Number of titles with missing values = {df_listings['Title'].isna().sum():,}\n"
    f"Number of listings = {len(df_listings):,}"
)
# Out:
# Number of unique titles = 10,072
# Number of titles with missing values = 703
# Number of listings = 10,816

# %% [markdown]
# Get listings with duplicate URLs

# %%
# Find duplicates - use keep=False to return all duplicated rows
dup_listings_requests = df_listings[
    df_listings.duplicated(subset=["url"], keep=False)
].sort_values(by=["url"])
print(f"Number of duplicate URLs = {len(dup_listings_requests)}")
display(
    dup_listings_requests[
        [
            "page_num",
            "listing_num",
            "Title",
            "Developer",
            "filename",
            "Publisher",
            "url",
            "user_defined_tags",
            "platforms",
        ]
    ]
)
# Out:
# Number of duplicate URLs = 2
#       page_num  listing_num Title Developer              filename Publisher  \
# 1125        95           20   NaN       NaN  p95_l20_Doom_Vfr.csv       NaN
# 1462       112            8   NaN       NaN  p112_l8_Doom_Vfr.csv       NaN
#
#                                                     url  \
# 1125  https://store.steampowered.com/app/650000/DOOM...
# 1462  https://store.steampowered.com/app/650000/DOOM...
#
#                                       user_defined_tags         platforms
# 1125  Action, VR, Violent, Gore, FPS, Shooter, Horro...  win, vr_required
# 1462  Action, VR, Violent, Gore, FPS, Shooter, Horro...  win, vr_required

# %% [markdown]
# **Observations**
# 1. One URL in the `requests_listings_to_scrape.csv` file (produced by `4_filter_requests_listings.ipynb`, also shown in section 3.1 of this notebook) has likely resolved to the URL of another listing. This is the likely reason for the presence of this duplicated row, which we did not expect. We'll drop the duplicated row.

# %% [markdown]
# Drop rows with duplicated listing URLs

# %%
df_listings = df_listings.drop_duplicates(subset=["url"])

# %% [markdown]
# Explore listings with duplicates based on the `Title` and `URL` columns

# %%
# Find duplicates - use keep=False to return all duplicated rows
dup_titles = df_listings.dropna(subset=["Title"])[
    df_listings.dropna(subset=["Title"]).duplicated(subset=["Title", "url"], keep=False)
]
cols_to_show = [
    "page_num",
    "listing_num",
    "Title",
    "url",
    "filename",
    "Developer",
    "Publisher",
    "user_defined_tags",
    "platforms",
]
display(dup_titles[cols_to_show].sort_values(by="Title"))
print(f"Number of duplicate Titles = {int(len(dup_titles) / 2)}")
for _, row in dup_titles.sort_values(by="Title")[["url", "is_collection"]].iterrows():
    print(f"is_collection = {row['is_collection']}, URL = {row['url']}")
# Out:
# Empty DataFrame
# Columns: [page_num, listing_num, Title, url, filename, Developer, Publisher, user_defined_tags, platforms]
# Index: []
# Number of duplicate Titles = 0

# %% [markdown]
# Now, explore any remaining listings with only a duplicate `Title`

# %%
# Find duplicates - use keep=False to return all duplicated rows
dup_titles = df_listings.dropna(subset=["Title"])[
    df_listings.dropna(subset=["Title"]).duplicated(subset=["Title"], keep=False)
]
cols_to_show = [
    "Title",
    "url",
    "Developer",
    "Publisher",
    "user_defined_tags",
    "platforms",
    "is_collection",
    "page_num",
]
display(dup_titles[cols_to_show].sort_values(by="Title"))
print(f"Number of duplicate URLs = {int(len(dup_titles) / 2)}")
for _, row in dup_titles.sort_values(by="Title")[
    ["url", "is_collection", "page_num", "listing_num"]
].iterrows():
    print(
        f"is_collection = {row['is_collection']}, page_num = {row['page_num']}, "
        f"listing_num = {row['listing_num']}, URL = {row['url']}"
    )
# Out:
#                                Title  \
# 10648  Airport Madness: Time Machine
# 10737  Airport Madness: Time Machine
# 10779                  Alone on Mars
# 10689                  Alone on Mars
# 8311           Anime girl Or Bottle?
# ...                              ...
# 10710                  UFO vs Bikini
# 10000               Village Monsters
# 10812               Village Monsters
# 8477                   War Trigger 3
# 10217                  War Trigger 3
#
#                                                      url  \
# 10648  https://store.steampowered.com/app/402210/Airp...
# 10737  https://store.steampowered.com/app/402210/Airp...
# 10779  https://store.steampowered.com/app/1637490/Alo...
# 10689  https://store.steampowered.com/app/1637490/Alo...
# 8311   https://store.steampowered.com/app/785110/Anim...
# ...                                                  ...
# 10710  https://store.steampowered.com/app/1660750/UFO...
# 10000  https://store.steampowered.com/app/679830/Vill...
# 10812  https://store.steampowered.com/app/679830/Vill...
# 8477   https://store.steampowered.com/app/298240/War_...
# 10217  https://store.steampowered.com/app/1210360/War...
#
#                          Developer                    Publisher  \
# 10648     Big Fat Simulations Inc.     Big Fat Simulations Inc.
# 10737     Big Fat Simulations Inc.     Big Fat Simulations Inc.
# 10779                        Gnelf                        Gnelf
# 10689                        Gnelf                        Gnelf
# 8311            Nikita "Ghost_RUS"              Ghost_RUS Games
# ...                            ...                          ...
# 10710                     Xenon Lu          WELOVEBOT CO., LTD.
# 10000                  Josh Bossie                  Josh Bossie
# 10812                  Josh Bossie                  Josh Bossie
# 8477   Rocketeer Games Studio, LLC  Rocketeer Games Studio, LLC
# 10217  Rocketeer Games Studio, LLC  Rocketeer Games Studio, LLC
#
#                                        user_defined_tags        platforms  \
# 10648                    Adventure, Simulation, Strategy         win, mac
# 10737                    Adventure, Simulation, Strategy         win, mac
# 10779  Adventure, Action, Arcade, Platformer, Action-...              win
# 10689  Adventure, Action, Arcade, Platformer, Action-...              win
# 8311          Indie, Casual, Anime, Psychological Horror              win
# ...                                                  ...              ...
# 10710  RPG, Sci-fi, Casual, Cute, Aliens, Action-Adve...              win
# 10000  Early Access, Life Sim, Time Management, Relax...  win, mac, linux
# 10812  Early Access, Life Sim, Time Management, Relax...  win, mac, linux
# 8477   Shooter, Free to Play, FPS, Multiplayer, Actio...         win, mac
# 10217  Free to Play, Action, Indie, Casual, Gore, Vio...         win, mac
#
#        is_collection  page_num
# 10648          False       496
# 10737          False       500
# 10779          False       502
# 10689          False       498
# 8311           False       400
# ...              ...       ...
# 10710          False       499
# 10000          False       469
# 10812          False       503
# 8477           False       407
# 10217          False       478
#
# [82 rows x 8 columns]
# Number of duplicate URLs = 41
# is_collection = False, page_num = 496, listing_num = 18, URL = https://store.steampowered.com/app/402210/Airport_Madness_Time_Machine/
# is_collection = False, page_num = 500, listing_num = 8, URL = https://store.steampowered.com/app/402210/Airport Madness: Time Machine/
# is_collection = False, page_num = 502, listing_num = 2, URL = https://store.steampowered.com/app/1637490/Alone on Mars/
# is_collection = False, page_num = 498, listing_num = 10, URL = https://store.steampowered.com/app/1637490/Alone_on_Mars/
# is_collection = False, page_num = 400, listing_num = 3, URL = https://store.steampowered.com/app/785110/Anime_girl_Or_Bottle/
# is_collection = False, page_num = 503, listing_num = 15, URL = https://store.steampowered.com/app/785110/Anime girl Or Bottle?/
# is_collection = False, page_num = 490, listing_num = 21, URL = https://store.steampowered.com/app/1449540/Atlas_Rogues/
# is_collection = False, page_num = 500, listing_num = 4, URL = https://store.steampowered.com/app/1449540/Atlas Rogues/
# is_collection = False, page_num = 359, listing_num = 11, URL = https://store.steampowered.com/app/695960/Awakening_The_Goblin_Kingdom_Collectors_Edition/
# is_collection = False, page_num = 501, listing_num = 25, URL = https://store.steampowered.com/app/695960/Awakening: The Goblin Kingdom Collector's Edition/
# is_collection = False, page_num = 503, listing_num = 17, URL = https://store.steampowered.com/app/1219230/Bingo Hall/
# is_collection = False, page_num = 365, listing_num = 15, URL = https://store.steampowered.com/app/1219230/Bingo_Hall/
# is_collection = False, page_num = 503, listing_num = 3, URL = https://store.steampowered.com/app/308270/Buzz Aldrin's Space Program Manager/
# is_collection = False, page_num = 473, listing_num = 16, URL = https://store.steampowered.com/app/308270/Buzz_Aldrins_Space_Program_Manager/
# is_collection = False, page_num = 483, listing_num = 13, URL = https://store.steampowered.com/app/928840/Cybarian_The_Time_Travelling_Warrior/
# is_collection = False, page_num = 502, listing_num = 23, URL = https://store.steampowered.com/app/928840/Cybarian: The Time Travelling Warrior/
# is_collection = False, page_num = 485, listing_num = 24, URL = https://store.steampowered.com/app/729460/Distant_Space_2/
# is_collection = False, page_num = 503, listing_num = 18, URL = https://store.steampowered.com/app/729460/Distant Space 2/
# is_collection = False, page_num = 400, listing_num = 18, URL = https://store.steampowered.com/app/603350/Dont_cut_your_hand/
# is_collection = False, page_num = 505, listing_num = 7, URL = https://store.steampowered.com/app/603350/Don't cut your hand/
# is_collection = False, page_num = 500, listing_num = 3, URL = https://store.steampowered.com/app/766630/Dust and Salt/
# is_collection = False, page_num = 471, listing_num = 7, URL = https://store.steampowered.com/app/766630/Dust_and_Salt/
# is_collection = False, page_num = 351, listing_num = 24, URL = https://store.steampowered.com/app/530630/Empires_Apart/
# is_collection = False, page_num = 505, listing_num = 18, URL = https://store.steampowered.com/app/530630/Empires Apart/
# is_collection = False, page_num = 503, listing_num = 22, URL = https://store.steampowered.com/app/1138910/Escape Mind/
# is_collection = False, page_num = 482, listing_num = 7, URL = https://store.steampowered.com/app/1138910/Escape_Mind/
# is_collection = False, page_num = 478, listing_num = 1, URL = https://store.steampowered.com/app/214590/Fairy_Bloom_Freesia/
# is_collection = False, page_num = 505, listing_num = 25, URL = https://store.steampowered.com/app/214590/Fairy Bloom Freesia/
# is_collection = False, page_num = 357, listing_num = 17, URL = https://store.steampowered.com/app/1542060/Forgotten_Spirits/
# is_collection = False, page_num = 504, listing_num = 24, URL = https://store.steampowered.com/app/1542060/Forgotten Spirits/
# is_collection = False, page_num = 500, listing_num = 7, URL = https://store.steampowered.com/app/1284550/Geometric Feel the Beats/
# is_collection = False, page_num = 402, listing_num = 20, URL = https://store.steampowered.com/app/1284550/Geometric_Feel_the_Beats/
# is_collection = False, page_num = 477, listing_num = 3, URL = https://store.steampowered.com/app/404510/Heavens_Hope__Special_Edition/
# is_collection = False, page_num = 505, listing_num = 11, URL = https://store.steampowered.com/app/404510/Heaven's Hope - Special Edition/
# is_collection = False, page_num = 502, listing_num = 16, URL = https://store.steampowered.com/app/297370/Hero of Many/
# is_collection = False, page_num = 490, listing_num = 4, URL = https://store.steampowered.com/app/297370/Hero_of_Many/
# is_collection = False, page_num = 364, listing_num = 11, URL = https://store.steampowered.com/app/686190/Killing_Time/
# is_collection = False, page_num = 436, listing_num = 25, URL = https://store.steampowered.com/app/493320/Killing_Time/
# is_collection = False, page_num = 493, listing_num = 13, URL = https://store.steampowered.com/app/805400/Mahjong_Solitaire/
# is_collection = False, page_num = 500, listing_num = 11, URL = https://store.steampowered.com/app/805400/Mahjong Solitaire/
# is_collection = False, page_num = 487, listing_num = 9, URL = https://store.steampowered.com/app/513360/Mu_Cartographer/
# is_collection = False, page_num = 504, listing_num = 20, URL = https://store.steampowered.com/app/513360/Mu Cartographer/
# is_collection = False, page_num = 503, listing_num = 14, URL = https://store.steampowered.com/app/1498600/Neko Chan/
# is_collection = False, page_num = 401, listing_num = 11, URL = https://store.steampowered.com/app/1498600/Neko_Chan/
# is_collection = False, page_num = 502, listing_num = 4, URL = https://store.steampowered.com/app/1044220/Oik Reloaded/
# is_collection = False, page_num = 482, listing_num = 2, URL = https://store.steampowered.com/app/1044220/Oik_Reloaded/
# is_collection = False, page_num = 375, listing_num = 4, URL = https://store.steampowered.com/app/1218890/Ollie__Bollie_Outdoor_Estate/
# is_collection = False, page_num = 504, listing_num = 11, URL = https://store.steampowered.com/app/1218890/Ollie & Bollie: Outdoor Estate/
# is_collection = False, page_num = 477, listing_num = 18, URL = https://store.steampowered.com/app/1419350/Outbreak_Endless_Nightmares/
# is_collection = False, page_num = 504, listing_num = 16, URL = https://store.steampowered.com/app/1419350/Outbreak: Endless Nightmares/
# is_collection = False, page_num = 354, listing_num = 3, URL = https://store.steampowered.com/app/992640/Pagan_Absent_Gods/
# is_collection = False, page_num = 502, listing_num = 13, URL = https://store.steampowered.com/app/992640/Pagan: Absent Gods/
# is_collection = False, page_num = 475, listing_num = 5, URL = https://store.steampowered.com/app/696460/Pixel_Traffic_Circle_Rush/
# is_collection = False, page_num = 504, listing_num = 12, URL = https://store.steampowered.com/app/696460/Pixel Traffic: Circle Rush/
# is_collection = False, page_num = 500, listing_num = 22, URL = https://store.steampowered.com/app/929320/RHEM II SE: The Cave/
# is_collection = False, page_num = 472, listing_num = 19, URL = https://store.steampowered.com/app/929320/RHEM_II_SE_The_Cave/
# is_collection = False, page_num = 505, listing_num = 9, URL = https://store.steampowered.com/app/636170/Reaching for Petals/
# is_collection = False, page_num = 421, listing_num = 22, URL = https://store.steampowered.com/app/636170/Reaching_for_Petals/
# is_collection = False, page_num = 137, listing_num = 5, URL = https://store.steampowered.com/app/8260/Sam__Max_Season_Two/
# is_collection = False, page_num = 144, listing_num = 9, URL = https://store.steampowered.com/app/8260/Sam__Max_201_Ice_Station_Santa/
# is_collection = False, page_num = 139, listing_num = 23, URL = https://store.steampowered.com/app/31220/Sam__Max_The_Devils_Playhouse/
# is_collection = False, page_num = 143, listing_num = 22, URL = https://store.steampowered.com/app/31220/Sam__Max_301_The_Penal_Zone/
# is_collection = False, page_num = 500, listing_num = 20, URL = https://store.steampowered.com/app/230980/Starseed Pilgrim/
# is_collection = False, page_num = 380, listing_num = 19, URL = https://store.steampowered.com/app/230980/Starseed_Pilgrim/
# is_collection = False, page_num = 74, listing_num = 9, URL = https://store.steampowered.com/app/40960/The_Stronghold_Collection/
# is_collection = False, page_num = 78, listing_num = 12, URL = https://store.steampowered.com/app/40960/Stronghold_2_Steam_Edition/
# is_collection = False, page_num = 504, listing_num = 23, URL = https://store.steampowered.com/app/255940/The 11th Hour/
# is_collection = False, page_num = 313, listing_num = 17, URL = https://store.steampowered.com/app/255940/The_11th_Hour/
# is_collection = False, page_num = 184, listing_num = 7, URL = https://store.steampowered.com/app/230820/The_Night_of_the_Rabbit/
# is_collection = False, page_num = 418, listing_num = 11, URL = https://store.steampowered.com/app/230820/The_Night_of_the_Rabbit_Premium_Edition/
# is_collection = False, page_num = 501, listing_num = 15, URL = https://store.steampowered.com/app/513230/The Underground Man/
# is_collection = False, page_num = 481, listing_num = 3, URL = https://store.steampowered.com/app/513230/The_Underground_Man/
# is_collection = False, page_num = 73, listing_num = 12, URL = https://store.steampowered.com/app/33220/Tom_Clancys_Splinter_Cell_Conviction_Deluxe_Edition/
# is_collection = False, page_num = 72, listing_num = 1, URL = https://store.steampowered.com/app/33220/Tom_Clancys_Splinter_Cell_Conviction/
# is_collection = False, page_num = 399, listing_num = 7, URL = https://store.steampowered.com/app/499460/Tomato_Jones/
# is_collection = False, page_num = 500, listing_num = 18, URL = https://store.steampowered.com/app/499460/Tomato Jones/
# is_collection = False, page_num = 504, listing_num = 6, URL = https://store.steampowered.com/app/1660750/UFO vs Bikini/
# is_collection = False, page_num = 499, listing_num = 6, URL = https://store.steampowered.com/app/1660750/UFO_vs_Bikini/
# is_collection = False, page_num = 469, listing_num = 14, URL = https://store.steampowered.com/app/679830/Village_Monsters/
# is_collection = False, page_num = 503, listing_num = 11, URL = https://store.steampowered.com/app/679830/Village Monsters/
# is_collection = False, page_num = 407, listing_num = 2, URL = https://store.steampowered.com/app/298240/War_Trigger_3/
# is_collection = False, page_num = 478, listing_num = 18, URL = https://store.steampowered.com/app/1210360/War_Trigger_3/

# %% [markdown]
# Show the page number on which duplicate titles are found and the number of pages with such duplicates

# %%
print(dup_titles["page_num"].unique().tolist(), dup_titles["page_num"].nunique())
# Out:
# [72, 73, 74, 78, 137, 139, 143, 144, 184, 313, 351, 354, 357, 359, 364, 365, 375, 380, 399, 400, 401, 402, 407, 418, 421, 436, 469, 471, 472, 473, 475, 477, 478, 481, 482, 483, 485, 487, 490, 493, 496, 498, 499, 500, 501, 502, 503, 504, 505] 49

# %% [markdown]
# **Observations**
# 1. All these URLs are not duplicated but the titles are duplicated.
# 2. From manual inspection of this list and inspecting some of the individual game listings on the Steam web store, one game in each pair of duplicates corresponds to a single episode within a multi-episode game. In other words, each multi-episode listing is a valid listing but it is like a collection since it refers to multiple individual games or episodes. Unlike a collection, multiple `app_id`s are not present in the URL of a multi-episode listing, so the `is_collection` column does not catch such listings. So, from each of these pairs that have been returned as duplicates, we'll manually drop the multi-episode listing and keep only the single-episode one.
# 3. The remaining are valid duplicated URLs. However, the source of these is not known since we weren't expecting duplicates. Without understanding where they are coming from, we'll drop both occurrences of the duplicated rows from the data.

# %% [markdown]
# Define a list of multi-episode listings by their URL

# %%
multi_episode_listings = [
    "https://store.steampowered.com/app/31220/Sam__Max_The_Devils_Playhouse/",
    "https://store.steampowered.com/app/8260/Sam__Max_Season_Two/",
    "https://store.steampowered.com/app/40960/The_Stronghold_Collection/",
    "https://store.steampowered.com/app/33220/Tom_Clancys_Splinter_Cell_Conviction_Deluxe_Edition/",
]

# %% [markdown]
# Remove multi-episode listings

# %%
df_listings = df_listings.query("url not in @multi_episode_listings")

# %% [markdown]
# After this removal, we'll drop the leftover duplicates `Title`s (from point 3. of the **Observations** above, we're dropping both occurrences of the duplicates so we'll set `keep=False` to do this)

# %%
df_listings = df_listings.dropna(subset=["Title"]).drop_duplicates(
    subset=["Title"], keep=False
)

# %% [markdown]
# There will then not be any duplicated `Title`s remaining

# %%
dup_titles = df_listings.dropna(subset=["Title"])[
    df_listings.dropna(subset=["Title"]).duplicated(subset=["Title"], keep=False)
]
print(f"Number of duplicate Titles = {int(len(dup_titles) / 2)}")
# Out:
# Number of duplicate Titles = 0

# %% [markdown]
# <a id="merge-with-price-from-search-results-dataset-acquired-using-`requests`"></a>
#
# ### 3.3. [Merge with Price from Search Results dataset acquired using `requests`](#merge-with-price-from-search-results-dataset-acquired-using-`requests`)

# %%
# %%time
dfm = df_listings.merge(
    df_search_results_requests[
        ["url", "discount_pct", "original_price", "discount_price"]
    ],
    on="url",
    how="left",
)
show_df(dfm.drop(columns=["user_defined_tags", "drm"]), 1)
show_df_dtypes_nans(dfm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa953_">
#   <caption>First & Last 1 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >review_type_all</th>
#       <th class="col_heading level0 col1" >overall_review_rating</th>
#       <th class="col_heading level0 col2" >pct_overall</th>
#       <th class="col_heading level0 col3" >pct_overall_threshold</th>
#       <th class="col_heading level0 col4" >pct_overall_lang</th>
#       <th class="col_heading level0 col5" >pct_overall_threshold_lang</th>
#       <th class="col_heading level0 col6" >platforms</th>
#       <th class="col_heading level0 col7" >num_steam_achievements</th>
#       <th class="col_heading level0 col8" >rating</th>
#       <th class="col_heading level0 col9" >rating_descriptors</th>
#       <th class="col_heading level0 col10" >review_type_positive</th>
#       <th class="col_heading level0 col11" >review_type_negative</th>
#       <th class="col_heading level0 col12" >review_language_mine</th>
#       <th class="col_heading level0 col13" >Title</th>
#       <th class="col_heading level0 col14" >Genre</th>
#       <th class="col_heading level0 col15" >Release Date</th>
#       <th class="col_heading level0 col16" >Early Access Release Date</th>
#       <th class="col_heading level0 col17" >Developer</th>
#       <th class="col_heading level0 col18" >Publisher</th>
#       <th class="col_heading level0 col19" >Franchise</th>
#       <th class="col_heading level0 col20" >languages</th>
#       <th class="col_heading level0 col21" >num_languages</th>
#       <th class="col_heading level0 col22" >page_num</th>
#       <th class="col_heading level0 col23" >listing_num</th>
#       <th class="col_heading level0 col24" >url</th>
#       <th class="col_heading level0 col25" >filename</th>
#       <th class="col_heading level0 col26" >app_id</th>
#       <th class="col_heading level0 col27" >is_collection</th>
#       <th class="col_heading level0 col28" >discount_pct</th>
#       <th class="col_heading level0 col29" >original_price</th>
#       <th class="col_heading level0 col30" >discount_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa953_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa953_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_aa953_row0_col1" class="data row0 col1" >Very Positive</td>
#       <td id="T_aa953_row0_col2" class="data row0 col2" >90.000000</td>
#       <td id="T_aa953_row0_col3" class="data row0 col3" >positive</td>
#       <td id="T_aa953_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_aa953_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_aa953_row0_col6" class="data row0 col6" >win</td>
#       <td id="T_aa953_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_aa953_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_aa953_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_aa953_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_aa953_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_aa953_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_aa953_row0_col13" class="data row0 col13" >Blazing Sails</td>
#       <td id="T_aa953_row0_col14" class="data row0 col14" >Action, Adventure, Casual, Indie, Early Access</td>
#       <td id="T_aa953_row0_col15" class="data row0 col15" >Nov 5, 2020</td>
#       <td id="T_aa953_row0_col16" class="data row0 col16" >Sep 9, 2020</td>
#       <td id="T_aa953_row0_col17" class="data row0 col17" >Get Up Games</td>
#       <td id="T_aa953_row0_col18" class="data row0 col18" >Iceberg Interactive</td>
#       <td id="T_aa953_row0_col19" class="data row0 col19" >Iceberg Interactive</td>
#       <td id="T_aa953_row0_col20" class="data row0 col20" >True</td>
#       <td id="T_aa953_row0_col21" class="data row0 col21" >15.000000</td>
#       <td id="T_aa953_row0_col22" class="data row0 col22" >50</td>
#       <td id="T_aa953_row0_col23" class="data row0 col23" >1</td>
#       <td id="T_aa953_row0_col24" class="data row0 col24" >https://store.steampowered.com/app/1158940/Blazing_Sails/</td>
#       <td id="T_aa953_row0_col25" class="data row0 col25" >p50_l1_Blazing_Sails.csv</td>
#       <td id="T_aa953_row0_col26" class="data row0 col26" >1158940</td>
#       <td id="T_aa953_row0_col27" class="data row0 col27" >False</td>
#       <td id="T_aa953_row0_col28" class="data row0 col28" >-30%</td>
#       <td id="T_aa953_row0_col29" class="data row0 col29" >14.99</td>
#       <td id="T_aa953_row0_col30" class="data row0 col30" >10.49</td>
#     </tr>
#     <tr>
#       <th id="T_aa953_level0_row1" class="row_heading level0 row1" >10034</th>
#       <td id="T_aa953_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_aa953_row1_col1" class="data row1 col1" >Mostly Positive</td>
#       <td id="T_aa953_row1_col2" class="data row1 col2" >73.000000</td>
#       <td id="T_aa953_row1_col3" class="data row1 col3" >positive</td>
#       <td id="T_aa953_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_aa953_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_aa953_row1_col6" class="data row1 col6" >win, mac</td>
#       <td id="T_aa953_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_aa953_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_aa953_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_aa953_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_aa953_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_aa953_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_aa953_row1_col13" class="data row1 col13" >Dead In Bermuda</td>
#       <td id="T_aa953_row1_col14" class="data row1 col14" >Adventure, Indie, RPG, Simulation, Strategy</td>
#       <td id="T_aa953_row1_col15" class="data row1 col15" >Aug 27, 2015</td>
#       <td id="T_aa953_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_aa953_row1_col17" class="data row1 col17" >Ishtar Games</td>
#       <td id="T_aa953_row1_col18" class="data row1 col18" >Dear Villagers</td>
#       <td id="T_aa953_row1_col19" class="data row1 col19" >Dead In Games, Dear Villagers</td>
#       <td id="T_aa953_row1_col20" class="data row1 col20" >True</td>
#       <td id="T_aa953_row1_col21" class="data row1 col21" >5.000000</td>
#       <td id="T_aa953_row1_col22" class="data row1 col22" >505</td>
#       <td id="T_aa953_row1_col23" class="data row1 col23" >24</td>
#       <td id="T_aa953_row1_col24" class="data row1 col24" >https://store.steampowered.com/app/384310/Dead In Bermuda/</td>
#       <td id="T_aa953_row1_col25" class="data row1 col25" >p505_l24_Dead_In_Bermuda.csv</td>
#       <td id="T_aa953_row1_col26" class="data row1 col26" >384310</td>
#       <td id="T_aa953_row1_col27" class="data row1 col27" >False</td>
#       <td id="T_aa953_row1_col28" class="data row1 col28" >None</td>
#       <td id="T_aa953_row1_col29" class="data row1 col29" >14.99</td>
#       <td id="T_aa953_row1_col30" class="data row1 col30" >None</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_06f21_">
#   <caption>Column Datatypes and Missing Values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >num_missing</th>
#       <th class="col_heading level0 col1" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06f21_level0_row0" class="row_heading level0 row0" >review_type_all</th>
#       <td id="T_06f21_row0_col0" class="data row0 col0" >10035</td>
#       <td id="T_06f21_row0_col1" class="data row0 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row1" class="row_heading level0 row1" >overall_review_rating</th>
#       <td id="T_06f21_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_06f21_row1_col1" class="data row1 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row2" class="row_heading level0 row2" >pct_overall</th>
#       <td id="T_06f21_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_06f21_row2_col1" class="data row2 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row3" class="row_heading level0 row3" >pct_overall_threshold</th>
#       <td id="T_06f21_row3_col0" class="data row3 col0" >14</td>
#       <td id="T_06f21_row3_col1" class="data row3 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row4" class="row_heading level0 row4" >pct_overall_lang</th>
#       <td id="T_06f21_row4_col0" class="data row4 col0" >10035</td>
#       <td id="T_06f21_row4_col1" class="data row4 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row5" class="row_heading level0 row5" >pct_overall_threshold_lang</th>
#       <td id="T_06f21_row5_col0" class="data row5 col0" >10035</td>
#       <td id="T_06f21_row5_col1" class="data row5 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row6" class="row_heading level0 row6" >platforms</th>
#       <td id="T_06f21_row6_col0" class="data row6 col0" >33</td>
#       <td id="T_06f21_row6_col1" class="data row6 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row7" class="row_heading level0 row7" >user_defined_tags</th>
#       <td id="T_06f21_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_06f21_row7_col1" class="data row7 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row8" class="row_heading level0 row8" >num_steam_achievements</th>
#       <td id="T_06f21_row8_col0" class="data row8 col0" >10035</td>
#       <td id="T_06f21_row8_col1" class="data row8 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row9" class="row_heading level0 row9" >drm</th>
#       <td id="T_06f21_row9_col0" class="data row9 col0" >8854</td>
#       <td id="T_06f21_row9_col1" class="data row9 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row10" class="row_heading level0 row10" >rating</th>
#       <td id="T_06f21_row10_col0" class="data row10 col0" >7686</td>
#       <td id="T_06f21_row10_col1" class="data row10 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row11" class="row_heading level0 row11" >rating_descriptors</th>
#       <td id="T_06f21_row11_col0" class="data row11 col0" >8272</td>
#       <td id="T_06f21_row11_col1" class="data row11 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row12" class="row_heading level0 row12" >review_type_positive</th>
#       <td id="T_06f21_row12_col0" class="data row12 col0" >10035</td>
#       <td id="T_06f21_row12_col1" class="data row12 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row13" class="row_heading level0 row13" >review_type_negative</th>
#       <td id="T_06f21_row13_col0" class="data row13 col0" >10035</td>
#       <td id="T_06f21_row13_col1" class="data row13 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row14" class="row_heading level0 row14" >review_language_mine</th>
#       <td id="T_06f21_row14_col0" class="data row14 col0" >10035</td>
#       <td id="T_06f21_row14_col1" class="data row14 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row15" class="row_heading level0 row15" >Title</th>
#       <td id="T_06f21_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_06f21_row15_col1" class="data row15 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row16" class="row_heading level0 row16" >Genre</th>
#       <td id="T_06f21_row16_col0" class="data row16 col0" >12</td>
#       <td id="T_06f21_row16_col1" class="data row16 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row17" class="row_heading level0 row17" >Release Date</th>
#       <td id="T_06f21_row17_col0" class="data row17 col0" >10</td>
#       <td id="T_06f21_row17_col1" class="data row17 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row18" class="row_heading level0 row18" >Early Access Release Date</th>
#       <td id="T_06f21_row18_col0" class="data row18 col0" >8939</td>
#       <td id="T_06f21_row18_col1" class="data row18 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row19" class="row_heading level0 row19" >Developer</th>
#       <td id="T_06f21_row19_col0" class="data row19 col0" >16</td>
#       <td id="T_06f21_row19_col1" class="data row19 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row20" class="row_heading level0 row20" >Publisher</th>
#       <td id="T_06f21_row20_col0" class="data row20 col0" >36</td>
#       <td id="T_06f21_row20_col1" class="data row20 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row21" class="row_heading level0 row21" >Franchise</th>
#       <td id="T_06f21_row21_col0" class="data row21 col0" >6643</td>
#       <td id="T_06f21_row21_col1" class="data row21 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row22" class="row_heading level0 row22" >languages</th>
#       <td id="T_06f21_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_06f21_row22_col1" class="data row22 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row23" class="row_heading level0 row23" >num_languages</th>
#       <td id="T_06f21_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_06f21_row23_col1" class="data row23 col1" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row24" class="row_heading level0 row24" >page_num</th>
#       <td id="T_06f21_row24_col0" class="data row24 col0" >0</td>
#       <td id="T_06f21_row24_col1" class="data row24 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row25" class="row_heading level0 row25" >listing_num</th>
#       <td id="T_06f21_row25_col0" class="data row25 col0" >0</td>
#       <td id="T_06f21_row25_col1" class="data row25 col1" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row26" class="row_heading level0 row26" >url</th>
#       <td id="T_06f21_row26_col0" class="data row26 col0" >0</td>
#       <td id="T_06f21_row26_col1" class="data row26 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row27" class="row_heading level0 row27" >filename</th>
#       <td id="T_06f21_row27_col0" class="data row27 col0" >0</td>
#       <td id="T_06f21_row27_col1" class="data row27 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row28" class="row_heading level0 row28" >app_id</th>
#       <td id="T_06f21_row28_col0" class="data row28 col0" >0</td>
#       <td id="T_06f21_row28_col1" class="data row28 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row29" class="row_heading level0 row29" >is_collection</th>
#       <td id="T_06f21_row29_col0" class="data row29 col0" >0</td>
#       <td id="T_06f21_row29_col1" class="data row29 col1" >bool</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row30" class="row_heading level0 row30" >discount_pct</th>
#       <td id="T_06f21_row30_col0" class="data row30 col0" >9467</td>
#       <td id="T_06f21_row30_col1" class="data row30 col1" >object</td>
#     </tr>
#     <tr>
#       <th id="T_06f21_level0_row31" class="row_heading level0 row31" >original
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 102 ms

# %% [markdown]
# <a id="export-combined-dataset-to-disk"></a>
#
# ## 4. [Export combined dataset to disk](#export-combined-dataset-to-disk)

# %% [markdown]
# We are now ready to vertically concatenate the merged datasets collected with `requests` and `selenium` and export the combined dataset to disk for use in analysis. However, inspecting the `original_price` and `discount_price` columns (shown below) we see that the currency has changed between the two datasets

# %%
show_df(dfm_sel[["original_price", "discount_price"]], 5)
show_df(dfm[["original_price", "discount_price"]], 5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e067f_">
#   <caption>First & Last 5 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >original_price</th>
#       <th class="col_heading level0 col1" >discount_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e067f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e067f_row0_col0" class="data row0 col0" >CDN$ 33.99</td>
#       <td id="T_e067f_row0_col1" class="data row0 col1" >CDN$ 30.59</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e067f_row1_col0" class="data row1 col0" >Free to Play</td>
#       <td id="T_e067f_row1_col1" class="data row1 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e067f_row2_col0" class="data row2 col0" >CDN$ 79.99</td>
#       <td id="T_e067f_row2_col1" class="data row2 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e067f_row3_col0" class="data row3 col0" >Free to Play</td>
#       <td id="T_e067f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e067f_row4_col0" class="data row4 col0" >CDN$ 49.99</td>
#       <td id="T_e067f_row4_col1" class="data row4 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row5" class="row_heading level0 row5" >878</th>
#       <td id="T_e067f_row5_col0" class="data row5 col0" >CDN$ 22.79</td>
#       <td id="T_e067f_row5_col1" class="data row5 col1" >CDN$ 17.09</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row6" class="row_heading level0 row6" >879</th>
#       <td id="T_e067f_row6_col0" class="data row6 col0" >CDN$ 22.79</td>
#       <td id="T_e067f_row6_col1" class="data row6 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row7" class="row_heading level0 row7" >880</th>
#       <td id="T_e067f_row7_col0" class="data row7 col0" >CDN$ 17.49</td>
#       <td id="T_e067f_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row8" class="row_heading level0 row8" >881</th>
#       <td id="T_e067f_row8_col0" class="data row8 col0" >CDN$ 8.99</td>
#       <td id="T_e067f_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e067f_level0_row9" class="row_heading level0 row9" >882</th>
#       <td id="T_e067f_row9_col0" class="data row9 col0" >CDN$ 22.79</td>
#       <td id="T_e067f_row9_col1" class="data row9 col1" >CDN$ 12.53</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e1799_">
#   <caption>First & Last 5 rows</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >original_price</th>
#       <th class="col_heading level0 col1" >discount_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1799_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1799_row0_col0" class="data row0 col0" >14.99</td>
#       <td id="T_e1799_row0_col1" class="data row0 col1" >10.49</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1799_row1_col0" class="data row1 col0" >19.99</td>
#       <td id="T_e1799_row1_col1" class="data row1 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1799_row2_col0" class="data row2 col0" >16.99</td>
#       <td id="T_e1799_row2_col1" class="data row2 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1799_row3_col0" class="data row3 col0" >4.99</td>
#       <td id="T_e1799_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1799_row4_col0" class="data row4 col0" >17.99</td>
#       <td id="T_e1799_row4_col1" class="data row4 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row5" class="row_heading level0 row5" >10030</th>
#       <td id="T_e1799_row5_col0" class="data row5 col0" >5.99</td>
#       <td id="T_e1799_row5_col1" class="data row5 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row6" class="row_heading level0 row6" >10031</th>
#       <td id="T_e1799_row6_col0" class="data row6 col0" >0.99</td>
#       <td id="T_e1799_row6_col1" class="data row6 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row7" class="row_heading level0 row7" >10032</th>
#       <td id="T_e1799_row7_col0" class="data row7 col0" >9.99</td>
#       <td id="T_e1799_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row8" class="row_heading level0 row8" >10033</th>
#       <td id="T_e1799_row8_col0" class="data row8 col0" >1.99</td>
#       <td id="T_e1799_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row9" class="row_heading level0 row9" >10034</th>
#       <td id="T_e1799_row9_col0" class="data row9 col0" >14.99</td>
#       <td id="T_e1799_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As mentioned in `3_requests_download.ipynb`, due to the slow speed of scraping with Selenium on a PC, a cloud-based virtual machine (VM) was used to scrape data using `requests`. However, the VM was created within a US-based allocation zone and so it was assigned an IP address based in the US. This is likely the reason for the currency in the larger dataset collected with `requests` being in USD while the smaller scraped dataset (using `selenium`) is in CAD. We cannot make a comparison across currencies, and also there are likely problems due to differences in search results based on geo-location. So a search originating in Canada (as is the case with data scraped using Selenium) possibly won't give the same results as one in the US (data scraped using `requests`).

# %% [markdown]
# The number of missing values in the user-review columns scraped with `selenium` are shown below and compared to the missing values when scraping with `requests`

# %%
user_review_cols = [
    "review_type_all",
    "review_type_positive",
    "review_type_negative",
    "review_language_mine",
    "pct_overall_lang",
    "pct_overall_threshold_lang",
    "num_steam_achievements",
]

# %%
d_nans = {col: dfm[col].isna().sum() for col in user_review_cols}
d_nans.update({"num_rows": len(dfm)})
d_nans_sel = {col: dfm_sel[col].isna().sum() for col in user_review_cols}
d_nans_sel.update({"num_rows": len(dfm_sel)})

display(
    pd.DataFrame.from_dict(d_nans, orient="index")
    .rename(columns={0: "requests"})
    .merge(
        pd.DataFrame.from_dict(d_nans_sel, orient="index").rename(
            columns={0: "selenium"}
        ),
        left_index=True,
        right_index=True,
        how="left",
    )
    .rename_axis("column_name")
    .style.set_caption("Rows with missing values in the merged datasets")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_98ac7_">
#   <caption>Rows with missing values in the merged datasets</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >requests</th>
#       <th class="col_heading level0 col1" >selenium</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98ac7_level0_row0" class="row_heading level0 row0" >review_type_all</th>
#       <td id="T_98ac7_row0_col0" class="data row0 col0" >10035</td>
#       <td id="T_98ac7_row0_col1" class="data row0 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row1" class="row_heading level0 row1" >review_type_positive</th>
#       <td id="T_98ac7_row1_col0" class="data row1 col0" >10035</td>
#       <td id="T_98ac7_row1_col1" class="data row1 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row2" class="row_heading level0 row2" >review_type_negative</th>
#       <td id="T_98ac7_row2_col0" class="data row2 col0" >10035</td>
#       <td id="T_98ac7_row2_col1" class="data row2 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row3" class="row_heading level0 row3" >review_language_mine</th>
#       <td id="T_98ac7_row3_col0" class="data row3 col0" >10035</td>
#       <td id="T_98ac7_row3_col1" class="data row3 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row4" class="row_heading level0 row4" >pct_overall_lang</th>
#       <td id="T_98ac7_row4_col0" class="data row4 col0" >10035</td>
#       <td id="T_98ac7_row4_col1" class="data row4 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row5" class="row_heading level0 row5" >pct_overall_threshold_lang</th>
#       <td id="T_98ac7_row5_col0" class="data row5 col0" >10035</td>
#       <td id="T_98ac7_row5_col1" class="data row5 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row6" class="row_heading level0 row6" >num_steam_achievements</th>
#       <td id="T_98ac7_row6_col0" class="data row6 col0" >10035</td>
#       <td id="T_98ac7_row6_col1" class="data row6 col1" >251</td>
#     </tr>
#     <tr>
#       <th id="T_98ac7_level0_row7" class="row_heading level0 row7" >num_rows</th>
#       <td id="T_98ac7_row7_col0" class="data row7 col0" >10035</td>
#       <td id="T_98ac7_row7_col1" class="data row7 col1" >883</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Notes**
# 1. These counts are taken from the merged datasets `dfm` (`requests`) and `dfm_sel` (scraped with `selenium`) taken from sections [2.3 (using `selenium`)](#merge-with-price-from-search-results-dataset-acquired-using-`selenium`) and [3.3 (using `requests`)](#merge-with-price-from-search-results-dataset-acquired-using-`requests`) in this notebook.
# 2. The last row `num_rows` is the total number of listings scraped.

# %% [markdown]
# The scraping of the user-review statistics from individual game listings has failed for `requests` with only missing values in this column. This was not the case for scraping with Selenium. There is a relatively small fraction of listings scraped using `selenium` with missing values, which primarily occurred since the particular listing was recently released at the time of scraping (first two and a half weeks of October 2021). This is compared to 100 percent of rows scraped with `requests` containing missing values. This difference may be attributed to the fact that the Selenium-based scraping approach involved scrolling down on the listing page in order to bring the user-reviews section into focus (loading the necessary javascript on the page) and only then scraped the user-review statistics. This is discussed in `2_selenium.ipynb`. When scraping with `requests`, scrolling to the bottom of the page wasn't done and this is likely the reason for the missing values in the columns related to user-reviews for every scraped listing gathered with `requests`. The missing values in the `num_steam_achievements` column is likely due to differences in the position of this element on the Steam store webpage for the Canadian and US versions of the site.

# %% [markdown]
# Unfortunately, both of these problems (currency and missing values) were not caught until approximately one third of the listings scraped with `requests` were already gathered. Taking these problems into account, the smaller Selenium-based dataset will be ignored for further analysis and only the dataset scraped with `requests` (with more rows of listings) will be considered and we will ignore the user-review columns which are filled with missing values. So we will only export the processed and merged version of that dataset (done in section [3.3](#merge-with-price-from-search-results-dataset-acquired-using-`requests`) of this notebook) to disk below and this will be used in further analysis in `7_eda.ipynb`

# %%
dfm.to_csv(processed_data_filepath, index=False)

# %% [markdown]
# ---

# %% [markdown]
# <span style="float:left">
#     <a href="./5_requests_process.ipynb"><< 5 - Requests process</a>
# </span>
#
# <span style="float:right">
#     <a href="./7_eda.ipynb">7 - Exploratory Data Analysis >></a>
# </span>
