# %% [markdown]
# # Scraping listings with the `requests` library

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import Python modules

# %%
import datetime
import os
import re
import time
from collections import OrderedDict
from glob import glob
from random import choice, uniform, random, randint, randrange

import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Import any custom modules

# %%
# Beautifulsoup modules to extract listing attributes
# %aimport src.bs4_helpers
import src.bs4_helpers as bsh

# Dictionary with key-value pairs to use if a scrape fails
# %aimport src.failure_records
from src.failure_records import dict_failed_extraction_from_listing_page

# Manually assembled list of browser headers to submit in a GET request
# %aimport src.webscraping_utils
from src.webscraping_utils import get_custom_headers_list

# %% [markdown]
# <a href="table-of-contents"></a>
#
# ## [Table of Contents](#table-of-contents)
# 0. [About](#about)
# 1. [User Inputs](#user-inputs)
# 2. [Load relevant columns from search results](#load-relevant-columns-from-search-results)
# 3. [Scrape](#scrape)
# 4. [Examine collected outputs](#examine-collected-outputs)

# %% [markdown]
# <a id="about"></a>
#
# ## 0. [About](#about)

# %% [markdown]
# In this notebook, we will iterate over the rows of the CSV file created by `5_filter_requests_listings.ipynb` and scrape the listing data in the URL column of that row. The scraping process will be described later in this notebook.

# %% [markdown]
# <a id="user-inputs"></a>
#
# ## 1. [User Inputs](#user-inputs)

# %% [markdown]
# Define variables that can be changed when running this notebook

# %%
PROJ_ROOT_DIR = os.getcwd()

# %%
# Cookies to be sent to Steam store to get access to listings that have an age requirement
cookies = {"mature_content": "1", "lastagecheckage": "14-0-1973"}

# Page numbers from CSV file to be scraped
pages_to_scrape = list(range(506, 550+1))

# Delay between sending request to successive listing URLs
min_pause_between_listings = 3.0
max_pause_between_listings = 5.4

# Delay between scraping listings from different pages of the page_num column in CSV file
min_pause_between_pages = 0.4
max_pause_between_pages = 0.8

# %% [markdown]
# Define variables that depend on the variables defined above
# - get paths to directories where single-row CSV files (produced after scraping) will be stored
# - create a list of manually assembled dictionaries of browser header, using the custom module imported earlier

# %%
# Path to data/raw/requests
data_dir = os.path.join(PROJ_ROOT_DIR, "data")
raw_data_dir = os.path.join(data_dir, "raw")
requests_data_dir = os.path.join(raw_data_dir, "requests")

# Create filepath for CSV containing non-duplicated listing URLs (created in
# 5_filter_requests_listings.ipynb) to be scraped
requests_listings_to_scrape_filepath = os.path.join(
    requests_data_dir,
    "requests_listings_to_scrape.csv",
)

# Get list of dicts of requests headers (when making a single
# request, a random header dict from this list will be chosen)
headers_list = get_custom_headers_list()

# %% [markdown]
# Define custom function to create a random birth date to append to request cookies ([link](https://stackoverflow.com/a/64072787/4057186))

# %%
def random_human_readable_timestamp_to_unix(
    start_date=datetime.datetime(1980, 4, 6),
    end_date=datetime.datetime(2000, 12, 7),
):
    """Create a random UNIX timestamp to use as birthdate in a request cookie."""
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)
    # print(random_date)
    return int(random_date.timestamp())

# %% [markdown]
# Define function to perform scraping of single game listing, using the following steps
# 1. Scrape listing
#    - Try to get the listing title
#      - if this is not possible, then the listing is either for a collection of games (won't scrape this) or is displaying content that we have not seen before (consider this an error and skip)
#        - if it is an errror, then assign attributes to this listing with `None` in all expected columns
#      - if this is possible, then call the `BeautifulSoup` custom helper module imported above and use it to scrape attributes from the listing
# 2. Export scraped attributes to CSV
# 3. Print time spent scraping

# %%
def scrape_listing_requests(soup, listing_num, page_num, raw_data_dir, url):
    """Scrape a single listing with the requests library."""
    print(f"Starting with listing {listing_num}")
    start_time = time.time()
    # 1. Scrape
    try:
        details_block = soup.find("div", {"id": "genresAndManufacturer"})
        game_title = (
            details_block.text.lower()
            .split("\ngenre: ")[0]
            .split("title: ")[-1]
            .title()
        )
        game_title = re.sub(r"\W+", "", game_title.replace(" ", "_"))
        print(f"Scraped game title for listing {listing_num} ({game_title})")
        try:
            listing_details = bsh.scrape_game_listing(soup)
            print(f"Scraped listing {listing_num}")
        except Exception:
            listing_details = dict_failed_extraction_from_listing_page()
            print(f"Error with listing {listing_num}. Used failure record.")
    except Exception:
        listing_details = dict_failed_extraction_from_listing_page()
        # Check if the listing is a collection
        try:
            collection_text = soup.find("h2", {"class": "no_margin"}).text.lower()
            game_title = re.sub(r"\W+", "", game_title.replace(" ", "_"))
            exp_collection_text = "items included in this package"
            if collection_text == exp_collection_text:
                game_title = soup.find("h2", {"class": "pageheader"}).text
                print(
                    "Listing is collection of games. Used failure record. "
                    "Skipped page scrape."
                )
            else:
                game_title = "Unknown"
                print(
                    f"For included items, got {collection_text}. "
                    "Used failure record."
                )
        except Exception:
            print("Unknown reason for error.")

    # 2. Export to CSV
    fname = f"p{page_num}_l{listing_num}_{game_title}.csv"
    df_listing_details = (
        pd.DataFrame.from_records([listing_details])
        .assign(page_num=page_num)
        .assign(listing_num=listing_num)
        .assign(url=url)
    )
    # display(df_listing_details)
    listing_filepath = os.path.join(requests_data_dir, fname)
    df_listing_details.to_csv(listing_filepath, index=False)
    print(f"Exported listing attributes for {game_title} to CSV file")
    
    # 3. Print duration
    duration = time.time() - start_time
    print(f"Done with page {page_num} listing {listing_num} in {duration:.3f} sec.")

# %% [markdown]
# <a id="load-relevant-columns-from-search-results"></a>
#
# ## 2. [Load relevant columns from search results](#load-relevant-columns-from-search-results)

# %% [markdown]
# We'll start by loading the CSV file of listings to be scraped. Recall that this was created by `5_filter_requests_listings.ipynb`

# %%
# %%time
df = pd.read_csv(requests_listings_to_scrape_filepath)
display(df.head(5).append(df.tail(5)))
# Out:
#        page  listing_counter                       title  \
# 0        50                1               Blazing_Sails
# 1        50                2  LEGO_Harry_Potter_Years_14
# 2        50                3           Source_of_Madness
# 3        50                4                        Roll
# 4        50                5               Cloud_Gardens
# 45994  2232                7                 CasterLords
# 45995  2232                8              Animal_Shelter
# 45996  2232                9       Ekko__A_Thiefs_Melody
# 45997  2232               11     Animal_Shelter_Prologue
# 45998  2232               12        Dynasty_of_the_Sands
#
#                                                      url
# 0      https://store.steampowered.com/app/1158940/Bla...
# 1      https://store.steampowered.com/app/21130/LEGO_...
# 2      https://store.steampowered.com/app/1315610/Sou...
# 3       https://store.steampowered.com/app/1585910/Roll/
# 4      https://store.steampowered.com/app/1372320/Clo...
# 45994  https://store.steampowered.com/app/812780/Cast...
# 45995  https://store.steampowered.com/app/1239320/Ani...
# 45996  https://store.steampowered.com/app/1344990/Ekk...
# 45997  https://store.steampowered.com/app/1661260/Ani...
# 45998  https://store.steampowered.com/app/1143070/Dyn...
# CPU times: user 77.8 ms, sys: 24.7 ms, total: 102 ms
# Wall time: 102 ms

# %% [markdown]
# **Notes**
# 1. These are the vertically concatenated search results. Each page of search results has the same page number (see the `page` column) and a different `listing_counter`. Duplicated listings are excluded from this `DataFrame` so each URL is unique.

# %% [markdown]
# <a id="scrape"></a>
#
# ## 3. [Scrape](#scrape)

# %% [markdown]
# We'll now iterate over each row of the `DataFrame` for the CSV file, retrieve HTML from the URL column and scrape the listing attributes. We will scrape each listing on a single page of search results (from the `page` column in the above `DataFrame`) and then pause before scraping listings from the next page. This willl be repeated for every page in the list of pages (`pages_to_scrape`) to be scraped (defined in the [User Inputs](#user-inputs) section earlier).
#
# The steps in this process are as follows
# 1. Get listing page number, URL and title
# 2. Send a GET request to get HTML for each URL
#    - as part of this, get a random
#      - header from the list of headers above
#      - birth date from the helper function defined above to generate this date
# 3. Scrape HTML to get listing attributes
# 4. Pause before sending next GET request
# 5. Pause if at end of a single page from the CSV file

# %%
# %%time
# Iterate over all listings belonging to a single page of search
# results (in the above DataFrame)
for page_to_scrape in pages_to_scrape:
    for idx, row in df.query(
        f"page == {page_to_scrape}"
    ).reset_index(drop=True).iterrows():
        # Get listing URL, page number and title
        page_num = row["page"]
        url = row["url"]
        listing_num = row["listing_counter"]

        # 2. Send GET request
        # # Retrieve random header
        headers = choice(headers_list)
        # # Create random birth date
        cookies["birthtime"] = str(random_human_readable_timestamp_to_unix())
        start_time = time.time()
        # # Send GET request
        with requests.Session() as r:
            response = r.get(
                url=url,
                cookies=cookies,
                headers=headers,
            )
        print(
            f"Received response to request from URL for "
            f"page {page_num} listing {listing_num} ({os.path.basename(url.rstrip('/'))})"
        )

        # 3. Scraping code
        soup = BeautifulSoup(response.content, "html.parser")
        # print(soup.prettify())
        scrape_listing_requests(soup, listing_num, page_num, requests_data_dir, url)

        time_spent = time.time() - start_time
        print(f"Time spent processing = {time_spent:.2f} seconds.")

        # 4. Pause between listings
        inter_listing_pause = uniform(
            min_pause_between_listings, max_pause_between_listings
        )
        print(f"Pausing for {inter_listing_pause:.2f} seconds...", end="")
        time.sleep(inter_listing_pause)
        print("done.\n")

    # 5. Pause between pages
    inter_page_pause = uniform(min_pause_between_pages, max_pause_between_pages)
    print(
        f"Reached end of page {page_to_scrape}. "
        f"Pausing for {inter_page_pause:.2f} seconds between pages...",
        end="",
    )
    if page_to_scrape < max(pages_to_scrape):
        time.sleep(inter_page_pause)
    print("done.\n")
# Out:
# Received response to request from URL for page 471 listing 1 (Crazy_Stone_Deep_Learning_The_First_Edition)
# Starting with listing 1
# Scraped game title for listing 1 (Crazy_Stone_Deep_Learning_The_First_Edition)
# Scraped listing 1
# Exported listing attributes for Crazy_Stone_Deep_Learning_The_First_Edition to CSV file
# Done with page 471 listing 1 in 0.073 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 3.11 seconds...done.
#
# Received response to request from URL for page 471 listing 2 (Dark_Zone_Defense)
# Starting with listing 2
# Scraped game title for listing 2 (Dark_Zone_Defense)
# Scraped listing 2
# Exported listing attributes for Dark_Zone_Defense to CSV file
# Done with page 471 listing 2 in 0.074 sec.
# Time spent processing = 0.59 seconds.
# Pausing for 4.71 seconds...done.
#
# Received response to request from URL for page 471 listing 3 (A_Trip_to_Yugoslavia_Directors_Cut)
# Starting with listing 3
# Scraped game title for listing 3 (A_Trip_To_Yugoslavia_DirectorS_Cut)
# Scraped listing 3
# Exported listing attributes for A_Trip_To_Yugoslavia_DirectorS_Cut to CSV file
# Done with page 471 listing 3 in 0.085 sec.
# Time spent processing = 0.94 seconds.
# Pausing for 3.08 seconds...done.
#
# Received response to request from URL for page 471 listing 4 (Starship_Traveller)
# Starting with listing 4
# Scraped game title for listing 4 (Starship_Traveller)
# Scraped listing 4
# Exported listing attributes for Starship_Traveller to CSV file
# Done with page 471 listing 4 in 0.077 sec.
# Time spent processing = 0.61 seconds.
# Pausing for 3.64 seconds...done.
#
# Received response to request from URL for page 471 listing 5 (Control_Craft_3)
# Starting with listing 5
# Scraped game title for listing 5 (Control_Craft_3)
# Scraped listing 5
# Exported listing attributes for Control_Craft_3 to CSV file
# Done with page 471 listing 5 in 0.080 sec.
# Time spent processing = 0.61 seconds.
# Pausing for 3.99 seconds...done.
#
# Received response to request from URL for page 471 listing 6 (Alveole)
# Starting with listing 6
# Scraped game title for listing 6 (Alveole)
# Scraped listing 6
# Exported listing attributes for Alveole to CSV file
# Done with page 471 listing 6 in 0.079 sec.
# Time spent processing = 0.65 seconds.
# Pausing for 3.58 seconds...done.
#
# Received response to request from URL for page 471 listing 7 (Dust_and_Salt)
# Starting with listing 7
# Scraped game title for listing 7 (Dust_And_Salt)
# Scraped listing 7
# Exported listing attributes for Dust_And_Salt to CSV file
# Done with page 471 listing 7 in 0.077 sec.
# Time spent processing = 0.47 seconds.
# Pausing for 4.38 seconds...done.
#
# Received response to request from URL for page 471 listing 8 (Super_Life_of_Pixel)
# Starting with listing 8
# Scraped game title for listing 8 (Super_Life_Of_Pixel)
# Scraped listing 8
# Exported listing attributes for Super_Life_Of_Pixel to CSV file
# Done with page 471 listing 8 in 0.078 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 5.34 seconds...done.
#
# Received response to request from URL for page 471 listing 9 (Save_Home)
# Starting with listing 9
# Scraped game title for listing 9 (Save_Home)
# Scraped listing 9
# Exported listing attributes for Save_Home to CSV file
# Done with page 471 listing 9 in 0.080 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.19 seconds...done.
#
# Received response to request from URL for page 471 listing 10 (Paper_Train_Traffic)
# Starting with listing 10
# Scraped game title for listing 10 (Paper_Train_Traffic)
# Scraped listing 10
# Exported listing attributes for Paper_Train_Traffic to CSV file
# Done with page 471 listing 10 in 0.081 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 4.57 seconds...done.
#
# Received response to request from URL for page 471 listing 11 (The_Great_Perhaps)
# Starting with listing 11
# Scraped game title for listing 11 (The_Great_Perhaps)
# Scraped listing 11
# Exported listing attributes for The_Great_Perhaps to CSV file
# Done with page 471 listing 11 in 0.087 sec.
# Time spent processing = 0.66 seconds.
# Pausing for 3.28 seconds...done.
#
# Received response to request from URL for page 471 listing 12 (Wildlife_Park_2__Horses)
# Starting with listing 12
# Scraped game title for listing 12 (Wildlife_Park_2__Horses)
# Scraped listing 12
# Exported listing attributes for Wildlife_Park_2__Horses to CSV file
# Done with page 471 listing 12 in 0.093 sec.
# Time spent processing = 0.47 seconds.
# Pausing for 4.19 seconds...done.
#
# Received response to request from URL for page 471 listing 13 (Rocketbirds_2_Evolution)
# Starting with listing 13
# Scraped game title for listing 13 (Rocketbirds_2_Evolution)
# Scraped listing 13
# Exported listing attributes for Rocketbirds_2_Evolution to CSV file
# Done with page 471 listing 13 in 0.087 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 5.03 seconds...done.
#
# Received response to request from URL for page 471 listing 14 (Double)
# Starting with listing 14
# Scraped game title for listing 14 (Double)
# Scraped listing 14
# Exported listing attributes for Double to CSV file
# Done with page 471 listing 14 in 0.075 sec.
# Time spent processing = 0.56 seconds.
# Pausing for 4.33 seconds...done.
#
# Received response to request from URL for page 471 listing 15 (Kitty_Tactics)
# Starting with listing 15
# Scraped game title for listing 15 (Kitty_Tactics)
# Scraped listing 15
# Exported listing attributes for Kitty_Tactics to CSV file
# Done with page 471 listing 15 in 0.075 sec.
# Time spent processing = 0.46 seconds.
# Pausing for 3.51 seconds...done.
#
# Received response to request from URL for page 471 listing 16 (Gigachess)
# Starting with listing 16
# Scraped game title for listing 16 (Gigachess)
# Scraped listing 16
# Exported listing attributes for Gigachess to CSV file
# Done with page 471 listing 16 in 0.079 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 5.19 seconds...done.
#
# Received response to request from URL for page 471 listing 17 (aMAZE_Classic)
# Starting with listing 17
# Scraped game title for listing 17 (Amaze_Classic)
# Scraped listing 17
# Exported listing attributes for Amaze_Classic to CSV file
# Done with page 471 listing 17 in 0.077 sec.
# Time spent processing = 0.77 seconds.
# Pausing for 3.23 seconds...done.
#
# Received response to request from URL for page 471 listing 18 (Shooting_Stars)
# Starting with listing 18
# Scraped game title for listing 18 (Shooting_Stars)
# Scraped listing 18
# Exported listing attributes for Shooting_Stars to CSV file
# Done with page 471 listing 18 in 0.086 sec.
# Time spent processing = 0.93 seconds.
# Pausing for 4.14 seconds...done.
#
# Received response to request from URL for page 471 listing 19 (Draw_It_2)
# Starting with listing 19
# Scraped game title for listing 19 (Draw_It_2)
# Scraped listing 19
# Exported listing attributes for Draw_It_2 to CSV file
# Done with page 471 listing 19 in 0.079 sec.
# Time spent processing = 0.64 seconds.
# Pausing for 4.62 seconds...done.
#
# Received response to request from URL for page 471 listing 20 (Everyday_Genius_SquareLogic)
# Starting with listing 20
# Scraped game title for listing 20 (Everyday_Genius_Squarelogic)
# Scraped listing 20
# Exported listing attributes for Everyday_Genius_Squarelogic to CSV file
# Done with page 471 listing 20 in 0.074 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 4.39 seconds...done.
#
# Received response to request from URL for page 471 listing 21 (Weable)
# Starting with listing 21
# Scraped game title for listing 21 (Weable)
# Scraped listing 21
# Exported listing attributes for Weable to CSV file
# Done with page 471 listing 21 in 0.078 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 3.91 seconds...done.
#
# Received response to request from URL for page 471 listing 22 (Cultures__8th_Wonder_of_the_World)
# Starting with listing 22
# Scraped game title for listing 22 (Cultures__8Th_Wonder_Of_The_World)
# Scraped listing 22
# Exported listing attributes for Cultures__8Th_Wonder_Of_The_World to CSV file
# Done with page 471 listing 22 in 0.078 sec.
# Time spent processing = 0.44 seconds.
# Pausing for 3.51 seconds...done.
#
# Received response to request from URL for page 471 listing 23 (Achievement_Machine)
# Starting with listing 23
# Scraped game title for listing 23 (Achievement_Machine)
# Scraped listing 23
# Exported listing attributes for Achievement_Machine to CSV file
# Done with page 471 listing 23 in 0.075 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 4.28 seconds...done.
#
# Received response to request from URL for page 471 listing 24 (Paint_Chips)
# Starting with listing 24
# Scraped game title for listing 24 (Paint_Chips)
# Scraped listing 24
# Exported listing attributes for Paint_Chips to CSV file
# Done with page 471 listing 24 in 0.076 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 5.19 seconds...done.
#
# Received response to request from URL for page 471 listing 25 (Supipara__Chapter_2_Spring_Has_Come)
# Starting with listing 25
# Scraped game title for listing 25 (Supipara__Chapter_2_Spring_Has_Come)
# Scraped listing 25
# Exported listing attributes for Supipara__Chapter_2_Spring_Has_Come to CSV file
# Done with page 471 listing 25 in 0.075 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 4.80 seconds...done.
#
# Reached end of page 471. Pausing for 0.56 seconds between pages...done.
#
# Received response to request from URL for page 472 listing 1 (The_Old_City_Leviathan)
# Starting with listing 1
# Scraped game title for listing 1 (The_Old_City_Leviathan)
# Scraped listing 1
# Exported listing attributes for The_Old_City_Leviathan to CSV file
# Done with page 472 listing 1 in 0.076 sec.
# Time spent processing = 0.39 seconds.
# Pausing for 4.08 seconds...done.
#
# Received response to request from URL for page 472 listing 2 (Samurai_Riot)
# Starting with listing 2
# Scraped game title for listing 2 (Samurai_Riot)
# Scraped listing 2
# Exported listing attributes for Samurai_Riot to CSV file
# Done with page 472 listing 2 in 0.080 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 4.30 seconds...done.
#
# Received response to request from URL for page 472 listing 3 (Race_With_Ryan)
# Starting with listing 3
# Scraped game title for listing 3 (Race_With_Ryan)
# Scraped listing 3
# Exported listing attributes for Race_With_Ryan to CSV file
# Done with page 472 listing 3 in 0.079 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.92 seconds...done.
#
# Received response to request from URL for page 472 listing 4 (Spellsworn)
# Starting with listing 4
# Scraped game title for listing 4 (Spellsworn)
# Scraped listing 4
# Exported listing attributes for Spellsworn to CSV file
# Done with page 472 listing 4 in 0.085 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 3.66 seconds...done.
#
# Received response to request from URL for page 472 listing 5 (Kings_Bounty_Legions)
# Starting with listing 5
# Scraped game title for listing 5 (KingS_Bounty_Legions)
# Scraped listing 5
# Exported listing attributes for KingS_Bounty_Legions to CSV file
# Done with page 472 listing 5 in 0.079 sec.
# Time spent processing = 0.66 seconds.
# Pausing for 3.65 seconds...done.
#
# Received response to request from URL for page 472 listing 6 (Algo_Bot)
# Starting with listing 6
# Scraped game title for listing 6 (Algo_Bot)
# Scraped listing 6
# Exported listing attributes for Algo_Bot to CSV file
# Done with page 472 listing 6 in 0.079 sec.
# Time spent processing = 0.59 seconds.
# Pausing for 3.34 seconds...done.
#
# Received response to request from URL for page 472 listing 7 (Brimstone_Brawlers__Early_Access)
# Starting with listing 7
# Scraped game title for listing 7 (Brimstone_Brawlers__Early_Access)
# Scraped listing 7
# Exported listing attributes for Brimstone_Brawlers__Early_Access to CSV file
# Done with page 472 listing 7 in 0.080 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.52 seconds...done.
#
# Received response to request from URL for page 472 listing 8 (Mighty_Gunvolt)
# Starting with listing 8
# Scraped game title for listing 8 (Mighty_Gunvolt)
# Scraped listing 8
# Exported listing attributes for Mighty_Gunvolt to CSV file
# Done with page 472 listing 8 in 0.070 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.77 seconds...done.
#
# Received response to request from URL for page 472 listing 9 (Machines_At_War_3)
# Starting with listing 9
# Scraped game title for listing 9 (Machines_At_War_3)
# Scraped listing 9
# Exported listing attributes for Machines_At_War_3 to CSV file
# Done with page 472 listing 9 in 0.085 sec.
# Time spent processing = 0.44 seconds.
# Pausing for 5.03 seconds...done.
#
# Received response to request from URL for page 472 listing 10 (Deep_Diving_Simulator)
# Starting with listing 10
# Scraped game title for listing 10 (Deep_Diving_Simulator)
# Scraped listing 10
# Exported listing attributes for Deep_Diving_Simulator to CSV file
# Done with page 472 listing 10 in 0.088 sec.
# Time spent processing = 0.71 seconds.
# Pausing for 4.45 seconds...done.
#
# Received response to request from URL for page 472 listing 11 (Cat_on_a_Diet)
# Starting with listing 11
# Scraped game title for listing 11 (Cat_On_A_Diet)
# Scraped listing 11
# Exported listing attributes for Cat_On_A_Diet to CSV file
# Done with page 472 listing 11 in 0.071 sec.
# Time spent processing = 0.40 seconds.
# Pausing for 4.69 seconds...done.
#
# Received response to request from URL for page 472 listing 12 (Dungeon_Hunter_Champions)
# Starting with listing 12
# Scraped game title for listing 12 (Dungeon_Hunter_Champions)
# Scraped listing 12
# Exported listing attributes for Dungeon_Hunter_Champions to CSV file
# Done with page 472 listing 12 in 0.077 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 3.26 seconds...done.
#
# Received response to request from URL for page 472 listing 13 (Argonus_and_the_Gods_of_Stone)
# Starting with listing 13
# Scraped game title for listing 13 (Argonus_And_The_Gods_Of_Stone)
# Scraped listing 13
# Exported listing attributes for Argonus_And_The_Gods_Of_Stone to CSV file
# Done with page 472 listing 13 in 0.080 sec.
# Time spent processing = 0.50 seconds.
# Pausing for 3.75 seconds...done.
#
# Received response to request from URL for page 472 listing 14 (Chess_Brain)
# Starting with listing 14
# Scraped game title for listing 14 (Chess_Brain)
# Scraped listing 14
# Exported listing attributes for Chess_Brain to CSV file
# Done with page 472 listing 14 in 0.086 sec.
# Time spent processing = 0.69 seconds.
# Pausing for 4.21 seconds...done.
#
# Received response to request from URL for page 472 listing 15 (Groove_Gunner)
# Starting with listing 15
# Scraped game title for listing 15 (Groove_Gunner)
# Scraped listing 15
# Exported listing attributes for Groove_Gunner to CSV file
# Done with page 472 listing 15 in 0.090 sec.
# Time spent processing = 0.68 seconds.
# Pausing for 3.95 seconds...done.
#
# Received response to request from URL for page 472 listing 16 (Nemesis_Realms)
# Starting with listing 16
# Scraped game title for listing 16 (Nemesis_Realms)
# Scraped listing 16
# Exported listing attributes for Nemesis_Realms to CSV file
# Done with page 472 listing 16 in 0.076 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.73 seconds...done.
#
# Received response to request from URL for page 472 listing 17 (Rescue_Team_Planet_Savers)
# Starting with listing 17
# Scraped game title for listing 17 (Rescue_Team_Planet_Savers)
# Scraped listing 17
# Exported listing attributes for Rescue_Team_Planet_Savers to CSV file
# Done with page 472 listing 17 in 0.074 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 3.68 seconds...done.
#
# Received response to request from URL for page 472 listing 18 (Antisphere)
# Starting with listing 18
# Scraped game title for listing 18 (Antisphere)
# Scraped listing 18
# Exported listing attributes for Antisphere to CSV file
# Done with page 472 listing 18 in 0.074 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.37 seconds...done.
#
# Received response to request from URL for page 472 listing 19 (RHEM_II_SE_The_Cave)
# Starting with listing 19
# Scraped game title for listing 19 (Rhem_Ii_Se_The_Cave)
# Scraped listing 19
# Exported listing attributes for Rhem_Ii_Se_The_Cave to CSV file
# Done with page 472 listing 19 in 0.067 sec.
# Time spent processing = 0.39 seconds.
# Pausing for 5.15 seconds...done.
#
# Received response to request from URL for page 472 listing 20 (Steel_Alcimus)
# Starting with listing 20
# Scraped game title for listing 20 (Steel_Alcimus)
# Scraped listing 20
# Exported listing attributes for Steel_Alcimus to CSV file
# Done with page 472 listing 20 in 0.087 sec.
# Time spent processing = 0.71 seconds.
# Pausing for 4.68 seconds...done.
#
# Received response to request from URL for page 472 listing 21 (Putin_VS_ISIS)
# Starting with listing 21
# Scraped game title for listing 21 (Putin_Vs_Isis)
# Scraped listing 21
# Exported listing attributes for Putin_Vs_Isis to CSV file
# Done with page 472 listing 21 in 0.077 sec.
# Time spent processing = 0.81 seconds.
# Pausing for 4.63 seconds...done.
#
# Received response to request from URL for page 472 listing 22 (Element_TD)
# Starting with listing 22
# Scraped game title for listing 22 (Element_Td)
# Scraped listing 22
# Exported listing attributes for Element_Td to CSV file
# Done with page 472 listing 22 in 0.067 sec.
# Time spent processing = 0.39 seconds.
# Pausing for 4.45 seconds...done.
#
# Received response to request from URL for page 472 listing 23 (Dark_Fall_2_Lights_Out)
# Starting with listing 23
# Scraped game title for listing 23 (Dark_Fall_2_Lights_Out)
# Scraped listing 23
# Exported listing attributes for Dark_Fall_2_Lights_Out to CSV file
# Done with page 472 listing 23 in 0.070 sec.
# Time spent processing = 0.47 seconds.
# Pausing for 4.97 seconds...done.
#
# Received response to request from URL for page 472 listing 24 (Forge_Quest)
# Starting with listing 24
# Scraped game title for listing 24 (Forge_Quest)
# Scraped listing 24
# Exported listing attributes for Forge_Quest to CSV file
# Done with page 472 listing 24 in 0.070 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 5.17 seconds...done.
#
# Received response to request from URL for page 472 listing 25 (Planet_RIX13)
# Starting with listing 25
# Scraped game title for listing 25 (Planet_Rix13)
# Scraped listing 25
# Exported listing attributes for Planet_Rix13 to CSV file
# Done with page 472 listing 25 in 0.071 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 3.30 seconds...done.
#
# Reached end of page 472. Pausing for 0.68 seconds between pages...done.
#
# Received response to request from URL for page 473 listing 1 (PAKO__Car_Chase_Simulator)
# Starting with listing 1
# Scraped game title for listing 1 (Pako__Car_Chase_Simulator)
# Scraped listing 1
# Exported listing attributes for Pako__Car_Chase_Simulator to CSV file
# Done with page 473 listing 1 in 0.080 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 4.09 seconds...done.
#
# Received response to request from URL for page 473 listing 2 (Unlock_The_King_3)
# Starting with listing 2
# Scraped game title for listing 2 (Unlock_The_King_3)
# Scraped listing 2
# Exported listing attributes for Unlock_The_King_3 to CSV file
# Done with page 473 listing 2 in 0.073 sec.
# Time spent processing = 0.66 seconds.
# Pausing for 5.28 seconds...done.
#
# Received response to request from URL for page 473 listing 4 (Neon_Space)
# Starting with listing 4
# Scraped game title for listing 4 (Neon_Space)
# Scraped listing 4
# Exported listing attributes for Neon_Space to CSV file
# Done with page 473 listing 4 in 0.077 sec.
# Time spent processing = 0.61 seconds.
# Pausing for 4.10 seconds...done.
#
# Received response to request from URL for page 473 listing 5 (Mare_Nostrvm)
# Starting with listing 5
# Scraped game title for listing 5 (Mare_Nostrvm)
# Scraped listing 5
# Exported listing attributes for Mare_Nostrvm to CSV file
# Done with page 473 listing 5 in 0.071 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 5.26 seconds...done.
#
# Received response to request from URL for page 473 listing 6 (Inexistence_Rebirth)
# Starting with listing 6
# Scraped game title for listing 6 (Inexistence_Rebirth)
# Scraped listing 6
# Exported listing attributes for Inexistence_Rebirth to CSV file
# Done with page 473 listing 6 in 0.079 sec.
# Time spent processing = 0.48 seconds.
# Pausing for 4.68 seconds...done.
#
# Received response to request from URL for page 473 listing 7 (Collapse)
# Starting with listing 7
# Scraped game title for listing 7 (Collapse)
# Scraped listing 7
# Exported listing attributes for Collapse to CSV file
# Done with page 473 listing 7 in 0.079 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 4.60 seconds...done.
#
# Received response to request from URL for page 473 listing 8 (Just_Arms)
# Starting with listing 8
# Scraped game title for listing 8 (Just_Arms)
# Scraped listing 8
# Exported listing attributes for Just_Arms to CSV file
# Done with page 473 listing 8 in 0.075 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 3.04 seconds...done.
#
# Received response to request from URL for page 473 listing 9 (Lets_Create_Pottery_VR)
# Starting with listing 9
# Scraped game title for listing 9 (LetS_Create_Pottery_Vr)
# Scraped listing 9
# Exported listing attributes for LetS_Create_Pottery_Vr to CSV file
# Done with page 473 listing 9 in 0.074 sec.
# Time spent processing = 0.40 seconds.
# Pausing for 4.23 seconds...done.
#
# Received response to request from URL for page 473 listing 10 (Rise_of_Mavros)
# Starting with listing 10
# Scraped game title for listing 10 (Rise_Of_Mavros)
# Scraped listing 10
# Exported listing attributes for Rise_Of_Mavros to CSV file
# Done with page 473 listing 10 in 0.074 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 3.97 seconds...done.
#
# Received response to request from URL for page 473 listing 11 (King_Kaiju)
# Starting with listing 11
# Scraped game title for listing 11 (King_Kaiju)
# Scraped listing 11
# Exported listing attributes for King_Kaiju to CSV file
# Done with page 473 listing 11 in 0.071 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 3.02 seconds...done.
#
# Received response to request from URL for page 473 listing 12 (Gun_Done)
# Starting with listing 12
# Scraped game title for listing 12 (Gun_Done)
# Scraped listing 12
# Exported listing attributes for Gun_Done to CSV file
# Done with page 473 listing 12 in 0.071 sec.
# Time spent processing = 0.52 seconds.
# Pausing for 4.40 seconds...done.
#
# Received response to request from URL for page 473 listing 13 (Please_Knock_on_My_Door)
# Starting with listing 13
# Scraped game title for listing 13 (Please_Knock_On_My_Door)
# Scraped listing 13
# Exported listing attributes for Please_Knock_On_My_Door to CSV file
# Done with page 473 listing 13 in 0.073 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 3.97 seconds...done.
#
# Received response to request from URL for page 473 listing 15 (Rocwood_Academy)
# Starting with listing 15
# Scraped game title for listing 15 (Rocwood_Academy)
# Scraped listing 15
# Exported listing attributes for Rocwood_Academy to CSV file
# Done with page 473 listing 15 in 0.067 sec.
# Time spent processing = 0.50 seconds.
# Pausing for 5.32 seconds...done.
#
# Received response to request from URL for page 473 listing 16 (Buzz_Aldrins_Space_Program_Manager)
# Starting with listing 16
# Scraped game title for listing 16 (Buzz_AldrinS_Space_Program_Manager)
# Scraped listing 16
# Exported listing attributes for Buzz_AldrinS_Space_Program_Manager to CSV file
# Done with page 473 listing 16 in 0.086 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.39 seconds...done.
#
# Received response to request from URL for page 473 listing 17 (Eschalon_Book_II)
# Starting with listing 17
# Scraped game title for listing 17 (Eschalon_Book_Ii)
# Scraped listing 17
# Exported listing attributes for Eschalon_Book_Ii to CSV file
# Done with page 473 listing 17 in 0.070 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 5.30 seconds...done.
#
# Received response to request from URL for page 473 listing 18 (Pendula_Swing__The_Complete_Journey)
# Starting with listing 18
# Scraped game title for listing 18 (Pendula_Swing__The_Complete_Journey)
# Scraped listing 18
# Exported listing attributes for Pendula_Swing__The_Complete_Journey to CSV file
# Done with page 473 listing 18 in 0.077 sec.
# Time spent processing = 0.67 seconds.
# Pausing for 4.94 seconds...done.
#
# Received response to request from URL for page 473 listing 19 (Divinity_Anthology)
# Starting with listing 19
# Scraped game title for listing 19 (Divinity_Ii_DeveloperS_Cut)
# Scraped listing 19
# Exported listing attributes for Divinity_Ii_DeveloperS_Cut to CSV file
# Done with page 473 listing 19 in 0.079 sec.
# Time spent processing = 0.52 seconds.
# Pausing for 3.44 seconds...done.
#
# Received response to request from URL for page 473 listing 20 (Obey_Me)
# Starting with listing 20
# Scraped game title for listing 20 (Obey_Me)
# Scraped listing 20
# Exported listing attributes for Obey_Me to CSV file
# Done with page 473 listing 20 in 0.075 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 3.62 seconds...done.
#
# Received response to request from URL for page 473 listing 21 (Survival_Vacancy)
# Starting with listing 21
# Scraped game title for listing 21 (Survival_Vacancy)
# Scraped listing 21
# Exported listing attributes for Survival_Vacancy to CSV file
# Done with page 473 listing 21 in 0.078 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 5.26 seconds...done.
#
# Received response to request from URL for page 473 listing 22 (Shanghai_Office_Simulator)
# Starting with listing 22
# Scraped game title for listing 22 (Shanghai_Office_Simulator)
# Scraped listing 22
# Exported listing attributes for Shanghai_Office_Simulator to CSV file
# Done with page 473 listing 22 in 0.075 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 5.39 seconds...done.
#
# Received response to request from URL for page 473 listing 23 (Fortissimo_FA_INTL_Ver)
# Starting with listing 23
# Scraped game title for listing 23 (Fortissimo_Fa_Intl_Ver)
# Scraped listing 23
# Exported listing attributes for Fortissimo_Fa_Intl_Ver to CSV file
# Done with page 473 listing 23 in 0.084 sec.
# Time spent processing = 0.70 seconds.
# Pausing for 3.07 seconds...done.
#
# Received response to request from URL for page 473 listing 24 (MY_FOX__Desktop_Wild_Pet)
# Starting with listing 24
# Scraped game title for listing 24 (My_Fox__Desktop_Wild_Pet)
# Scraped listing 24
# Exported listing attributes for My_Fox__Desktop_Wild_Pet to CSV file
# Done with page 473 listing 24 in 0.092 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 3.48 seconds...done.
#
# Received response to request from URL for page 473 listing 25 (Gathering_Sky)
# Starting with listing 25
# Scraped game title for listing 25 (Gathering_Sky)
# Scraped listing 25
# Exported listing attributes for Gathering_Sky to CSV file
# Done with page 473 listing 25 in 0.084 sec.
# Time spent processing = 0.71 seconds.
# Pausing for 4.07 seconds...done.
#
# Reached end of page 473. Pausing for 0.70 seconds between pages...done.
#
# Received response to request from URL for page 474 listing 1 (Super_Skelemania)
# Starting with listing 1
# Scraped game title for listing 1 (Super_Skelemania)
# Scraped listing 1
# Exported listing attributes for Super_Skelemania to CSV file
# Done with page 474 listing 1 in 0.070 sec.
# Time spent processing = 0.40 seconds.
# Pausing for 4.92 seconds...done.
#
# Received response to request from URL for page 474 listing 2 (Dungeon_Dreams_Female_Protagonist)
# Starting with listing 2
# Scraped game title for listing 2 (Dungeon_Dreams_Female_Protagonist)
# Scraped listing 2
# Exported listing attributes for Dungeon_Dreams_Female_Protagonist to CSV file
# Done with page 474 listing 2 in 0.078 sec.
# Time spent processing = 0.44 seconds.
# Pausing for 5.19 seconds...done.
#
# Received response to request from URL for page 474 listing 3 (Thief_Town)
# Starting with listing 3
# Scraped game title for listing 3 (Thief_Town)
# Scraped listing 3
# Exported listing attributes for Thief_Town to CSV file
# Done with page 474 listing 3 in 0.077 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 4.42 seconds...done.
#
# Received response to request from URL for page 474 listing 4 (Over_The_Hills_And_Far_Away)
# Starting with listing 4
# Scraped game title for listing 4 (Over_The_Hills_And_Far_Away)
# Scraped listing 4
# Exported listing attributes for Over_The_Hills_And_Far_Away to CSV file
# Done with page 474 listing 4 in 0.071 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.43 seconds...done.
#
# Received response to request from URL for page 474 listing 5 (One_Dreamer_Prologue)
# Starting with listing 5
# Scraped game title for listing 5 (One_Dreamer_Prologue)
# Scraped listing 5
# Exported listing attributes for One_Dreamer_Prologue to CSV file
# Done with page 474 listing 5 in 0.076 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.42 seconds...done.
#
# Received response to request from URL for page 474 listing 6 (TOK)
# Starting with listing 6
# Scraped game title for listing 6 (Tok)
# Scraped listing 6
# Exported listing attributes for Tok to CSV file
# Done with page 474 listing 6 in 0.084 sec.
# Time spent processing = 0.80 seconds.
# Pausing for 5.28 seconds...done.
#
# Received response to request from URL for page 474 listing 7 (Snowdome)
# Starting with listing 7
# Scraped game title for listing 7 (Snowdome)
# Scraped listing 7
# Exported listing attributes for Snowdome to CSV file
# Done with page 474 listing 7 in 0.076 sec.
# Time spent processing = 0.65 seconds.
# Pausing for 4.36 seconds...done.
#
# Received response to request from URL for page 474 listing 8 (The_Chronicles_of_Nyanya)
# Starting with listing 8
# Scraped game title for listing 8 (The_Chronicles_Of_Nyanya)
# Scraped listing 8
# Exported listing attributes for The_Chronicles_Of_Nyanya to CSV file
# Done with page 474 listing 8 in 0.075 sec.
# Time spent processing = 0.71 seconds.
# Pausing for 3.85 seconds...done.
#
# Received response to request from URL for page 474 listing 9 (Mighty_Switch_Force_Hose_It_Down)
# Starting with listing 9
# Scraped game title for listing 9 (Mighty_Switch_Force_Hose_It_Down)
# Scraped listing 9
# Exported listing attributes for Mighty_Switch_Force_Hose_It_Down to CSV file
# Done with page 474 listing 9 in 0.065 sec.
# Time spent processing = 0.38 seconds.
# Pausing for 4.17 seconds...done.
#
# Received response to request from URL for page 474 listing 10 (Dinner_with_an_Owl)
# Starting with listing 10
# Scraped game title for listing 10 (Dinner_With_An_Owl)
# Scraped listing 10
# Exported listing attributes for Dinner_With_An_Owl to CSV file
# Done with page 474 listing 10 in 0.073 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 3.64 seconds...done.
#
# Received response to request from URL for page 474 listing 11 (MONOLISK)
# Starting with listing 11
# Scraped game title for listing 11 (Monolisk)
# Scraped listing 11
# Exported listing attributes for Monolisk to CSV file
# Done with page 474 listing 11 in 0.074 sec.
# Time spent processing = 0.40 seconds.
# Pausing for 3.62 seconds...done.
#
# Received response to request from URL for page 474 listing 12 (Mimpi)
# Starting with listing 12
# Scraped game title for listing 12 (Mimpi)
# Scraped listing 12
# Exported listing attributes for Mimpi to CSV file
# Done with page 474 listing 12 in 0.070 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 4.40 seconds...done.
#
# Received response to request from URL for page 474 listing 13 (Professor_Fizzwizzle_and_the_Molten_Mystery)
# Starting with listing 13
# Scraped game title for listing 13 (Professor_Fizzwizzle_And_The_Molten_Mystery)
# Scraped listing 13
# Exported listing attributes for Professor_Fizzwizzle_And_The_Molten_Mystery to CSV file
# Done with page 474 listing 13 in 0.063 sec.
# Time spent processing = 0.48 seconds.
# Pausing for 3.05 seconds...done.
#
# Received response to request from URL for page 474 listing 14 (Car_Dealer)
# Starting with listing 14
# Scraped game title for listing 14 (Car_Dealer)
# Scraped listing 14
# Exported listing attributes for Car_Dealer to CSV file
# Done with page 474 listing 14 in 0.075 sec.
# Time spent processing = 0.41 seconds.
# Pausing for 5.22 seconds...done.
#
# Received response to request from URL for page 474 listing 15 (Colorful_Colore)
# Starting with listing 15
# Scraped game title for listing 15 (Colorful_Colore)
# Scraped listing 15
# Exported listing attributes for Colorful_Colore to CSV file
# Done with page 474 listing 15 in 0.077 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.23 seconds...done.
#
# Received response to request from URL for page 474 listing 16 (Disney_The_Princess_and_the_Frog)
# Starting with listing 16
# Scraped game title for listing 16 (Disney_The_Princess_And_The_Frog)
# Scraped listing 16
# Exported listing attributes for Disney_The_Princess_And_The_Frog to CSV file
# Done with page 474 listing 16 in 0.071 sec.
# Time spent processing = 0.34 seconds.
# Pausing for 4.32 seconds...done.
#
# Received response to request from URL for page 474 listing 17 (Royale_Age_Battle_of_Kings)
# Starting with listing 17
# Scraped game title for listing 17 (Royale_Age_Battle_Of_Kings)
# Scraped listing 17
# Exported listing attributes for Royale_Age_Battle_Of_Kings to CSV file
# Done with page 474 listing 17 in 0.093 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 4.72 seconds...done.
#
# Received response to request from URL for page 474 listing 18 (Zombo_Buster_Rising)
# Starting with listing 18
# Scraped game title for listing 18 (Zombo_Buster_Rising)
# Scraped listing 18
# Exported listing attributes for Zombo_Buster_Rising to CSV file
# Done with page 474 listing 18 in 0.070 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 4.40 seconds...done.
#
# Received response to request from URL for page 474 listing 19 (Pretty_Girls_Mahjong_Solitaire_BLUE)
# Starting with listing 19
# Scraped game title for listing 19 (Pretty_Girls_Mahjong_Solitaire_Blue)
# Scraped listing 19
# Exported listing attributes for Pretty_Girls_Mahjong_Solitaire_Blue to CSV file
# Done with page 474 listing 19 in 0.076 sec.
# Time spent processing = 0.57 seconds.
# Pausing for 3.40 seconds...done.
#
# Received response to request from URL for page 474 listing 20 (Trivia_Vault_Mini_Mixed_Trivia_4)
# Starting with listing 20
# Scraped game title for listing 20 (Trivia_Vault_Mini_Mixed_Trivia_4)
# Scraped listing 20
# Exported listing attributes for Trivia_Vault_Mini_Mixed_Trivia_4 to CSV file
# Done with page 474 listing 20 in 0.085 sec.
# Time spent processing = 1.20 seconds.
# Pausing for 4.67 seconds...done.
#
# Received response to request from URL for page 474 listing 21 (Shines_Adventures_2_Zombie_Attack)
# Starting with listing 21
# Scraped game title for listing 21 (ShineS_Adventures_2_Zombie_Attack)
# Scraped listing 21
# Exported listing attributes for ShineS_Adventures_2_Zombie_Attack to CSV file
# Done with page 474 listing 21 in 0.077 sec.
# Time spent processing = 0.52 seconds.
# Pausing for 3.28 seconds...done.
#
# Received response to request from URL for page 474 listing 22 (Double_Cross)
# Starting with listing 22
# Scraped game title for listing 22 (Double_Cross)
# Scraped listing 22
# Exported listing attributes for Double_Cross to CSV file
# Done with page 474 listing 22 in 0.072 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 4.60 seconds...done.
#
# Received response to request from URL for page 474 listing 23 (Heart_of_the_House)
# Starting with listing 23
# Scraped game title for listing 23 (Heart_Of_The_House)
# Scraped listing 23
# Exported listing attributes for Heart_Of_The_House to CSV file
# Done with page 474 listing 23 in 0.076 sec.
# Time spent processing = 1.06 seconds.
# Pausing for 4.99 seconds...done.
#
# Received response to request from URL for page 474 listing 24 (Sandmade)
# Starting with listing 24
# Scraped game title for listing 24 (Sandmade)
# Scraped listing 24
# Exported listing attributes for Sandmade to CSV file
# Done with page 474 listing 24 in 0.081 sec.
# Time spent processing = 0.43 seconds.
# Pausing for 3.03 seconds...done.
#
# Received response to request from URL for page 474 listing 25 (BLACKHOLE)
# Starting with listing 25
# Scraped game title for listing 25 (Blackhole)
# Scraped listing 25
# Exported listing attributes for Blackhole to CSV file
# Done with page 474 listing 25 in 0.081 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 4.57 seconds...done.
#
# Reached end of page 474. Pausing for 0.50 seconds between pages...done.
#
# Received response to request from URL for page 475 listing 1 (12_Labours_of_Hercules_V_Kids_of_Hellas_Platinum_Edition)
# Starting with listing 1
# Scraped game title for listing 1 (12_Labours_Of_Hercules_V_Kids_Of_Hellas_Platinum_Edition)
# Scraped listing 1
# Exported listing attributes for 12_Labours_Of_Hercules_V_Kids_Of_Hellas_Platinum_Edition to CSV file
# Done with page 475 listing 1 in 0.071 sec.
# Time spent processing = 0.54 seconds.
# Pausing for 5.33 seconds...done.
#
# Received response to request from URL for page 475 listing 3 (LOST_ORBIT)
# Starting with listing 3
# Scraped game title for listing 3 (Lost_Orbit)
# Scraped listing 3
# Exported listing attributes for Lost_Orbit to CSV file
# Done with page 475 listing 3 in 0.075 sec.
# Time spent processing = 0.65 seconds.
# Pausing for 4.94 seconds...done.
#
# Received response to request from URL for page 475 listing 4 (TOK_HARDCORE)
# Starting with listing 4
# Scraped game title for listing 4 (Tok_Hardcore)
# Scraped listing 4
# Exported listing attributes for Tok_Hardcore to CSV file
# Done with page 475 listing 4 in 0.087 sec.
# Time spent processing = 0.66 seconds.
# Pausing for 5.20 seconds...done.
#
# Received response to request from URL for page 475 listing 5 (Pixel_Traffic_Circle_Rush)
# Starting with listing 5
# Scraped game title for listing 5 (Pixel_Traffic_Circle_Rush)
# Scraped listing 5
# Exported listing attributes for Pixel_Traffic_Circle_Rush to CSV file
# Done with page 475 listing 5 in 0.077 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 3.08 seconds...done.
#
# Received response to request from URL for page 475 listing 6 (Extricate)
# Starting with listing 6
# Scraped game title for listing 6 (Extricate)
# Scraped listing 6
# Exported listing attributes for Extricate to CSV file
# Done with page 475 listing 6 in 0.068 sec.
# Time spent processing = 0.50 seconds.
# Pausing for 3.85 seconds...done.
#
# Received response to request from URL for page 475 listing 7 (Skatemasta_Tcheco)
# Starting with listing 7
# Scraped game title for listing 7 (Skatemasta_Tcheco)
# Scraped listing 7
# Exported listing attributes for Skatemasta_Tcheco to CSV file
# Done with page 475 listing 7 in 0.076 sec.
# Time spent processing = 0.46 seconds.
# Pausing for 4.68 seconds...done.
#
# Received response to request from URL for page 475 listing 8 (Soccer_Player_Simulator)
# Starting with listing 8
# Scraped game title for listing 8 (Soccer_Player_Simulator)
# Scraped listing 8
# Exported listing attributes for Soccer_Player_Simulator to CSV file
# Done with page 475 listing 8 in 0.069 sec.
# Time spent processing = 0.39 seconds.
# Pausing for 4.03 seconds...done.
#
# Received response to request from URL for page 475 listing 9 (Axegend_VR)
# Starting with listing 9
# Scraped game title for listing 9 (Axegend_Vr)
# Scraped listing 9
# Exported listing attributes for Axegend_Vr to CSV file
# Done with page 475 listing 9 in 0.081 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.45 seconds...done.
#
# Received response to request from URL for page 475 listing 10 (Escape_Doodland)
# Starting with listing 10
# Scraped game title for listing 10 (Escape_Doodland)
# Scraped listing 10
# Exported listing attributes for Escape_Doodland to CSV file
# Done with page 475 listing 10 in 0.076 sec.
# Time spent processing = 0.42 seconds.
# Pausing for 3.71 seconds...done.
#
# Received response to request from URL for page 475 listing 11 (One_Gun_Cat)
# Starting with listing 11
# Scraped game title for listing 11 (One_Gun_Cat)
# Scraped listing 11
# Exported listing attributes for One_Gun_Cat to CSV file
# Done with page 475 listing 11 in 0.071 sec.
# Time spent processing = 0.40 seconds.
# Pausing for 3.06 seconds...done.
#
# Received response to request from URL for page 475 listing 12 (Lost_in_Blindness)
# Starting with listing 12
# Scraped game title for listing 12 (Lost_In_Blindness)
# Scraped listing 12
# Exported listing attributes for Lost_In_Blindness to CSV file
# Done with page 475 listing 12 in 0.068 sec.
# Time spent processing = 0.52 seconds.
# Pausing for 4.28 seconds...done.
#
# Received response to request from URL for page 475 listing 13 (Anime_Wave_Simulator)
# Starting with listing 13
# Scraped game title for listing 13 (Anime_Wave_Simulator)
# Scraped listing 13
# Exported listing attributes for Anime_Wave_Simulator to CSV file
# Done with page 475 listing 13 in 0.072 sec.
# Time spent processing = 0.76 seconds.
# Pausing for 4.59 seconds...done.
#
# Received response to request from URL for page 475 listing 14 (Overkill_VR_Action_Shooter_FPS)
# Starting with listing 14
# Scraped game title for listing 14 (Overkill_Vr_Action_Shooter_Fps)
# Scraped listing 14
# Exported listing attributes for Overkill_Vr_Action_Shooter_Fps to CSV file
# Done with page 475 listing 14 in 0.075 sec.
# Time spent processing = 0.48 seconds.
# Pausing for 3.94 seconds...done.
#
# Received response to request from URL for page 475 listing 15 (SpaceNET__A_Space_Adventure)
# Starting with listing 15
# Scraped game title for listing 15 (Spacenet__A_Space_Adventure)
# Scraped listing 15
# Exported listing attributes for Spacenet__A_Space_Adventure to CSV file
# Done with page 475 listing 15 in 0.076 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 4.31 seconds...done.
#
# Received response to request from URL for page 475 listing 16 (Heli_Heroes)
# Starting with listing 16
# Scraped game title for listing 16 (Heli_Heroes)
# Scraped listing 16
# Exported listing attributes for Heli_Heroes to CSV file
# Done with page 475 listing 16 in 0.076 sec.
# Time spent processing = 0.69 seconds.
# Pausing for 5.17 seconds...done.
#
# Received response to request from URL for page 475 listing 17 (10_Second_Ninja)
# Starting with listing 17
# Scraped game title for listing 17 (10_Second_Ninja)
# Scraped listing 17
# Exported listing attributes for 10_Second_Ninja to CSV file
# Done with page 475 listing 17 in 0.072 sec.
# Time spent processing = 1.10 seconds.
# Pausing for 3.69 seconds...done.
#
# Received response to request from URL for page 475 listing 18 (Pon_Para_and_the_Great_Southern_Labyrinth)
# Starting with listing 18
# Scraped game title for listing 18 (Pon_Para_And_The_Great_Southern_Labyrinth)
# Scraped listing 18
# Exported listing attributes for Pon_Para_And_The_Great_Southern_Labyrinth to CSV file
# Done with page 475 listing 18 in 0.072 sec.
# Time spent processing = 1.09 seconds.
# Pausing for 4.66 seconds...done.
#
# Received response to request from URL for page 475 listing 19 (Seraph)
# Starting with listing 19
# Scraped game title for listing 19 (Seraph)
# Scraped listing 19
# Exported listing attributes for Seraph to CSV file
# Done with page 475 listing 19 in 0.087 sec.
# Time spent processing = 0.50 seconds.
# Pausing for 4.89 seconds...done.
#
# Received response to request from URL for page 475 listing 21 (Strange_Night)
# Starting with listing 21
# Scraped game title for listing 21 (Strange_Night)
# Scraped listing 21
# Exported listing attributes for Strange_Night to CSV file
# Done with page 475 listing 21 in 0.080 sec.
# Time spent processing = 0.45 seconds.
# Pausing for 5.33 seconds...done.
#
# Received response to request from URL for page 475 listing 22 (Bubbaruka)
# Starting with listing 22
# Scraped game title for listing 22 (Bubbaruka)
# Scraped listing 22
# Exported listing attributes for Bubbaruka to CSV file
# Done with page 475 listing 22 in 0.075 sec.
# Time spent processing = 0.64 seconds.
# Pausing for 4.68 seconds...done.
#
# Received response to request from URL for page 475 listing 23 (Arelite_Core)
# Starting with listing 23
# Scraped game title for listing 23 (Arelite_Core)
# Scraped listing 23
# Exported listing attributes for Arelite_Core to CSV file
# Done with page 475 listing 23 in 0.071 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.34 seconds...done.
#
# Received response to request from URL for page 475 listing 24 (The_Take)
# Starting with listing 24
# Scraped game title for listing 24 (The_Take)
# Scraped listing 24
# Exported listing attributes for The_Take to CSV file
# Done with page 475 listing 24 in 0.077 sec.
# Time spent processing = 0.57 seconds.
# Pausing for 5.29 seconds...done.
#
# Received response to request from URL for page 475 listing 25 (Idle_Expanse)
# Starting with listing 25
# Scraped game title for listing 25 (Idle_Expanse)
# Scraped listing 25
# Exported listing attributes for Idle_Expanse to CSV file
# Done with page 475 listing 25 in 0.079 sec.
# Time spent processing = 0.56 seconds.
# Pausing for 4.63 seconds...done.
#
# Reached end of page 475. Pausing for 0.79 seconds between pages...done.
#
# Received response to request from URL for page 476 listing 2 (The_Last_Dream_Developers_Edition)
# Starting with listing 2
# Scraped game title for listing 2 (The_Last_Dream_DeveloperS_Edition)
# Scraped listing 2
# Exported listing attributes for The_Last_Dream_DeveloperS_Edition to CSV file
# Done with page 476 listing 2 in 0.083 sec.
# Time spent processing = 0.68 seconds.
# Pausing for 4.69 seconds...done.
#
# Received response to request from URL for page 476 listing 3 (Reversion__The_Return_Last_Chapter)
# Starting with listing 3
# Scraped game title for listing 3 (Reversion__The_Return_Last_Chapter)
# Scraped listing 3
# Exported listing attributes for Reversion__The_Return_Last_Chapter to CSV file
# Done with page 476 listing 3 in 0.079 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 4.18 seconds...done.
#
# Received response to request from URL for page 476 listing 4 (GhostControl_Inc)
# Starting with listing 4
# Scraped game title for listing 4 (Ghostcontrol_Inc)
# Scraped listing 4
# Exported listing attributes for Ghostcontrol_Inc to CSV file
# Done with page 476 listing 4 in 0.079 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 5.24 seconds...done.
#
# Received response to request from URL for page 476 listing 5 (Sink_Again)
# Starting with listing 5
# Scraped game title for listing 5 (Sink_Again)
# Scraped listing 5
# Exported listing attributes for Sink_Again to CSV file
# Done with page 476 listing 5 in 0.076 sec.
# Time spent processing = 0.45 seconds.
# Pausing for 5.06 seconds...done.
#
# Received response to request from URL for page 476 listing 6 (Hope_Lake)
# Starting with listing 6
# Scraped game title for listing 6 (Hope_Lake)
# Scraped listing 6
# Exported listing attributes for Hope_Lake to CSV file
# Done with page 476 listing 6 in 0.080 sec.
# Time spent processing = 0.62 seconds.
# Pausing for 3.40 seconds...done.
#
# Received response to request from URL for page 476 listing 7 (Newt_One)
# Starting with listing 7
# Scraped game title for listing 7 (Newt_One)
# Scraped listing 7
# Exported listing attributes for Newt_One to CSV file
# Done with page 476 listing 7 in 0.076 sec.
# Time spent processing = 0.85 seconds.
# Pausing for 3.60 seconds...done.
#
# Received response to request from URL for page 476 listing 8 (Sigi__A_Fart_for_Melusina)
# Starting with listing 8
# Scraped game title for listing 8 (Sigi__A_Fart_For_Melusina)
# Scraped listing 8
# Exported listing attributes for Sigi__A_Fart_For_Melusina to CSV file
# Done with page 476 listing 8 in 0.083 sec.
# Time spent processing = 0.57 seconds.
# Pausing for 4.68 seconds...done.
#
# Received response to request from URL for page 476 listing 10 (Shadow_Brawlers)
# Starting with listing 10
# Scraped game title for listing 10 (Shadow_Brawlers)
# Scraped listing 10
# Exported listing attributes for Shadow_Brawlers to CSV file
# Done with page 476 listing 10 in 0.073 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 5.05 seconds...done.
#
# Received response to request from URL for page 476 listing 11 (X_Beyond_the_Frontier)
# Starting with listing 11
# Scraped game title for listing 11 (X_Beyond_The_Frontier)
# Scraped listing 11
# Exported listing attributes for X_Beyond_The_Frontier to CSV file
# Done with page 476 listing 11 in 0.072 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 4.16 seconds...done.
#
# Received response to request from URL for page 476 listing 12 (Hop_Step_Sing_Kisekiteki_Shining_HQ_Edition)
# Starting with listing 12
# Scraped game title for listing 12 (Hop_Step_Sing_Kisekiteki_Shining_Hq_Edition)
# Scraped listing 12
# Exported listing attributes for Hop_Step_Sing_Kisekiteki_Shining_Hq_Edition to CSV file
# Done with page 476 listing 12 in 0.076 sec.
# Time spent processing = 0.63 seconds.
# Pausing for 3.80 seconds...done.
#
# Received response to request from URL for page 476 listing 13 (Molecats)
# Starting with listing 13
# Scraped game title for listing 13 (Molecats)
# Scraped listing 13
# Exported listing attributes for Molecats to CSV file
# Done with page 476 listing 13 in 0.086 sec.
# Time spent processing = 0.75 seconds.
# Pausing for 4.93 seconds...done.
#
# Received response to request from URL for page 476 listing 14 (Good_Robot)
# Starting with listing 14
# Scraped game title for listing 14 (Good_Robot)
# Scraped listing 14
# ...
# Starting with listing 8
# Scraped game title for listing 8 (President_Trump_The_Way_In_Uganda)
# Scraped listing 8
# Exported listing attributes for President_Trump_The_Way_In_Uganda to CSV file
# Done with page 504 listing 8 in 0.067 sec.
# Time spent processing = 0.81 seconds.
# Pausing for 3.95 seconds...done.
#
# Received response to request from URL for page 504 listing 9 (Lighton)
# Starting with listing 9
# Scraped game title for listing 9 (Lighton)
# Scraped listing 9
# Exported listing attributes for Lighton to CSV file
# Done with page 504 listing 9 in 0.074 sec.
# Time spent processing = 0.55 seconds.
# Pausing for 3.38 seconds...done.
#
# Received response to request from URL for page 504 listing 10 (Opaline)
# Starting with listing 10
# Scraped game title for listing 10 (Opaline)
# Scraped listing 10
# Exported listing attributes for Opaline to CSV file
# Done with page 504 listing 10 in 0.078 sec.
# Time spent processing = 0.76 seconds.
# Pausing for 4.55 seconds...done.
#
# Received response to request from URL for page 504 listing 11 (Ollie & Bollie: Outdoor Estate)
# Starting with listing 11
# Scraped game title for listing 11 (Ollie__Bollie_Outdoor_Estate)
# Scraped listing 11
# Exported listing attributes for Ollie__Bollie_Outdoor_Estate to CSV file
# Done with page 504 listing 11 in 0.075 sec.
# Time spent processing = 0.76 seconds.
# Pausing for 3.22 seconds...done.
#
# Received response to request from URL for page 504 listing 12 (Pixel Traffic: Circle Rush)
# Starting with listing 12
# Scraped game title for listing 12 (Pixel_Traffic_Circle_Rush)
# Scraped listing 12
# Exported listing attributes for Pixel_Traffic_Circle_Rush to CSV file
# Done with page 504 listing 12 in 0.078 sec.
# Time spent processing = 0.88 seconds.
# Pausing for 5.11 seconds...done.
#
# Received response to request from URL for page 504 listing 13 (Soda Girls)
# Starting with listing 13
# Scraped game title for listing 13 (Soda_Girls)
# Scraped listing 13
# Exported listing attributes for Soda_Girls to CSV file
# Done with page 504 listing 13 in 0.079 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 4.46 seconds...done.
#
# Received response to request from URL for page 504 listing 14 (FPS Training)
# Starting with listing 14
# Scraped game title for listing 14 (Fps_Training)
# Scraped listing 14
# Exported listing attributes for Fps_Training to CSV file
# Done with page 504 listing 14 in 0.072 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 3.24 seconds...done.
#
# Received response to request from URL for page 504 listing 15 (Intensive Exposure)
# Starting with listing 15
# Scraped game title for listing 15 (Intensive_Exposure)
# Scraped listing 15
# Exported listing attributes for Intensive_Exposure to CSV file
# Done with page 504 listing 15 in 0.066 sec.
# Time spent processing = 0.41 seconds.
# Pausing for 4.84 seconds...done.
#
# Received response to request from URL for page 504 listing 16 (Outbreak: Endless Nightmares)
# Starting with listing 16
# Scraped game title for listing 16 (Outbreak_Endless_Nightmares)
# Scraped listing 16
# Exported listing attributes for Outbreak_Endless_Nightmares to CSV file
# Done with page 504 listing 16 in 0.089 sec.
# Time spent processing = 0.88 seconds.
# Pausing for 3.28 seconds...done.
#
# Received response to request from URL for page 504 listing 17 (UBERMOSH + Original Soundtrack)
# Starting with listing 17
# Scraped game title for listing 17 (Ubermosh)
# Scraped listing 17
# Exported listing attributes for Ubermosh to CSV file
# Done with page 504 listing 17 in 0.081 sec.
# Time spent processing = 0.85 seconds.
# Pausing for 3.50 seconds...done.
#
# Received response to request from URL for page 504 listing 18 (Abduction Bit)
# Starting with listing 18
# Scraped game title for listing 18 (Abduction_Bit)
# Scraped listing 18
# Exported listing attributes for Abduction_Bit to CSV file
# Done with page 504 listing 18 in 0.079 sec.
# Time spent processing = 0.75 seconds.
# Pausing for 4.25 seconds...done.
#
# Received response to request from URL for page 504 listing 19 (Sniper Ghost Warrior Contracts Digital Deluxe Edition)
# Starting with listing 19
# Scraped game title for listing 19 (Sniper_Ghost_Warrior_Contracts)
# Scraped listing 19
# Exported listing attributes for Sniper_Ghost_Warrior_Contracts to CSV file
# Done with page 504 listing 19 in 0.087 sec.
# Time spent processing = 0.64 seconds.
# Pausing for 3.74 seconds...done.
#
# Received response to request from URL for page 504 listing 20 (Mu Cartographer)
# Starting with listing 20
# Scraped game title for listing 20 (Mu_Cartographer)
# Scraped listing 20
# Exported listing attributes for Mu_Cartographer to CSV file
# Done with page 504 listing 20 in 0.069 sec.
# Time spent processing = 0.46 seconds.
# Pausing for 3.22 seconds...done.
#
# Received response to request from URL for page 504 listing 21 (COROPATA)
# Starting with listing 21
# Scraped game title for listing 21 (Coropata)
# Scraped listing 21
# Exported listing attributes for Coropata to CSV file
# Done with page 504 listing 21 in 0.071 sec.
# Time spent processing = 0.47 seconds.
# Pausing for 4.28 seconds...done.
#
# Received response to request from URL for page 504 listing 22 (Kittypocalypse - Ungoggled)
# Starting with listing 22
# Scraped game title for listing 22 (Kittypocalypse__Ungoggled)
# Scraped listing 22
# Exported listing attributes for Kittypocalypse__Ungoggled to CSV file
# Done with page 504 listing 22 in 0.069 sec.
# Time spent processing = 0.72 seconds.
# Pausing for 4.64 seconds...done.
#
# Received response to request from URL for page 504 listing 23 (The 11th Hour)
# Starting with listing 23
# Scraped game title for listing 23 (The_11Th_Hour)
# Scraped listing 23
# Exported listing attributes for The_11Th_Hour to CSV file
# Done with page 504 listing 23 in 0.072 sec.
# Time spent processing = 0.45 seconds.
# Pausing for 4.65 seconds...done.
#
# Received response to request from URL for page 504 listing 24 (Forgotten Spirits)
# Starting with listing 24
# Scraped game title for listing 24 (Forgotten_Spirits)
# Scraped listing 24
# Exported listing attributes for Forgotten_Spirits to CSV file
# Done with page 504 listing 24 in 0.072 sec.
# Time spent processing = 0.47 seconds.
# Pausing for 4.59 seconds...done.
#
# Received response to request from URL for page 504 listing 25 (MOAI 3: Trade Mission Collector's Edition)
# Starting with listing 25
# Scraped game title for listing 25 (Moai_3_Trade_Mission_CollectorS_Edition)
# Scraped listing 25
# Exported listing attributes for Moai_3_Trade_Mission_CollectorS_Edition to CSV file
# Done with page 504 listing 25 in 0.072 sec.
# Time spent processing = 0.71 seconds.
# Pausing for 4.57 seconds...done.
#
# Reached end of page 504. Pausing for 0.52 seconds between pages...done.
#
# Received response to request from URL for page 505 listing 1 (Storm Boy)
# Starting with listing 1
# Scraped game title for listing 1 (Storm_Boy)
# Scraped listing 1
# Exported listing attributes for Storm_Boy to CSV file
# Done with page 505 listing 1 in 0.066 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.43 seconds...done.
#
# Received response to request from URL for page 505 listing 2 (Future Fortune)
# Starting with listing 2
# Scraped game title for listing 2 (Future_Fortune)
# Scraped listing 2
# Exported listing attributes for Future_Fortune to CSV file
# Done with page 505 listing 2 in 0.069 sec.
# Time spent processing = 0.42 seconds.
# Pausing for 4.08 seconds...done.
#
# Received response to request from URL for page 505 listing 3 (Harvested)
# Starting with listing 3
# Scraped game title for listing 3 (Harvested)
# Scraped listing 3
# Exported listing attributes for Harvested to CSV file
# Done with page 505 listing 3 in 0.100 sec.
# Time spent processing = 0.64 seconds.
# Pausing for 5.01 seconds...done.
#
# Received response to request from URL for page 505 listing 4 (Maze: Sinister Play Collector's Edition)
# Starting with listing 4
# Scraped game title for listing 4 (Maze_Sinister_Play_CollectorS_Edition)
# Scraped listing 4
# Exported listing attributes for Maze_Sinister_Play_CollectorS_Edition to CSV file
# Done with page 505 listing 4 in 0.072 sec.
# Time spent processing = 0.41 seconds.
# Pausing for 3.82 seconds...done.
#
# Received response to request from URL for page 505 listing 5 (Trivia Vault: Toy Trivia)
# Starting with listing 5
# Scraped game title for listing 5 (Trivia_Vault_Toy_Trivia)
# Scraped listing 5
# Exported listing attributes for Trivia_Vault_Toy_Trivia to CSV file
# Done with page 505 listing 5 in 0.073 sec.
# Time spent processing = 0.80 seconds.
# Pausing for 4.65 seconds...done.
#
# Received response to request from URL for page 505 listing 6 (Fighties)
# Starting with listing 6
# Scraped game title for listing 6 (Fighties)
# Scraped listing 6
# Exported listing attributes for Fighties to CSV file
# Done with page 505 listing 6 in 0.072 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.61 seconds...done.
#
# Received response to request from URL for page 505 listing 7 (Don't cut your hand)
# Starting with listing 7
# Scraped game title for listing 7 (DonT_Cut_Your_Hand)
# Scraped listing 7
# Exported listing attributes for DonT_Cut_Your_Hand to CSV file
# Done with page 505 listing 7 in 0.072 sec.
# Time spent processing = 0.56 seconds.
# Pausing for 3.32 seconds...done.
#
# Received response to request from URL for page 505 listing 8 (VR Shooting Range: Multiple Weapons)
# Starting with listing 8
# Scraped game title for listing 8 (Vr_Shooting_Range_Multiple_Weapons)
# Scraped listing 8
# Exported listing attributes for Vr_Shooting_Range_Multiple_Weapons to CSV file
# Done with page 505 listing 8 in 0.092 sec.
# Time spent processing = 1.05 seconds.
# Pausing for 3.16 seconds...done.
#
# Received response to request from URL for page 505 listing 9 (Reaching for Petals)
# Starting with listing 9
# Scraped game title for listing 9 (Reaching_For_Petals)
# Scraped listing 9
# Exported listing attributes for Reaching_For_Petals to CSV file
# Done with page 505 listing 9 in 0.073 sec.
# Time spent processing = 0.56 seconds.
# Pausing for 5.10 seconds...done.
#
# Received response to request from URL for page 505 listing 10 (Awakening: The Redleaf Forest Collector's Edition)
# Starting with listing 10
# Scraped game title for listing 10 (Awakening_The_Redleaf_Forest_CollectorS_Edition)
# Scraped listing 10
# Exported listing attributes for Awakening_The_Redleaf_Forest_CollectorS_Edition to CSV file
# Done with page 505 listing 10 in 0.076 sec.
# Time spent processing = 0.53 seconds.
# Pausing for 5.25 seconds...done.
#
# Received response to request from URL for page 505 listing 11 (Heaven's Hope - Special Edition)
# Starting with listing 11
# Scraped game title for listing 11 (HeavenS_Hope__Special_Edition)
# Scraped listing 11
# Exported listing attributes for HeavenS_Hope__Special_Edition to CSV file
# Done with page 505 listing 11 in 0.068 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 5.37 seconds...done.
#
# Received response to request from URL for page 505 listing 12 (Gabe Newell Simulator)
# Starting with listing 12
# Scraped game title for listing 12 (Gabe_Newell_Simulator)
# Scraped listing 12
# Exported listing attributes for Gabe_Newell_Simulator to CSV file
# Done with page 505 listing 12 in 0.076 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 4.83 seconds...done.
#
# Received response to request from URL for page 505 listing 13 (Angry Arrows)
# Starting with listing 13
# Scraped game title for listing 13 (Angry_Arrows)
# Scraped listing 13
# Exported listing attributes for Angry_Arrows to CSV file
# Done with page 505 listing 13 in 0.070 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 4.47 seconds...done.
#
# Received response to request from URL for page 505 listing 14 (VR Zeppelin Airship Trips: Flying hotel experiences in VR)
# Starting with listing 14
# Scraped game title for listing 14 (Vr_Zeppelin_Airship_Trips_Flying_Hotel_Experiences_In_Vr)
# Scraped listing 14
# Exported listing attributes for Vr_Zeppelin_Airship_Trips_Flying_Hotel_Experiences_In_Vr to CSV file
# Done with page 505 listing 14 in 0.090 sec.
# Time spent processing = 0.94 seconds.
# Pausing for 4.86 seconds...done.
#
# Received response to request from URL for page 505 listing 15 (Metal Dead)
# Starting with listing 15
# Scraped game title for listing 15 (Metal_Dead)
# Scraped listing 15
# Exported listing attributes for Metal_Dead to CSV file
# Done with page 505 listing 15 in 0.073 sec.
# Time spent processing = 0.58 seconds.
# Pausing for 4.49 seconds...done.
#
# Received response to request from URL for page 505 listing 16 (Ultimate MMA)
# Starting with listing 16
# Scraped game title for listing 16 (Ultimate_Mma)
# Scraped listing 16
# Exported listing attributes for Ultimate_Mma to CSV file
# Done with page 505 listing 16 in 0.073 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.83 seconds...done.
#
# Received response to request from URL for page 505 listing 17 (Close Your Eyes [Old Version])
# Starting with listing 17
# Scraped game title for listing 17 (Close_Your_Eyes_Old_Version)
# Scraped listing 17
# Exported listing attributes for Close_Your_Eyes_Old_Version to CSV file
# Done with page 505 listing 17 in 0.070 sec.
# Time spent processing = 0.61 seconds.
# Pausing for 4.36 seconds...done.
#
# Received response to request from URL for page 505 listing 18 (Empires Apart)
# Starting with listing 18
# Scraped game title for listing 18 (Empires_Apart)
# Scraped listing 18
# Exported listing attributes for Empires_Apart to CSV file
# Done with page 505 listing 18 in 0.076 sec.
# Time spent processing = 0.59 seconds.
# Pausing for 4.21 seconds...done.
#
# Received response to request from URL for page 505 listing 19 (Monument)
# Starting with listing 19
# Scraped game title for listing 19 (Monument)
# Scraped listing 19
# Exported listing attributes for Monument to CSV file
# Done with page 505 listing 19 in 0.077 sec.
# Time spent processing = 0.48 seconds.
# Pausing for 4.90 seconds...done.
#
# Received response to request from URL for page 505 listing 20 (Half Past Fate: Romantic Distancing)
# Starting with listing 20
# Scraped game title for listing 20 (Half_Past_Fate_Romantic_Distancing)
# Scraped listing 20
# Exported listing attributes for Half_Past_Fate_Romantic_Distancing to CSV file
# Done with page 505 listing 20 in 0.067 sec.
# Time spent processing = 0.65 seconds.
# Pausing for 5.10 seconds...done.
#
# Received response to request from URL for page 505 listing 21 (Ain Dodo)
# Starting with listing 21
# Scraped game title for listing 21 (Ain_Dodo)
# Scraped listing 21
# Exported listing attributes for Ain_Dodo to CSV file
# Done with page 505 listing 21 in 0.070 sec.
# Time spent processing = 0.51 seconds.
# Pausing for 3.90 seconds...done.
#
# Received response to request from URL for page 505 listing 22 (Massive Assault: Phantom Renaissance)
# Starting with listing 22
# Scraped game title for listing 22 (Massive_Assault_Phantom_Renaissance)
# Scraped listing 22
# Exported listing attributes for Massive_Assault_Phantom_Renaissance to CSV file
# Done with page 505 listing 22 in 0.064 sec.
# Time spent processing = 0.49 seconds.
# Pausing for 3.19 seconds...done.
#
# Received response to request from URL for page 505 listing 23 (The Twins)
# Starting with listing 23
# Scraped game title for listing 23 (The_Twins)
# Scraped listing 23
# Exported listing attributes for The_Twins to CSV file
# Done with page 505 listing 23 in 0.071 sec.
# Time spent processing = 0.50 seconds.
# Pausing for 5.09 seconds...done.
#
# Received response to request from URL for page 505 listing 24 (Dead In Bermuda)
# Starting with listing 24
# Scraped game title for listing 24 (Dead_In_Bermuda)
# Scraped listing 24
# Exported listing attributes for Dead_In_Bermuda to CSV file
# Done with page 505 listing 24 in 0.075 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 3.13 seconds...done.
#
# Received response to request from URL for page 505 listing 25 (Fairy Bloom Freesia)
# Starting with listing 25
# Scraped game title for listing 25 (Fairy_Bloom_Freesia)
# Scraped listing 25
# Exported listing attributes for Fairy_Bloom_Freesia to CSV file
# Done with page 505 listing 25 in 0.073 sec.
# Time spent processing = 0.60 seconds.
# Pausing for 3.97 seconds...done.
#
# Reached end of page 505. Pausing for 0.53 seconds between pages...done.
#
# CPU times: user 2min 19s, sys: 1.86 s, total: 2min 21s
# Wall time: 1h 7min 16s

# %% [markdown]
# <a id="examine-collected-outputs"></a>
#
# ## 4. [Examine collected outputs](#examine-collected-outputs)

# %% [markdown]
# Get a list of the created CSV filepaths

# %%
csv_file_list = glob(os.path.join(requests_data_dir, "p*_l*_*.csv"))
csv_file_list.sort(key=lambda f: int(re.sub("\D", "", f)))
print(f"Found {len(csv_file_list)} CSV files of listings.")
# Out:
# Found 4256 CSV files of listings.

# %% [markdown]
# Vertically concatenate all CSV files into a single DataFrame

# %%
# %%time
df_listings = pd.concat(
    [pd.read_csv(f) for f in csv_file_list],
    ignore_index=True,
).drop_duplicates()
cols_to_hide = ["user_defined_tags", "languages"]
display(df_listings.head(2).append(df_listings.tail(2)).drop(columns=cols_to_hide))
display(
    df_listings.isna().sum().rename("num_missing").to_frame().merge(
        df_listings.dtypes.rename("dtype").to_frame(),
        left_index=True,
        right_index=True,
    )
)
# Out:
#       review_type_all overall_review_rating  pct_overall  \
# 0                 NaN         Very Positive         90.0
# 1                 NaN         Very Positive         93.0
# 4254              NaN       Mostly Negative         48.0
# 4255              NaN                 Mixed         69.0
#
#      pct_overall_threshold  pct_overall_lang  pct_overall_threshold_lang  \
# 0                 positive               NaN                         NaN
# 1                 positive               NaN                         NaN
# 4254              positive               NaN                         NaN
# 4255              positive               NaN                         NaN
#
#             platforms  num_steam_achievements  \
# 0                 win                     NaN
# 1                 win                     NaN
# 4254              win                     NaN
# 4255  win, mac, linux                     NaN
#
#                                                     drm rating  ...  \
# 0                                                   NaN    NaN  ...
# 1     Requires agreement to a 3rd-party EULA, Hot La...    NaN  ...
# 4254                                                NaN      e  ...
# 4255                                                NaN    NaN  ...
#
#                                                   Genre  Release Date  \
# 0     Action, Casual, Indie, Simulation, Strategy, E...  Mar 23, 2020
# 1                      Action, Adventure, Indie, Racing  Sep 19, 2019
# 4254                                                NaN  Jan 19, 2012
# 4255                                                NaN   Apr 5, 2018
#
#       Early Access Release Date             Developer           Publisher  \
# 0                  Mar 23, 2020      Nezon Production    Nezon Production
# 1                           NaN    Klei Entertainment  Klei Entertainment
# 4254                        NaN                  SEGA                SEGA
# 4255                        NaN  Nova B12, OtakuNovel            Nova B12
#
#                Franchise num_languages page_num listing_num  \
# 0                    NaN             2       53           1
# 1     Klei Entertainment            14       53           2
# 4254  Sonic the Hedgehog             6      185          15
# 4255                 NaN             2      407          24
#
#                                                     url
# 0     https://store.steampowered.com/app/1216320/Shi...
# 1     https://store.steampowered.com/app/382560/Hot_...
# 4254  https://store.steampowered.com/app/202530/Soni...
# 4255  https://store.steampowered.com/app/825550/Blue...
#
# [4 rows x 25 columns]
#                             num_missing    dtype
# review_type_all                    4256  float64
# overall_review_rating                 5   object
# pct_overall                           7  float64
# pct_overall_threshold                 7   object
# pct_overall_lang                   4256  float64
# pct_overall_threshold_lang         4256  float64
# platforms                            25   object
# user_defined_tags                     0   object
# num_steam_achievements             4256  float64
# drm                                3705   object
# rating                             3271   object
# rating_descriptors                 3499   object
# review_type_positive               4256  float64
# review_type_negative               4256  float64
# review_language_mine               4256  float64
# Title                               261   object
# Genre                               269   object
# Release Date                        267   object
# Early Access Release Date          3826   object
# Developer                           268   object
# Publisher                           282   object
# Franchise                          2923   object
# languages                             0   object
# num_languages                         0    int64
# page_num                              0    int64
# listing_num                           0    int64
# url                                   0   object
# CPU times: user 13.4 s, sys: 192 ms, total: 13.6 s
# Wall time: 13.6 s

# %% [markdown]
# Verify that the number of unique URLs matches the number of rows in this dataset (this means the URL column should be unique in the `DataFrame`, since we are expecting this)
# - consider page numbers 100 onwards since pages 50-100 included some duplicate results that appeared after page 100 (more detailed discussion is given in `6_merge_searches_listings.ipynb`)

# %%
try:
    assert df_listings[df_listings["page_num"] >= 100]["url"].nunique() == len(df_listings[df_listings["page_num"] >= 100])
except AssertionError:
    print("Found duplicated URL.")
    print(
        f"Number of unique URLs = {df_listings[df_listings['page_num'] >= 100]['url'].nunique()}\n"
        f"Number of rows = {len(df_listings[df_listings['page_num'] >= 100])}"
    )

# %% [markdown]
# **Observations**
# 1. As expected, the URL column is unique in this dataset and there are as many URLs as rows in the `DataFrame`.

# %% [markdown]
# ---

# %% [markdown]
# <span style="float:left">
#     <a href="./4_filter_requests_listings.ipynb"><< 4 - Filter Search Results scraped with requests library</a>
# </span>
#
# <span style="float:right">
#     <a href="./6_merge_searches_listings.ipynb">6 - Merge scraped Search Results Dataset with Listings Dataset >></a>
# </span>
